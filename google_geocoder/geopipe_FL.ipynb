# %%
import requests
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
#fl_df= pd.read_csv("../../data/state_data/pipe_states/21/fl.csv") 
fl_df= pd.read_csv("../../data/state_data/geo/geocoded/geo_fl.csv") #Use if partially geoprocessed
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber  SBAOfficeCode ProcessingMethod  \
# 0               6             6  9794577700            491              PPP
# 1          205912        205912  1345247301            491              PPP
# 2          205913        205913  1442247205            455              PPP
# 3          205914        205914  2030068400            455              PPP
# 4          205915        205915  2964268209            455              PPP
# ...           ...           ...         ...            ...              ...
# 60036      265947        265947  9950428308            455              PPS
# 60037      265948        265948  9963928609            455              PPP
# 60038      265949        265949  9977848305            455              PPS
# 60039      265950        265950  9988227001            455              PPP
# 60040      265951        265951  9993628309            455              PPS
#
# ...

# %%
print(fl_geodf.isnull().sum())
# Out:
# Unnamed: 0            0
# Unnamed: 0.1          0
# Unnamed: 0.1.1        0
# LoanNumber            0
# DateApproved          0
#                   ...
# job_Range             0
# full_add              0
# Lat                   0
# Long                  1
# FIPS_z            10182
# Length: 73, dtype: int64

# %%
mask = fl_geodf['Lat'].isnull() 
mask_fl = fl_geodf[mask]
mask_fl
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 11712      217623        217623          217623  3874118701      3/31/21
# 23529      229440        229440          229440  3635048304      1/22/21
# 23530      229441        229441          229441  9551438401      2/17/21
# 38683      244594        244594          244594  6775747900      6/16/20
#
#        SBAOfficeCode ProcessingMethod                       BorrowerName  \
# 11712            455              PPS             MICCOSUKEE ENTERPRISES
# 23529            491              PPS  UNITED ELECTRICAL CONTRACTORS INC
# 23530            455              PPS                 OSPREY LEISURE LLC
# 38683            455              PPP        TEDDY PIERRE-LOUIS, PA, LLC
#
#                           BorrowerAddress BorrowerCity  ... TRIIndustrySector  \
# 11712          MILE MARKER 37.5 US HWY 41        MIAMI  ...         999 Other
# ...

# %%
fl_geodf['Lat'].replace('None', np.nan, inplace=True)

# %%
print(fl_geodf.isnull().sum())
# Out:
# Unnamed: 0            0
# Unnamed: 0.1          0
# Unnamed: 0.1.1        0
# LoanNumber            0
# DateApproved          0
#                   ...
# job_Range             0
# full_add              0
# Lat                   4
# Long                  1
# FIPS_z            10182
# Length: 73, dtype: int64

# %%
fl_df= fl_df.drop(["Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1"], axis=1)

# %% [markdown]
# <h4>Google GeoCoding API Part 1

# %% [markdown]
# <b>Add coordinate columns if not previously geoprocessed

# %%
#Add coordinate columns
fl_df["Lat"]=np.nan
fl_df["Long"]=np.nan
fl_df["FIPS_z"]=np.nan

# %% [markdown]
# <b>Filter geoprocessed rows

# %%
fl_df_null = fl_df[fl_df["Lat"].isnull()] 
fl_df_null
# Out:
#        LoanNumber  SBAOfficeCode ProcessingMethod  \
# 5163   7789398610            455              PPS
# 6743   3284547106            455              PPP
# 8243   2070197108            455              PPP
# 9814   1524968002            491              PPP
# 9815   6794148300            455              PPS
# ...           ...            ...              ...
# 60035  9940717704            455              PPP
# 60036  9950428308            455              PPS
# 60038  9977848305            455              PPS
# 60039  9988227001            455              PPP
# 60040  9993628309            455              PPS
#
#                                             BorrowerName  \
# 5163                               BOLAY ENTERPRISES LLC
# 6743                            TIERRA SOUTH FLORIDA INC
# 8243                               BRIGHT LINE TITLE LLC
# 9814                     HYUNDAI OF CENTRAL FLORIDA, LLC
# 9815                              PARADISE EXTERIORS LLC
# ...

# %% [markdown]
# <b>Drop Duplicate Address to Limit # of Requests

# %%
#process to identify and code for unique addresses 
ppp_togeo = fl_df_null["full_add"]
ppp_togeo_unique = ppp_togeo.drop_duplicates()
ppp_togeo_unique
# Out:
# 5163          11390 N Jog Rd Ste 101, Palm Bch Gdns, FL
# 6743               2765 VISTA PKWY, WEST PALM BEACH, FL
# 8243     5404 Cypress Center Drive Suite 300, TAMPA, FL
# 9814                  17325 State Road 50, Clermont, FL
# 9815               1918 Corporate Dr, Boynton Beach, FL
#                               ...
# 60035                 2600 Douglas Rd, Coral Gables, FL
# 60036                   7369 Sheridan St, Hollywood, FL
# 60038               8608 Little Rd, New Port Richey, FL
# 60039                    5016 N COOLIDGE AVE, TAMPA, FL
# 60040           5670 S Highway A1A, Melbourne Beach, FL
# Name: full_add, Length: 47513, dtype: object

# %% [markdown]
# <b>First 40K request allowance

# %%
#ppp_togeo_unique40= ppp_togeo_unique.iloc[:40000] #40000-9425=30575
#ppp_togeo_unique40
ppp_togeo_unique40= ppp_togeo_unique.iloc[:30575] #40000-9425=30575
ppp_togeo_unique40
# Out:
# 5163          11390 N Jog Rd Ste 101, Palm Bch Gdns, FL
# 6743               2765 VISTA PKWY, WEST PALM BEACH, FL
# 8243     5404 Cypress Center Drive Suite 300, TAMPA, FL
# 9814                  17325 State Road 50, Clermont, FL
# 9815               1918 Corporate Dr, Boynton Beach, FL
#                               ...
# 42069                  1102 NW 40th Way, LAUDERHILL, FL
# 42070                   3845 Beck Boulevard, Naples, FL
# 42071                    3811 FOWLER ST, FORT MYERS, FL
# 42072         16 NE 4TH ST STE 210, FORT LAUDERDALE, FL
# 42073               921 THOMASVILLE RD, TALLAHASSEE, FL
# Name: full_add, Length: 30575, dtype: object

# %% [markdown]
# <b>Google Geocoding API

# %%
API_KEY = "AIzaSyB1VgzISCRoQ1hh-ARhR0rzXtQmSKA4TkI" # c.s = 40000

# %%
params = {
    "key":API_KEY
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
addresses = ppp_togeo_unique40 #STATE
lat = []
lng = []
notfound = []
for address in tqdm(addresses):
    params['address'] = f"{address}"
    response = requests.get(base_url, params=params).json()
    results = response['results']
    try:
        #print(f"{address} is {results[0]['geometry']['location']}")
        #geometry = results[0]['geometry']
        lat.append(results[0]['geometry']['location']['lat'])
        lng.append(results[0]['geometry']['location']['lng'])
        
    except (KeyError, IndexError):
        print(f"{address} Not Found")
        notfound.append(address)
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
#   0%|          | 0/30575 [00:00<?, ?it/s]
# (813) 731-2210, Lutz, FL Not Found
# 7800 NW 25th Street, #1, MIAMI, FL Not Found
# 4309 SALISBURY ROAD, JACKSONVILLE, FL Not Found
# 1597 The Greens Way, Jacksonville Beach, FL Not Found
# 1700 SANS SOUCI BLVD, MIAMI, FL Not Found
# 1933 E EDGEWOOD DR STE 102, LAKELAND, FL Not Found
# 221 WEST OAKLAND PARK BLVD, OAKLAND PK, FL Not Found
# 1320 Orlando Avenue 4, Winter Park, FL Not Found
# 114 S Orange Ave, Orlando, FL Not Found
# 10709 INDIAN TRAIL, COOPER CITY, FL Not Found
# 106 N TAMIAMI TRAIL, OSPREY, FL Not Found
# 3625 Avalon Park W Blvd, ORLANDO, FL Not Found
# 3700 Dohnavur Drive, MOUNT DORA, FL Not Found
# 1500 NW FEDERAL HWY, STUART, FL Not Found
# 713 US Highway 1, North Palm Beach, FL Not Found
# 2221 Shoma Lane, Royal Palm Beach, FL Not Found
# 1385 Coral Way Fl 3, Miami, FL Not Found
# 6267 OLD WATER OAK RD, TALLAHASSEE, FL Not Found
# 1641 N 71st Ter, Hollywood, FL Not Found
# 425 Hobbs St, Tampa, FL Not Found
# ...

# %%
print(notfound)
notfound_df = pd.DataFrame({"Not_Found":notfound})
notfound_df.count()
# Out:
# ['(813) 731-2210, Lutz, FL', '7800 NW 25th Street, #1, MIAMI, FL', '4309 SALISBURY ROAD, JACKSONVILLE, FL', '1597 The Greens Way, Jacksonville Beach, FL', '1700 SANS SOUCI BLVD, MIAMI, FL', '1933 E EDGEWOOD DR STE 102, LAKELAND, FL', '221 WEST OAKLAND PARK BLVD, OAKLAND PK, FL', '1320 Orlando Avenue 4, Winter Park, FL', '114 S Orange Ave, Orlando, FL', '10709 INDIAN TRAIL, COOPER CITY, FL', '106 N TAMIAMI TRAIL, OSPREY, FL', '3625 Avalon Park W Blvd, ORLANDO, FL', '3700 Dohnavur Drive, MOUNT DORA, FL', '1500 NW FEDERAL HWY, STUART, FL', '713 US Highway 1, North Palm Beach, FL', '2221 Shoma Lane, Royal Palm Beach, FL', '1385 Coral Way Fl 3, Miami, FL', '6267 OLD WATER OAK RD, TALLAHASSEE, FL', '1641 N 71st Ter, Hollywood, FL', '425 Hobbs St, Tampa, FL', '5050 Ulmerton Rd, Clearwater, FL', '1102 NW 40th Way, LAUDERHILL, FL', '3845 Beck Boulevard, Naples, FL']
# Not_Found    23
# dtype: int64

# %%
addresses = ppp_togeo_unique40
addresses
# Out:
# 5163          11390 N Jog Rd Ste 101, Palm Bch Gdns, FL
# 6743               2765 VISTA PKWY, WEST PALM BEACH, FL
# 8243     5404 Cypress Center Drive Suite 300, TAMPA, FL
# 9814                  17325 State Road 50, Clermont, FL
# 9815               1918 Corporate Dr, Boynton Beach, FL
#                               ...
# 42069                  1102 NW 40th Way, LAUDERHILL, FL
# 42070                   3845 Beck Boulevard, Naples, FL
# 42071                    3811 FOWLER ST, FORT MYERS, FL
# 42072         16 NE 4TH ST STE 210, FORT LAUDERDALE, FL
# 42073               921 THOMASVILLE RD, TALLAHASSEE, FL
# Name: full_add, Length: 30575, dtype: object

# %%
lat_df= pd.DataFrame(lat)
lng_df= pd.DataFrame(lng)
print(lat_df.count())
print(lng_df.count()) #check for number equal to addresses
# Out:
# 0    30552
# dtype: int64
# 0    30552
# dtype: int64

# %%
location_df = pd.DataFrame({"full_add": addresses, "Lat": lat, "Long":lng})
location_df #review NaN
# Out:
#                                              full_add        Lat       Long
# 5163        11390 N Jog Rd Ste 101, Palm Bch Gdns, FL  26.703219 -80.148534
# 6743             2765 VISTA PKWY, WEST PALM BEACH, FL  26.716615 -80.138225
# 8243   5404 Cypress Center Drive Suite 300, TAMPA, FL  27.949659 -82.535031
# 9814                17325 State Road 50, Clermont, FL  28.547978 -81.668996
# 9815             1918 Corporate Dr, Boynton Beach, FL  26.510346 -80.076333
# ...                                               ...        ...        ...
# 42069                1102 NW 40th Way, LAUDERHILL, FL        NaN        NaN
# 42070                 3845 Beck Boulevard, Naples, FL        NaN        NaN
# 42071                  3811 FOWLER ST, FORT MYERS, FL  26.606413 -81.861408
# 42072       16 NE 4TH ST STE 210, FORT LAUDERDALE, FL  26.125775 -80.143030
# 42073             921 THOMASVILLE RD, TALLAHASSEE, FL  30.452326 -84.278720
#
# [30575 rows x 3 columns]

# %%
#mapping coordinates to NaN values in main ppp_geo
m = dict(zip(location_df.full_add,location_df.Lat))
fl_df.Lat = fl_df.Lat.fillna(fl_df.full_add.map(m))
n = dict(zip(location_df.full_add,location_df.Long))
fl_df.Long = fl_df.Long.fillna(fl_df.full_add.map(n))

# %%
null_check = fl_df.loc[fl_df["Lat"].isnull()] #49396>17226
null_check
# Out:
#        LoanNumber  SBAOfficeCode ProcessingMethod  \
# 26535  4394838406            455              PPS
# 42005  6354347105            455              PPP
# 42013  4796727110            491              PPP
# 42017  9830828806            491              PPS
# 42018  8734157108            455              PPP
# ...           ...            ...              ...
# 60035  9940717704            455              PPP
# 60036  9950428308            455              PPS
# 60038  9977848305            455              PPS
# 60039  9988227001            455              PPP
# 60040  9993628309            455              PPS
#
#                                             BorrowerName  \
# 26535                                 TRAVELIN LIGHT INC
# 42005                              DORAL BILLIARDS GROUP
# 42013               VERNIS & BOWLING OF NORTH FLORIDA PA
# 42017                   TIDES EDGE RECOVERY SERVICES LLC
# 42018                                 MINTZ TRUPPMAN P A
# ...

# %%
print(fl_df.isnull().sum()) #verify Lat, Long are same number
# Out:
# LoanNumber              0
# SBAOfficeCode           0
# ProcessingMethod        0
# BorrowerName            0
# BorrowerAddress         0
#                     ...
# job_Range               0
# full_add                0
# Lat                 17226
# Long                17226
# FIPS_Z              60041
# Length: 68, dtype: int64

# %%
fl_df.to_csv("../../data/state_data/geo/geocoded/geo_fl.csv")

# %% [markdown]
# <h4>Google GeoCoding API Part 2

# %% [markdown]
# <b>Remainder Requests >40K

# %%
fl_df = pd.read_csv("../../data/state_data/geo/geocoded/geo_fl.csv")
fl_df_null = fl_df[fl_df["Lat"].isnull()] 
fl_df_null #17226
# Out:
#        Unnamed: 0  LoanNumber  SBAOfficeCode ProcessingMethod  \
# 26535       26535  4394838406            455              PPS
# 42005       42005  6354347105            455              PPP
# 42013       42013  4796727110            491              PPP
# 42017       42017  9830828806            491              PPS
# 42018       42018  8734157108            455              PPP
# ...           ...         ...            ...              ...
# 60035       60035  9940717704            455              PPP
# 60036       60036  9950428308            455              PPS
# 60038       60038  9977848305            455              PPS
# 60039       60039  9988227001            455              PPP
# 60040       60040  9993628309            455              PPS
#
#                                             BorrowerName  \
# 26535                                 TRAVELIN LIGHT INC
# 42005                              DORAL BILLIARDS GROUP
# ...

# %%
#process to identify and code for unique addresses 
ppp_togeo = fl_df_null["full_add"]
ppp_togeo_uniqueREMAINDER = ppp_togeo.drop_duplicates()
ppp_togeo_uniqueREMAINDER #16961
# Out:
# 26535                       (813) 731-2210, Lutz, FL
# 42005             7800 NW 25th Street, #1, MIAMI, FL
# 42013          4309 SALISBURY ROAD, JACKSONVILLE, FL
# 42017    1597 The Greens Way, Jacksonville Beach, FL
# 42018                1700 SANS SOUCI BLVD, MIAMI, FL
#                             ...
# 60035              2600 Douglas Rd, Coral Gables, FL
# 60036                7369 Sheridan St, Hollywood, FL
# 60038            8608 Little Rd, New Port Richey, FL
# 60039                 5016 N COOLIDGE AVE, TAMPA, FL
# 60040        5670 S Highway A1A, Melbourne Beach, FL
# Name: full_add, Length: 16961, dtype: object

# %% [markdown]
# <b>Google Geocoding API

# %%
API_KEY = "AIzaSyC7hhwM4qlfkU8zfiq1_MR-n4BWktUxxMo" #c.d.s = 21651

# %%
params = {
    "key":API_KEY
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
addresses = ppp_togeo_uniqueREMAINDER #STATE
lat = []
lng = []
notfound = []
for address in tqdm(addresses):
    params['address'] = f"{address}"
    response = requests.get(base_url, params=params).json()
    results = response['results']
    try:
        #print(f"{address} is {results[0]['geometry']['location']}")
        #geometry = results[0]['geometry']
        lat.append(results[0]['geometry']['location']['lat'])
        lng.append(results[0]['geometry']['location']['lng'])
        
    except (KeyError, IndexError):
        print(f"{address} Not Found")
        notfound.append(address)
        lat.append(np.nan) 
        lng.append(np.nan)
# Out:
#   0%|          | 0/16961 [00:00<?, ?it/s]
# (813) 731-2210, Lutz, FL Not Found
# 7800 NW 25th Street, #1, MIAMI, FL Not Found
# 4309 SALISBURY ROAD, JACKSONVILLE, FL Not Found
# 1597 The Greens Way, Jacksonville Beach, FL Not Found
# 1700 SANS SOUCI BLVD, MIAMI, FL Not Found
# 114 S Orange Ave, Orlando, FL Not Found
# 3625 Avalon Park W Blvd, ORLANDO, FL Not Found
# 1500 NW FEDERAL HWY, STUART, FL Not Found
# 6267 OLD WATER OAK RD, TALLAHASSEE, FL Not Found
# 1641 N 71st Ter, Hollywood, FL Not Found
# 4364 40th St. S., SAINT PETERSBURG, FL Not Found
# 817 N Dixie Hwy, Pompano Beach, FL Not Found

# %%
print(notfound)
notfound_df = pd.DataFrame({"Not_Found":notfound})
notfound_df.count()
# Out:
# ['(813) 731-2210, Lutz, FL', '7800 NW 25th Street, #1, MIAMI, FL', '4309 SALISBURY ROAD, JACKSONVILLE, FL', '1597 The Greens Way, Jacksonville Beach, FL', '1700 SANS SOUCI BLVD, MIAMI, FL', '114 S Orange Ave, Orlando, FL', '3625 Avalon Park W Blvd, ORLANDO, FL', '1500 NW FEDERAL HWY, STUART, FL', '6267 OLD WATER OAK RD, TALLAHASSEE, FL', '1641 N 71st Ter, Hollywood, FL', '4364 40th St. S., SAINT PETERSBURG, FL', '817 N Dixie Hwy, Pompano Beach, FL']
# Not_Found    12
# dtype: int64

# %%
addresses = ppp_togeo_uniqueREMAINDER
addresses
# Out:
# 26535                       (813) 731-2210, Lutz, FL
# 42005             7800 NW 25th Street, #1, MIAMI, FL
# 42013          4309 SALISBURY ROAD, JACKSONVILLE, FL
# 42017    1597 The Greens Way, Jacksonville Beach, FL
# 42018                1700 SANS SOUCI BLVD, MIAMI, FL
#                             ...
# 60035              2600 Douglas Rd, Coral Gables, FL
# 60036                7369 Sheridan St, Hollywood, FL
# 60038            8608 Little Rd, New Port Richey, FL
# 60039                 5016 N COOLIDGE AVE, TAMPA, FL
# 60040        5670 S Highway A1A, Melbourne Beach, FL
# Name: full_add, Length: 16961, dtype: object

# %%
lat_df= pd.DataFrame(lat)
lng_df= pd.DataFrame(lng)
lat_df.count() 
lng_df.count() #check for number equal to addresses
# Out:
# 0    16949
# dtype: int64

# %%
location_df = pd.DataFrame({"full_add": addresses, "Lat": lat, "Long":lng})
location_df
# Out:
#                                           full_add        Lat       Long
# 26535                     (813) 731-2210, Lutz, FL        NaN        NaN
# 42005           7800 NW 25th Street, #1, MIAMI, FL        NaN        NaN
# 42013        4309 SALISBURY ROAD, JACKSONVILLE, FL        NaN        NaN
# 42017  1597 The Greens Way, Jacksonville Beach, FL        NaN        NaN
# 42018              1700 SANS SOUCI BLVD, MIAMI, FL        NaN        NaN
# ...                                            ...        ...        ...
# 60035            2600 Douglas Rd, Coral Gables, FL  25.747722 -80.254740
# 60036              7369 Sheridan St, Hollywood, FL  26.031886 -80.236052
# 60038          8608 Little Rd, New Port Richey, FL  28.282086 -82.675429
# 60039               5016 N COOLIDGE AVE, TAMPA, FL  27.992650 -82.518094
# 60040      5670 S Highway A1A, Melbourne Beach, FL  27.969087 -80.510022
#
# [16961 rows x 3 columns]

# %%
#mapping coordinates to NaN values in main ppp_geo
m = dict(zip(location_df.full_add,location_df.Lat))
fl_df.Lat = fl_df.Lat.fillna(fl_df.full_add.map(m))
n = dict(zip(location_df.full_add,location_df.Long))
fl_df.Long = fl_df.Long.fillna(fl_df.full_add.map(n))

# %%
null_check = fl_df.loc[fl_df["Lat"].isnull()] 
null_check
# Out:
#        Unnamed: 0  LoanNumber  SBAOfficeCode ProcessingMethod  \
# 26535       26535  4394838406            455              PPS
# 42005       42005  6354347105            455              PPP
# 42013       42013  4796727110            491              PPP
# 42017       42017  9830828806            491              PPS
# 42018       42018  8734157108            455              PPP
# 42046       42046  1036188909            491              PPS
# 42050       42050  1361187209            491              PPP
# 42053       42053  5368367009            455              PPP
# 42064       42064  7147317207            491              PPP
# 42065       42065  3891828508            455              PPS
# 42089       42089  1057017101            455              PPP
# 42098       42098  3833108506            455              PPS
# 57494       57494  4732607208            491              PPP
#
#                                       BorrowerName          BorrowerAddress  \
# ...

# %%
fl_df["FIPS_z"]=np.nan
fl_df = fl_df.drop(["FIPS_Z"], axis=1)
fl_df
# Out:
#        Unnamed: 0  LoanNumber  SBAOfficeCode ProcessingMethod  \
# 0               0  9794577700            491              PPP
# 1               1  1345247301            491              PPP
# 2               2  1442247205            455              PPP
# 3               3  2030068400            455              PPP
# 4               4  2964268209            455              PPP
# ...           ...         ...            ...              ...
# 60036       60036  9950428308            455              PPS
# 60037       60037  9963928609            455              PPP
# 60038       60038  9977848305            455              PPS
# 60039       60039  9988227001            455              PPP
# 60040       60040  9993628309            455              PPS
#
#                                             BorrowerName  \
# 0       FRUIT COVE BAPTIST CHURCH OF JACKSONVILLE FL INC
# 1                           ASPIRE HEALTH PARTNERS, INC.
# ...

# %%
fl_df.to_csv("../../data/state_data/geo/geocoded/geo_fl.csv")

# %% [markdown]
# Verify Null

# %%
fl_df = pd.read_csv("../../data/state_data/geo/geocoded/geo_fl.csv")

# %%
fl_df.shape[0]
print(fl_df.isnull().sum()) #check after FL process 
# note: FL !!
# Out:
# Unnamed: 0              0
# LoanNumber              0
# SBAOfficeCode           0
# ProcessingMethod        0
# BorrowerName            0
#                     ...
# job_Range               0
# full_add                0
# Lat                    13
# Long                   13
# FIPS_z              60041
# Length: 69, dtype: int64

# %% [markdown]
# <h2>Part 3

# %% [markdown]
# <b>Rewrite geoprocessed state to Main Geo DataFrame

# %%
ppp_geo = pd.read_csv("../../data/state_data/geo/ppp_geo.csv")

# %%
fl_df = pd.read_csv("../../data/state_data/geo/geocoded/geo_fl.csv")

# %%
cols= ["LoanNumber", "Lat", "Long"]
fl_df_geoprocessed= fl_df[cols]

# %%
test_merge = ppp_geo.merge(fl_df, on ="LoanNumber", how="left").drop_duplicates(['Lat','Long'], keep='last') #Check
test_merge

# %%
merge = ppp_geo.merge(fl_df, on ="LoanNumber", how="left")
merge

# %% [markdown]
# <b> If fully geoprocessed then rename Lat, Long columns with newest
# <b> replace FIPS_z with NaN for state and process through FIPS
