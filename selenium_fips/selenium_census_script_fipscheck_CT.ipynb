# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_ct.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1"], axis =1) 
fips_check.head() #10912
# Out:
#    Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      185624  3903327306      4/29/20            156              PPP
# 1      185625  4505207402       5/9/20            156              PPP
# 2      185626  5539227705       5/1/20            156              PPP
# 3      185627  5630057006       4/6/20            156              PPP
# 4      185628  8388727000       4/8/20            156              PPP
#
#                    BorrowerName           BorrowerAddress BorrowerCity  \
# 0                   PROPARK INC             1 Union Place     Hartford
# 1  MONROE STAFFING SERVICES LLC             6 RESEARCH DR      SHELTON
# 2      CENVEO WORLDWIDE LIMITED  200 First Stamford Place     Stamford
# 3      SERVICE MANAGEMENT GROUP            25 CONTROLS DR      SHELTON
# 4                DAY PITNEY LLP           242 TRUMBULL ST     HARTFORD
#
#   BorrowerState  BorrowerZip  ...                          LongName  \
# 0            CT       6103.0  ...         Parking Lots and Garages
# 1            CT       6484.0  ...    Employment Placement Agencies
# 2            CT       6902.0  ...  Stationery Product Manufacturing
# 3            CT       6484.0  ...              Janitorial Services
# 4            CT       6103.0  ...                Offices of Lawyers
#
#   TRIIndustrySector                           IndustrySubsector  4DigitNAICS  \
# 0         999 Other               8129 Other Personal Services        8129.0
# 1         999 Other                    5613 Employment Services       5613.0
# 2         322 Paper  3222 Converted Paper Product Manufacturing       3222.0
# 3         999 Other    5617 Services to Buildings and Dwellings       5617.0
# 4         999 Other                         5411 Legal Services       5411.0
#
#                 SBAOfficeLabel       Loan_Range    job_Range  \
# 0  CONNECTICUT DISTRICT OFFICE  e $5-10 million  500 or more
# 1  CONNECTICUT DISTRICT OFFICE  e $5-10 million  500 or more
# 2  CONNECTICUT DISTRICT OFFICE  e $5-10 million  500 or more
# 3  CONNECTICUT DISTRICT OFFICE  e $5-10 million  500 or more
# 4  CONNECTICUT DISTRICT OFFICE  e $5-10 million   250 to 499
#
#                                  full_add        Lat       Long
# 0             1 Union Place, Hartford, CT  41.768886 -72.681543
# 1              6 RESEARCH DR, SHELTON, CT  41.274979 -73.134472
# 2  200 First Stamford Place, Stamford, CT  41.044604 -73.549385
# 3             25 CONTROLS DR, SHELTON, CT  41.283920 -73.107990
# 4           242 TRUMBULL ST, HARTFORD, CT  41.768035 -72.675077
#
# [5 rows x 70 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan
# Out:
#       LoanNumber                                           full_add  Lat  Long
# 5247  3539977109  1486 highland ave building 2 unit 1, CHESHIRE, CT  NaN   NaN

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna #12892
# Out:
#        LoanNumber                                 full_add        Lat  \
# 0      3903327306              1 Union Place, Hartford, CT  41.768886
# 1      4505207402               6 RESEARCH DR, SHELTON, CT  41.274979
# 2      5539227705   200 First Stamford Place, Stamford, CT  41.044604
# 3      5630057006              25 CONTROLS DR, SHELTON, CT  41.283920
# 4      8388727000            242 TRUMBULL ST, HARTFORD, CT  41.768035
# ...           ...                                      ...        ...
# 12888  9618168507           109 Pequotsepos Rd, Mystic, CT  41.362416
# 12889  9648837000               73 East St, PLAINVILLE, CT  41.669405
# 12890  9763078402           76 Knowlton St, Bridgeport, CT  41.184879
# 12891  9854708505           15 E Putnam Ave, Greenwich, CT  41.031819
# 12892  9988368505  2304 Berlin Tpke Ste 202, Newington, CT  41.689555
#
#             Long
# 0     -72.681543
# 1     -73.134472
# 2     -73.549385
# 3     -73.107990
# 4     -72.675077
# ...          ...
# 12888 -71.946780
# 12889 -72.861979
# 12890 -73.187417
# 12891 -73.626677
# 12892 -72.705986
#
# [12892 rows x 4 columns]

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("data/state_data/geo/geo_fips/CT_fips_scraped.csv") 
fips_check_scraped.head()

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #40813

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #1239

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
    
executable_path = {'executable_path': ChromeDriverManager().install()}
driver = Browser('chrome', **executable_path, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('_x_id').clear()
        driver.find_by_id('_y_id').clear()
        driver.find_by_id('_x_id').fill(long[i])
        driver.find_by_id('_y_id').fill(lat[i])
        driver.find_by_id('proceed').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='pl_gov_census_geo_geocoder_domain_GeographyResult')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('09')] #CT
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                print(f"{i},{lat[i]},{long[i]} Not Found")
                notfound.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# There is no [mac64] chromedriver for browser  in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/ciaraspencer/.wdm/drivers/chromedriver/mac64/99.0.4844.51]
# HBox(children=(FloatProgress(value=0.0, max=12892.0), HTML(value='')))

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 12892

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:1239]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
# <ipython-input-13-08e9c917fe2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fips_fill["FIPS_z"] = geo_id_list
#        LoanNumber                                 full_add        Lat  \
# 0      3903327306              1 Union Place, Hartford, CT  41.768886
# 1      4505207402               6 RESEARCH DR, SHELTON, CT  41.274979
# 2      5539227705   200 First Stamford Place, Stamford, CT  41.044604
# 3      5630057006              25 CONTROLS DR, SHELTON, CT  41.283920
# 4      8388727000            242 TRUMBULL ST, HARTFORD, CT  41.768035
# ...           ...                                      ...        ...
# 12888  9618168507           109 Pequotsepos Rd, Mystic, CT  41.362416
# 12889  9648837000               73 East St, PLAINVILLE, CT  41.669405
# 12890  9763078402           76 Knowlton St, Bridgeport, CT  41.184879
# 12891  9854708505           15 E Putnam Ave, Greenwich, CT  41.031819
# 12892  9988368505  2304 Berlin Tpke Ste 202, Newington, CT  41.689555
#
#             Long             FIPS_z
# 0     -72.681543  [090035021002009]
# 1     -73.134472  [090011103022004]
# 2     -73.549385  [090010223003001]
# 3     -73.107990  [090011102023008]
# 4     -72.675077  [090035021001038]
# ...          ...                ...
# 12888 -71.946780  [090117053001004]
# 12889 -72.861979  [090034205004006]
# 12890 -73.187417  [090010739003009]
# 12891 -73.626677  [090010106002002]
# 12892 -72.705986  [090034944002009]
#
# [12892 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
# <ipython-input-14-e19831f223ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
#        LoanNumber                                 full_add        Lat  \
# 0      3903327306              1 Union Place, Hartford, CT  41.768886
# 1      4505207402               6 RESEARCH DR, SHELTON, CT  41.274979
# 2      5539227705   200 First Stamford Place, Stamford, CT  41.044604
# 3      5630057006              25 CONTROLS DR, SHELTON, CT  41.283920
# 4      8388727000            242 TRUMBULL ST, HARTFORD, CT  41.768035
# ...           ...                                      ...        ...
# 12888  9618168507           109 Pequotsepos Rd, Mystic, CT  41.362416
# 12889  9648837000               73 East St, PLAINVILLE, CT  41.669405
# 12890  9763078402           76 Knowlton St, Bridgeport, CT  41.184879
# 12891  9854708505           15 E Putnam Ave, Greenwich, CT  41.031819
# 12892  9988368505  2304 Berlin Tpke Ste 202, Newington, CT  41.689555
#
#             Long           FIPS_z
# 0     -72.681543  090035021002009
# 1     -73.134472  090011103022004
# 2     -73.549385  090010223003001
# 3     -73.107990  090011102023008
# 4     -72.675077  090035021001038
# ...          ...              ...
# 12888 -71.946780  090117053001004
# 12889 -72.861979  090034205004006
# 12890 -73.187417  090010739003009
# 12891 -73.626677  090010106002002
# 12892 -72.705986  090034944002009
#
# [12892 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check
# Out:
#        LoanNumber                                     full_add        Lat  \
# 1457   1004577101  120 Long Ridge Road   3 North, STAMFORD, CT  41.195893
# 3075   7637387710                5200 Rte 42, Turnersville, CT  39.765211
# 10902  4931747305             180 Varick Street, SALISBURY, CT  40.727398
#
#             Long FIPS_z
# 1457  -73.620851    NaN
# 3075  -75.048383    NaN
# 10902 -74.005178    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#        LoanNumber           FIPS_z
# 0      3903327306  090035021002009
# 1      4505207402  090011103022004
# 2      5539227705  090010223003001
# 3      5630057006  090011102023008
# 4      8388727000  090035021001038
# ...           ...              ...
# 12888  9618168507  090117053001004
# 12889  9648837000  090034205004006
# 12890  9763078402  090010739003009
# 12891  9854708505  090010106002002
# 12892  9988368505  090034944002009
#
# [12892 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_ct.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check

#if from FIPS file
#fips_check = pd.read_csv("data/state_data/geo/geo_fips/CT_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #15796
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0          185624        185624  3903327306      4/29/20            156
# 1          185625        185625  4505207402       5/9/20            156
# 2          185626        185626  5539227705       5/1/20            156
# 3          185627        185627  5630057006       4/6/20            156
# 4          185628        185628  8388727000       4/8/20            156
# ...           ...           ...         ...          ...            ...
# 12888      198512        198512  9618168507      3/12/21            156
# 12889      198513        198513  9648837000       4/9/20            156
# 12890      198514        198514  9763078402      2/17/21            156
# 12891      198515        198515  9854708505      3/12/21            156
# 12892      198516        198516  9988368505      3/12/21            156
#
#       ProcessingMethod                            BorrowerName  \
# 0                  PPP                             PROPARK INC
# 1                  PPP            MONROE STAFFING SERVICES LLC
# 2                  PPP                CENVEO WORLDWIDE LIMITED
# 3                  PPP                SERVICE MANAGEMENT GROUP
# 4                  PPP                          DAY PITNEY LLP
# ...                ...                                     ...
# 12888              PPS  DENISON PEQUOTSEPOS NATURE CENTER INC.
# 12889              PPP                  GNAZZO FOOD CENTER INC
# 12890              PPS             ALL AROUND CONTRACTING CORP
# 12891              PPS                    WALKING WITH PURPOSE
# 12892              PPS                      WELLNESS HOME CARE
#
#                 BorrowerAddress BorrowerCity BorrowerState  ...  \
# 0                 1 Union Place     Hartford            CT  ...
# 1                 6 RESEARCH DR      SHELTON            CT  ...
# 2      200 First Stamford Place     Stamford            CT  ...
# 3                25 CONTROLS DR      SHELTON            CT  ...
# 4               242 TRUMBULL ST     HARTFORD            CT  ...
# ...                         ...          ...           ...  ...
# 12888        109 Pequotsepos Rd       Mystic            CT  ...
# 12889                73 East St   PLAINVILLE            CT  ...
# 12890            76 Knowlton St   Bridgeport            CT  ...
# 12891           15 E Putnam Ave    Greenwich            CT  ...
# 12892  2304 Berlin Tpke Ste 202    Newington            CT  ...
#
#                                                 LongName  \
# 0                              Parking Lots and Garages
# 1                         Employment Placement Agencies
# 2                       Stationery Product Manufacturing
# 3                                   Janitorial Services
# 4                                     Offices of Lawyers
# ...                                                  ...
# 12888   All Other Miscellaneous Schools and Instruction
# 12889  Supermarkets and Other Grocery (except Conveni...
# 12890    Other Heavy and Civil Engineering Construction
# 12891                              All Other Publishers
# 12892                          Home Health Care Services
#
#             TRIIndustrySector  \
# 0                   999 Other
# 1                   999 Other
# 2                   322 Paper
# 3                   999 Other
# 4                   999 Other
# ...                       ...
# 12888               999 Other
# 12889               999 Other
# 12890               999 Other
# 12891  511 512 519 Publishing
# 12892               999 Other
#
#                                        IndustrySubsector  4DigitNAICS  \
# 0                          8129 Other Personal Services        8129.0
# 1                               5613 Employment Services       5613.0
# 2             3222 Converted Paper Product Manufacturing       3222.0
# 3               5617 Services to Buildings and Dwellings       5617.0
# 4                                    5411 Legal Services       5411.0
# ...                                                  ...          ...
# 12888                 6116 Other Schools and Instruction       6116.0
# 12889                               4451 Grocery Stores        4451.0
# 12890  2379 Other Heavy and Civil Engineering Constru...       2379.0
# 12891  5111 Newspaper, Periodical, Book, and Director...       5111.0
# 12892                     6216 Home Health Care Services       6216.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 1      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 2      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 3      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 4      CONNECTICUT DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 12888  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12889  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12890  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12891  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12892  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat       Long
# 0                  1 Union Place, Hartford, CT  41.768886 -72.681543
# 1                   6 RESEARCH DR, SHELTON, CT  41.274979 -73.134472
# 2       200 First Stamford Place, Stamford, CT  41.044604 -73.549385
# 3                  25 CONTROLS DR, SHELTON, CT  41.283920 -73.107990
# 4                242 TRUMBULL ST, HARTFORD, CT  41.768035 -72.675077
# ...                                        ...        ...        ...
# 12888           109 Pequotsepos Rd, Mystic, CT  41.362416 -71.946780
# 12889               73 East St, PLAINVILLE, CT  41.669405 -72.861979
# 12890           76 Knowlton St, Bridgeport, CT  41.184879 -73.187417
# 12891           15 E Putnam Ave, Greenwich, CT  41.031819 -73.626677
# 12892  2304 Berlin Tpke Ste 202, Newington, CT  41.689555 -72.705986
#
# [12893 rows x 71 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0          185624        185624  3903327306      4/29/20            156
# 1          185625        185625  4505207402       5/9/20            156
# 2          185626        185626  5539227705       5/1/20            156
# 3          185627        185627  5630057006       4/6/20            156
# 4          185628        185628  8388727000       4/8/20            156
# ...           ...           ...         ...          ...            ...
# 12888      198512        198512  9618168507      3/12/21            156
# 12889      198513        198513  9648837000       4/9/20            156
# 12890      198514        198514  9763078402      2/17/21            156
# 12891      198515        198515  9854708505      3/12/21            156
# 12892      198516        198516  9988368505      3/12/21            156
#
#       ProcessingMethod                            BorrowerName  \
# 0                  PPP                             PROPARK INC
# 1                  PPP            MONROE STAFFING SERVICES LLC
# 2                  PPP                CENVEO WORLDWIDE LIMITED
# 3                  PPP                SERVICE MANAGEMENT GROUP
# 4                  PPP                          DAY PITNEY LLP
# ...                ...                                     ...
# 12888              PPS  DENISON PEQUOTSEPOS NATURE CENTER INC.
# 12889              PPP                  GNAZZO FOOD CENTER INC
# 12890              PPS             ALL AROUND CONTRACTING CORP
# 12891              PPS                    WALKING WITH PURPOSE
# 12892              PPS                      WELLNESS HOME CARE
#
#                 BorrowerAddress BorrowerCity BorrowerState  ...  \
# 0                 1 Union Place     Hartford            CT  ...
# 1                 6 RESEARCH DR      SHELTON            CT  ...
# 2      200 First Stamford Place     Stamford            CT  ...
# 3                25 CONTROLS DR      SHELTON            CT  ...
# 4               242 TRUMBULL ST     HARTFORD            CT  ...
# ...                         ...          ...           ...  ...
# 12888        109 Pequotsepos Rd       Mystic            CT  ...
# 12889                73 East St   PLAINVILLE            CT  ...
# 12890            76 Knowlton St   Bridgeport            CT  ...
# 12891           15 E Putnam Ave    Greenwich            CT  ...
# 12892  2304 Berlin Tpke Ste 202    Newington            CT  ...
#
#             TRIIndustrySector  \
# 0                   999 Other
# 1                   999 Other
# 2                   322 Paper
# 3                   999 Other
# 4                   999 Other
# ...                       ...
# 12888               999 Other
# 12889               999 Other
# 12890               999 Other
# 12891  511 512 519 Publishing
# 12892               999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 0                          8129 Other Personal Services       8129.0
# 1                               5613 Employment Services      5613.0
# 2             3222 Converted Paper Product Manufacturing      3222.0
# 3               5617 Services to Buildings and Dwellings      5617.0
# 4                                    5411 Legal Services      5411.0
# ...                                                  ...         ...
# 12888                 6116 Other Schools and Instruction      6116.0
# 12889                               4451 Grocery Stores       4451.0
# 12890  2379 Other Heavy and Civil Engineering Constru...      2379.0
# 12891  5111 Newspaper, Periodical, Book, and Director...      5111.0
# 12892                     6216 Home Health Care Services      6216.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 1      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 2      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 3      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 4      CONNECTICUT DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 12888  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12889  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12890  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12891  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12892  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat       Long  \
# 0                  1 Union Place, Hartford, CT  41.768886 -72.681543
# 1                   6 RESEARCH DR, SHELTON, CT  41.274979 -73.134472
# 2       200 First Stamford Place, Stamford, CT  41.044604 -73.549385
# 3                  25 CONTROLS DR, SHELTON, CT  41.283920 -73.107990
# 4                242 TRUMBULL ST, HARTFORD, CT  41.768035 -72.675077
# ...                                        ...        ...        ...
# 12888           109 Pequotsepos Rd, Mystic, CT  41.362416 -71.946780
# 12889               73 East St, PLAINVILLE, CT  41.669405 -72.861979
# 12890           76 Knowlton St, Bridgeport, CT  41.184879 -73.187417
# 12891           15 E Putnam Ave, Greenwich, CT  41.031819 -73.626677
# 12892  2304 Berlin Tpke Ste 202, Newington, CT  41.689555 -72.705986
#
#                 FIPS_z
# 0      090035021002009
# 1      090011103022004
# 2      090010223003001
# 3      090011102023008
# 4      090035021001038
# ...                ...
# 12888  090117053001004
# 12889  090034205004006
# 12890  090010739003009
# 12891  090010106002002
# 12892  090034944002009
#
# [12893 rows x 72 columns]

# %% [markdown]
# If FIPS Encoded

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
fips_merge_drop

# %%
fips_merge.loc[fips_merge["FIPS_z"].isnull()] #31
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 1457       187081        187081  1004577101       4/9/20            156
# 3075       188699        188699  7637387710       5/1/20            156
# 5247       190871        190871  3539977109      4/11/20            156
# 10902      196526        196526  4931747305      4/30/20            156
#
#       ProcessingMethod                   BorrowerName  \
# 1457               PPP   VISION FINANCIAL MARKETS LLC
# 3075               PPP          PIONEER EDUCATION LLC
# 5247               PPP                  EM BENSON LLC
# 10902              PPP  ELANUS CAPITAL MANAGEMENT LLC
#
#                            BorrowerAddress  BorrowerCity BorrowerState  ...  \
# 1457         120 Long Ridge Road   3 North      STAMFORD            CT  ...
# 3075                           5200 Rte 42  Turnersville            CT  ...
# 5247   1486 highland ave building 2 unit 1      CHESHIRE            CT  ...
# 10902                    180 Varick Street     SALISBURY            CT  ...
#
#                    TRIIndustrySector  \
# 1457                       999 Other
# 3075                       999 Other
# 5247   332 Fabricated Metal Products
# 10902                      999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 1457   5231 Securities and Commodity Contracts Interm...      5231.0
# 3075                  6116 Other Schools and Instruction      6116.0
# 5247   3329 Other Fabricated Metal Product Manufacturing      3329.0
# 10902         5239 Other Financial Investment Activities      5239.0
#
#                     SBAOfficeLabel            Loan_Range  job_Range  \
# 1457   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   50 to 99
# 3075   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   20 to 49
# 5247   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   10 to 19
# 10902  CONNECTICUT DISTRICT OFFICE    a $150,000-350,000     5 to 9
#
#                                                 full_add        Lat  \
# 1457         120 Long Ridge Road   3 North, STAMFORD, CT  41.195893
# 3075                       5200 Rte 42, Turnersville, CT  39.765211
# 5247   1486 highland ave building 2 unit 1, CHESHIRE, CT        NaN
# 10902                   180 Varick Street, SALISBURY, CT  40.727398
#
#             Long  FIPS_z
# 1457  -73.620851     NaN
# 3075  -75.048383     NaN
# 5247         NaN     NaN
# 10902 -74.005178     NaN
#
# [4 rows x 72 columns]

# %%
geo_CT_fips = fips_merge

# %% [markdown]
# Convert to File

# %%
geo_CT_fips.to_csv("data/state_data/geo/geo_fips/CT_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_CT_fips = pd.read_csv("data/state_data/geo/geo_fips/CT_fips_scraped.csv") 
geo_CT_fips
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0               0        185624          185624  3903327306      4/29/20
# 1               1        185625          185625  4505207402       5/9/20
# 2               2        185626          185626  5539227705       5/1/20
# 3               3        185627          185627  5630057006       4/6/20
# 4               4        185628          185628  8388727000       4/8/20
# ...           ...           ...             ...         ...          ...
# 12888       12888        198512          198512  9618168507      3/12/21
# 12889       12889        198513          198513  9648837000       4/9/20
# 12890       12890        198514          198514  9763078402      2/17/21
# 12891       12891        198515          198515  9854708505      3/12/21
# 12892       12892        198516          198516  9988368505      3/12/21
#
#        SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0                156              PPP                             PROPARK INC
# 1                156              PPP            MONROE STAFFING SERVICES LLC
# 2                156              PPP                CENVEO WORLDWIDE LIMITED
# 3                156              PPP                SERVICE MANAGEMENT GROUP
# 4                156              PPP                          DAY PITNEY LLP
# ...              ...              ...                                     ...
# 12888            156              PPS  DENISON PEQUOTSEPOS NATURE CENTER INC.
# 12889            156              PPP                  GNAZZO FOOD CENTER INC
# 12890            156              PPS             ALL AROUND CONTRACTING CORP
# 12891            156              PPS                    WALKING WITH PURPOSE
# 12892            156              PPS                      WELLNESS HOME CARE
#
#                 BorrowerAddress BorrowerCity  ...       TRIIndustrySector  \
# 0                 1 Union Place     Hartford  ...               999 Other
# 1                 6 RESEARCH DR      SHELTON  ...               999 Other
# 2      200 First Stamford Place     Stamford  ...               322 Paper
# 3                25 CONTROLS DR      SHELTON  ...               999 Other
# 4               242 TRUMBULL ST     HARTFORD  ...               999 Other
# ...                         ...          ...  ...                     ...
# 12888        109 Pequotsepos Rd       Mystic  ...               999 Other
# 12889                73 East St   PLAINVILLE  ...               999 Other
# 12890            76 Knowlton St   Bridgeport  ...               999 Other
# 12891           15 E Putnam Ave    Greenwich  ...  511 512 519 Publishing
# 12892  2304 Berlin Tpke Ste 202    Newington  ...               999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 0                          8129 Other Personal Services       8129.0
# 1                               5613 Employment Services      5613.0
# 2             3222 Converted Paper Product Manufacturing      3222.0
# 3               5617 Services to Buildings and Dwellings      5617.0
# 4                                    5411 Legal Services      5411.0
# ...                                                  ...         ...
# 12888                 6116 Other Schools and Instruction      6116.0
# 12889                               4451 Grocery Stores       4451.0
# 12890  2379 Other Heavy and Civil Engineering Constru...      2379.0
# 12891  5111 Newspaper, Periodical, Book, and Director...      5111.0
# 12892                     6216 Home Health Care Services      6216.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 1      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 2      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 3      CONNECTICUT DISTRICT OFFICE     e $5-10 million  500 or more
# 4      CONNECTICUT DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 12888  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12889  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12890  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12891  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 12892  CONNECTICUT DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat       Long  \
# 0                  1 Union Place, Hartford, CT  41.768886 -72.681543
# 1                   6 RESEARCH DR, SHELTON, CT  41.274979 -73.134472
# 2       200 First Stamford Place, Stamford, CT  41.044604 -73.549385
# 3                  25 CONTROLS DR, SHELTON, CT  41.283920 -73.107990
# 4                242 TRUMBULL ST, HARTFORD, CT  41.768035 -72.675077
# ...                                        ...        ...        ...
# 12888           109 Pequotsepos Rd, Mystic, CT  41.362416 -71.946780
# 12889               73 East St, PLAINVILLE, CT  41.669405 -72.861979
# 12890           76 Knowlton St, Bridgeport, CT  41.184879 -73.187417
# 12891           15 E Putnam Ave, Greenwich, CT  41.031819 -73.626677
# 12892  2304 Berlin Tpke Ste 202, Newington, CT  41.689555 -72.705986
#
#              FIPS_z
# 0      9.003502e+13
# 1      9.001110e+13
# 2      9.001022e+13
# 3      9.001110e+13
# 4      9.003502e+13
# ...             ...
# 12888  9.011705e+13
# 12889  9.003421e+13
# 12890  9.001074e+13
# 12891  9.001011e+13
# 12892  9.003494e+13
#
# [12893 rows x 73 columns]

# %%
#fill in missing Lat, Long, FIPS
geo_CT_fips.loc[geo_CT_fips["FIPS_z"].isnull()] #1241
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 1457         1457        187081          187081  1004577101       4/9/20
# 3075         3075        188699          188699  7637387710       5/1/20
# 5247         5247        190871          190871  3539977109      4/11/20
# 10902       10902        196526          196526  4931747305      4/30/20
#
#        SBAOfficeCode ProcessingMethod                   BorrowerName  \
# 1457             156              PPP   VISION FINANCIAL MARKETS LLC
# 3075             156              PPP          PIONEER EDUCATION LLC
# 5247             156              PPP                  EM BENSON LLC
# 10902            156              PPP  ELANUS CAPITAL MANAGEMENT LLC
#
#                            BorrowerAddress  BorrowerCity  ...  \
# 1457         120 Long Ridge Road   3 North      STAMFORD  ...
# 3075                           5200 Rte 42  Turnersville  ...
# 5247   1486 highland ave building 2 unit 1      CHESHIRE  ...
# 10902                    180 Varick Street     SALISBURY  ...
#
#                    TRIIndustrySector  \
# 1457                       999 Other
# 3075                       999 Other
# 5247   332 Fabricated Metal Products
# 10902                      999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 1457   5231 Securities and Commodity Contracts Interm...      5231.0
# 3075                  6116 Other Schools and Instruction      6116.0
# 5247   3329 Other Fabricated Metal Product Manufacturing      3329.0
# 10902         5239 Other Financial Investment Activities      5239.0
#
#                     SBAOfficeLabel            Loan_Range  job_Range  \
# 1457   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   50 to 99
# 3075   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   20 to 49
# 5247   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   10 to 19
# 10902  CONNECTICUT DISTRICT OFFICE    a $150,000-350,000     5 to 9
#
#                                                 full_add        Lat  \
# 1457         120 Long Ridge Road   3 North, STAMFORD, CT  41.195893
# 3075                       5200 Rte 42, Turnersville, CT  39.765211
# 5247   1486 highland ave building 2 unit 1, CHESHIRE, CT        NaN
# 10902                   180 Varick Street, SALISBURY, CT  40.727398
#
#             Long FIPS_z
# 1457  -73.620851    NaN
# 3075  -75.048383    NaN
# 5247         NaN    NaN
# 10902 -74.005178    NaN
#
# [4 rows x 73 columns]
