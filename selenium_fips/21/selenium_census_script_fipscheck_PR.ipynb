# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as BraveService
from webdriver_manager.core.utils import ChromeType
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_pr.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check
# Out:
#       Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0         774589  1724057303      4/28/20            252              PPP
# 1         774590  3828657103      4/12/20            252              PPP
# 2         774591  4150097210      4/27/20            252              PPP
# 3         774592  5502967210      4/27/20            252              PPP
# 4         774593  7953047007       4/8/20            252              PPP
# ...          ...         ...          ...            ...              ...
# 2947      777536  6288858603      3/23/21            252              PPS
# 2948      777537  8218768310      1/29/21            252              PPS
# 2949      777538  9097578505      3/12/21            252              PPP
# 2950      777539  9110348403      2/16/21            252              PPS
# 2951      777540  9394737701       5/1/20            252              PPP
#
#                            BorrowerName  \
# 0      CARIBBEAN TEMPORARY SERVICES LLC
# 1      SOUTH AMERICAN RESTAURANTS CORP.
# 2       GENESIS SECURITY SERVICES, INC.
# 3         CENTRO MEDICO DEL TURABO INC.
# 4             CARIBBEAN RESTAURANTS LLC
# ...                                 ...
# 2947                        GLADIUS LLC
# 2948       LABORATORIO CLINICO VAN SCOY
# 2949  PERSONNEL RECRUITING SERVICE CORP
# 2950                       PANUCHO INC.
# 2951                    MP ELEVATOR INC
#
#                                         BorrowerAddress BorrowerCity  \
# 0                          PONCE DE LEON 1431 SUITE 701     SANTURCE
# 1                   35 Diana St, Amelia Industrial Park     GUAYNABO
# 2                           5900 AVE. ISLA VERDE L2 PMB     CAROLINA
# 3                             100 AVE. LUIS MUNOZ MARIN       CAGUAS
# 4                        5 Carr Km 6 Hm 2 Barrio Amelia     GUAYNABO
# ...                                                 ...          ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...     San Juan
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...      Bayamon
# 2949        1244 Ave Munoz Rivera Reparto Universitario        Ponce
# 2950               1762 Calle Loiza Esq. Diez de Andino     San Juan
# 2951               EXT FOREST HILLS  E46 CALLE MARGINAL      BAYAMON
#
#      BorrowerState  BorrowerZip  ... TRIIndustrySector  \
# 0               PR        907.0  ...         999 Other
# 1               PR        969.0  ...         999 Other
# 2               PR        979.0  ...         999 Other
# 3               PR        725.0  ...         999 Other
# 4               PR        968.0  ...         999 Other
# ...            ...          ...  ...               ...
# 2947            PR        926.0  ...         999 Other
# 2948            PR        957.0  ...         999 Other
# 2949            PR        717.0  ...         999 Other
# 2950            PR        914.0  ...         999 Other
# 2951            PR        959.0  ...         999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0                              5613 Employment Services       5613.0
# 1              7225 Restaurants and Other Eating Places       7225.0
# 2              5616 Investigation and Security Services       5616.0
# 3           6221 General Medical and Surgical Hospitals       6221.0
# 4              7225 Restaurants and Other Eating Places       7225.0
# ...                                                 ...          ...
# 2947                   5414 Specialized Design Services       5414.0
# 2948           6215 Medical and Diagnostic Laboratories       6215.0
# 2949                           5613 Employment Services       5613.0
# 2950           7225 Restaurants and Other Eating Places       7225.0
# 2951  4238 Machinery, Equipment, and Supplies Mercha...       4238.0
#
#                             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 1     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 2     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 3     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 4     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# ...                                    ...                 ...          ...
# 2947  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2948  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2949  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000  500 or more
# 2950  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2951  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                                full_add        Lat       Long  \
# 0            PONCE DE LEON 1431 SUITE 701, SANTURCE, PR  18.388480 -66.062466
# 1     35 Diana St, Amelia Industrial Park, GUAYNABO, PR  18.416696 -66.118672
# 2             5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR  18.443043 -66.025696
# 3                 100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR  18.217878 -66.030109
# 4          5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR  18.419611 -66.114715
# ...                                                 ...        ...        ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...  18.357168 -66.062152
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...  18.315721 -66.203868
# 2949  1244 Ave Munoz Rivera Reparto Universitario, P...  18.000550 -66.620863
# 2950  1762 Calle Loiza Esq. Diez de Andino, San Juan...  18.451450 -66.059777
# 2951  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR  18.383183 -66.161705
#
#      FIPS_z
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 2947    NaN
# 2948    NaN
# 2949    NaN
# 2950    NaN
# 2951    NaN
#
# [2952 rows x 71 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan #3
# Out:
#       LoanNumber                          full_add  Lat  Long
# 84    6466228606  Carr. 5506 KM 1.8, Mercedita, PR  NaN   NaN
# 2862  1670129002  Carr. #1 KM 122.4, MERCEDITA, PR  NaN   NaN

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #15866
# Out:
#    LoanNumber                                           full_add        Lat  \
# 0  1724057303         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR  18.388480
# 1  3828657103  35 Diana St, Amelia Industrial Park, GUAYNABO, PR  18.416696
# 2  4150097210          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR  18.443043
# 3  5502967210              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR  18.217878
# 4  7953047007       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR  18.419611
#
#         Long
# 0 -66.062466
# 1 -66.118672
# 2 -66.025696
# 3 -66.030109
# 4 -66.114715

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
fips_check_scraped.head() #15869

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #15866

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #5503

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
#driver = webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))
#executable_path = {'executable_path': webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))}
executable_path = {'executable_path': ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()}
option = webdriver.ChromeOptions()
option.binary_location = "/Applications/Brave Browser.app/Contents/MacOS/Brave Browser"
driver = Browser('chrome', **executable_path, options=option, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('geoCoordX').clear()
        driver.find_by_id('geoCoordY').clear()
        driver.find_by_id('geoCoordX').fill(long[i])
        driver.find_by_id('geoCoordY').fill(lat[i])
        driver.find_by_id('geoCoordsSubmit').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='geoCoordsJsonOutput')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('72')] #PR
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                #print(f"{i},{lat[i]},{long[i]} Not Found")
                not_found.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
#   0%|          | 0/2950 [00:00<?, ?it/s]

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 2950

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:25062]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       LoanNumber                                           full_add  \
# 0     1724057303         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR
# 1     3828657103  35 Diana St, Amelia Industrial Park, GUAYNABO, PR
# 2     4150097210          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR
# 3     5502967210              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR
# 4     7953047007       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR
# ...          ...                                                ...
# 2947  6288858603  300 Ave Rincon de Gautier Las Vistas Shopping ...
# 2948  8218768310  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...
# 2949  9097578505  1244 Ave Munoz Rivera Reparto Universitario, P...
# 2950  9110348403  1762 Calle Loiza Esq. Diez de Andino, San Juan...
# 2951  9394737701  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR
#
#             Lat       Long             FIPS_z
# 0     18.388480 -66.062466  [721270096012001]
# 1     18.416696 -66.118672  [720610402001013]
# 2     18.443043 -66.025696  [720310501131002]
# 3     18.217878 -66.030109  [720252018001004]
# 4     18.419611 -66.114715  [720610402001013]
# ...         ...        ...                ...
# 2947  18.357168 -66.062152  [721270100022014]
# 2948  18.315721 -66.203868  [720210322002004]
# 2949  18.000550 -66.620863  [721130715003007]
# 2950  18.451450 -66.059777  [721270015002000]
# 2951  18.383183 -66.161705  [720210315032012]
#
# [2950 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       LoanNumber                                           full_add  \
# 0     1724057303         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR
# 1     3828657103  35 Diana St, Amelia Industrial Park, GUAYNABO, PR
# 2     4150097210          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR
# 3     5502967210              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR
# 4     7953047007       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR
# ...          ...                                                ...
# 2947  6288858603  300 Ave Rincon de Gautier Las Vistas Shopping ...
# 2948  8218768310  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...
# 2949  9097578505  1244 Ave Munoz Rivera Reparto Universitario, P...
# 2950  9110348403  1762 Calle Loiza Esq. Diez de Andino, San Juan...
# 2951  9394737701  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR
#
#             Lat       Long           FIPS_z
# 0     18.388480 -66.062466  721270096012001
# 1     18.416696 -66.118672  720610402001013
# 2     18.443043 -66.025696  720310501131002
# 3     18.217878 -66.030109  720252018001004
# 4     18.419611 -66.114715  720610402001013
# ...         ...        ...              ...
# 2947  18.357168 -66.062152  721270100022014
# 2948  18.315721 -66.203868  720210322002004
# 2949  18.000550 -66.620863  721130715003007
# 2950  18.451450 -66.059777  721270015002000
# 2951  18.383183 -66.161705  720210315032012
#
# [2950 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check #24
# Out:
#       LoanNumber                                           full_add  \
# 111   2954357201  URB INDUSTRIAL SABANETA CALLE HUCAR EDIFICIO M...
# 351   2942887210  URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...
# 672   9390667707         1402 N CORINTH ST RD SUITE 113, DAllas, PR
# 1052  6116877007        Urb. Parkville # 1 Mejico St., GUAYNABO, PR
# 1363  3391277310  CARRETERA 108 INTERIOR KM 3.2 BO CUBA, MAYAGUE...
# 1654  9603427100    Frances 39 Amelia Industrial Park, GUAYNABO, PR
# 1665  2372087203  4ta sec levittown , Centro Comercial Lago Vist...
# 1777  9332887705      1 Northfield Plaza, Suite 300, Northfield, PR
# 1799  2760167303                     167 Paris Street, Hato Rey, PR
# 1829  3178908600  CALLE R LOTE 4 EL COMANDANTE IND PARK, CAROLIN...
# 2178  7499078403  Cabo Caribe Ind Park Calle A lote 23, Vega Baj...
# 2280  9455907709  URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...
# 2309  3068298508  Caguas Norte Ind. Park Lote 12 Calle Desperak ...
# 2680  9343657701  SANTURCE CALLE SAGRADO CORAZON ESQ LOS ANGELES...
# 2888  2196488604              ROAD 869 BO PALMAS BLDG H, PALMAS, PR
#
#             Lat        Long FIPS_z
# 111    6.150486  -75.616879    NaN
# 351    6.150486  -75.616879    NaN
# 672   32.772884  -96.779098    NaN
# 1052  23.634501 -102.552784    NaN
# 1363  21.521757  -77.781167    NaN
# 1654  46.227638    2.213749    NaN
# 1665  30.460197  -97.988348    NaN
# 1777  42.107711  -87.773691    NaN
# 1799  48.856614    2.352222    NaN
# 1829  20.593684   78.962880    NaN
# 2178  20.593684   78.962880    NaN
# 2280   6.150486  -75.616879    NaN
# 2309  20.593684   78.962880    NaN
# 2680  34.052234 -118.243685    NaN
# 2888 -26.478873  -51.995789    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#       LoanNumber           FIPS_z
# 0     1724057303  721270096012001
# 1     3828657103  720610402001013
# 2     4150097210  720310501131002
# 3     5502967210  720252018001004
# 4     7953047007  720610402001013
# ...          ...              ...
# 2947  6288858603  721270100022014
# 2948  8218768310  720210322002004
# 2949  9097578505  721130715003007
# 2950  9110348403  721270015002000
# 2951  9394737701  720210315032012
#
# [2950 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_pr.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check.head()

#if from FIPS file
#fips_check = pd.read_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #22826
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0      774589        774589          774589  1724057303      4/28/20
# 1      774590        774590          774590  3828657103      4/12/20
# 2      774591        774591          774591  4150097210      4/27/20
# 3      774592        774592          774592  5502967210      4/27/20
# 4      774593        774593          774593  7953047007       4/8/20
#
#    SBAOfficeCode ProcessingMethod                      BorrowerName  \
# 0            252              PPP  CARIBBEAN TEMPORARY SERVICES LLC
# 1            252              PPP  SOUTH AMERICAN RESTAURANTS CORP.
# 2            252              PPP   GENESIS SECURITY SERVICES, INC.
# 3            252              PPP     CENTRO MEDICO DEL TURABO INC.
# 4            252              PPP         CARIBBEAN RESTAURANTS LLC
#
#                        BorrowerAddress BorrowerCity  ... TRIIndustrySector  \
# 0         PONCE DE LEON 1431 SUITE 701     SANTURCE  ...         999 Other
# 1  35 Diana St, Amelia Industrial Park     GUAYNABO  ...         999 Other
# 2          5900 AVE. ISLA VERDE L2 PMB     CAROLINA  ...         999 Other
# 3            100 AVE. LUIS MUNOZ MARIN       CAGUAS  ...         999 Other
# 4       5 Carr Km 6 Hm 2 Barrio Amelia     GUAYNABO  ...         999 Other
#
#                              IndustrySubsector 4DigitNAICS  \
# 0                     5613 Employment Services      5613.0
# 1     7225 Restaurants and Other Eating Places      7225.0
# 2     5616 Investigation and Security Services      5616.0
# 3  6221 General Medical and Surgical Hospitals      6221.0
# 4     7225 Restaurants and Other Eating Places      7225.0
#
#                          SBAOfficeLabel       Loan_Range    job_Range  \
# 0  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 1  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 2  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 3  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 4  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                             full_add        Lat       Long  \
# 0         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR  18.388480 -66.062466
# 1  35 Diana St, Amelia Industrial Park, GUAYNABO, PR  18.416696 -66.118672
# 2          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR  18.443043 -66.025696
# 3              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR  18.217878 -66.030109
# 4       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR  18.419611 -66.114715
#
#   FIPS_z
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         774589        774589          774589  1724057303      4/28/20
# 1         774590        774590          774590  3828657103      4/12/20
# 2         774591        774591          774591  4150097210      4/27/20
# 3         774592        774592          774592  5502967210      4/27/20
# 4         774593        774593          774593  7953047007       4/8/20
# ...          ...           ...             ...         ...          ...
# 2947      777536        777536          777536  6288858603      3/23/21
# 2948      777537        777537          777537  8218768310      1/29/21
# 2949      777538        777538          777538  9097578505      3/12/21
# 2950      777539        777539          777539  9110348403      2/16/21
# 2951      777540        777540          777540  9394737701       5/1/20
#
#       SBAOfficeCode ProcessingMethod                       BorrowerName  \
# 0               252              PPP   CARIBBEAN TEMPORARY SERVICES LLC
# 1               252              PPP   SOUTH AMERICAN RESTAURANTS CORP.
# 2               252              PPP    GENESIS SECURITY SERVICES, INC.
# 3               252              PPP      CENTRO MEDICO DEL TURABO INC.
# 4               252              PPP          CARIBBEAN RESTAURANTS LLC
# ...             ...              ...                                ...
# 2947            252              PPS                        GLADIUS LLC
# 2948            252              PPS       LABORATORIO CLINICO VAN SCOY
# 2949            252              PPP  PERSONNEL RECRUITING SERVICE CORP
# 2950            252              PPS                       PANUCHO INC.
# 2951            252              PPP                    MP ELEVATOR INC
#
#                                         BorrowerAddress BorrowerCity  ...  \
# 0                          PONCE DE LEON 1431 SUITE 701     SANTURCE  ...
# 1                   35 Diana St, Amelia Industrial Park     GUAYNABO  ...
# 2                           5900 AVE. ISLA VERDE L2 PMB     CAROLINA  ...
# 3                             100 AVE. LUIS MUNOZ MARIN       CAGUAS  ...
# 4                        5 Carr Km 6 Hm 2 Barrio Amelia     GUAYNABO  ...
# ...                                                 ...          ...  ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...     San Juan  ...
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...      Bayamon  ...
# 2949        1244 Ave Munoz Rivera Reparto Universitario        Ponce  ...
# 2950               1762 Calle Loiza Esq. Diez de Andino     San Juan  ...
# 2951               EXT FOREST HILLS  E46 CALLE MARGINAL      BAYAMON  ...
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0                              5613 Employment Services       5613.0
# 1              7225 Restaurants and Other Eating Places       7225.0
# 2              5616 Investigation and Security Services       5616.0
# 3           6221 General Medical and Surgical Hospitals       6221.0
# 4              7225 Restaurants and Other Eating Places       7225.0
# ...                                                 ...          ...
# 2947                   5414 Specialized Design Services       5414.0
# 2948           6215 Medical and Diagnostic Laboratories       6215.0
# 2949                           5613 Employment Services       5613.0
# 2950           7225 Restaurants and Other Eating Places       7225.0
# 2951  4238 Machinery, Equipment, and Supplies Mercha...       4238.0
#
#                             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 1     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 2     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 3     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# 4     PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million  500 or more
# ...                                    ...                 ...          ...
# 2947  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2948  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2949  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000  500 or more
# 2950  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2951  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                                full_add        Lat       Long  \
# 0            PONCE DE LEON 1431 SUITE 701, SANTURCE, PR  18.388480 -66.062466
# 1     35 Diana St, Amelia Industrial Park, GUAYNABO, PR  18.416696 -66.118672
# 2             5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR  18.443043 -66.025696
# 3                 100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR  18.217878 -66.030109
# 4          5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR  18.419611 -66.114715
# ...                                                 ...        ...        ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...  18.357168 -66.062152
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...  18.315721 -66.203868
# 2949  1244 Ave Munoz Rivera Reparto Universitario, P...  18.000550 -66.620863
# 2950  1762 Calle Loiza Esq. Diez de Andino, San Juan...  18.451450 -66.059777
# 2951  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR  18.383183 -66.161705
#
#       FIPS_z_x         FIPS_z_y
# 0          NaN  721270096012001
# 1          NaN  720610402001013
# 2          NaN  720310501131002
# 3          NaN  720252018001004
# 4          NaN  720610402001013
# ...        ...              ...
# 2947       NaN  721270100022014
# 2948       NaN  720210322002004
# 2949       NaN  721130715003007
# 2950       NaN  721270015002000
# 2951       NaN  720210315032012
#
# [2952 rows x 74 columns]

# %% [markdown]
# <b>Fill FIPS Columns - if FIPS file

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         774589        774589          774589  1724057303      4/28/20
# 1         774590        774590          774590  3828657103      4/12/20
# 2         774591        774591          774591  4150097210      4/27/20
# 3         774592        774592          774592  5502967210      4/27/20
# 4         774593        774593          774593  7953047007       4/8/20
# ...          ...           ...             ...         ...          ...
# 2947      777536        777536          777536  6288858603      3/23/21
# 2948      777537        777537          777537  8218768310      1/29/21
# 2949      777538        777538          777538  9097578505      3/12/21
# 2950      777539        777539          777539  9110348403      2/16/21
# 2951      777540        777540          777540  9394737701       5/1/20
#
#       SBAOfficeCode ProcessingMethod                       BorrowerName  \
# 0               252              PPP   CARIBBEAN TEMPORARY SERVICES LLC
# 1               252              PPP   SOUTH AMERICAN RESTAURANTS CORP.
# 2               252              PPP    GENESIS SECURITY SERVICES, INC.
# 3               252              PPP      CENTRO MEDICO DEL TURABO INC.
# 4               252              PPP          CARIBBEAN RESTAURANTS LLC
# ...             ...              ...                                ...
# 2947            252              PPS                        GLADIUS LLC
# 2948            252              PPS       LABORATORIO CLINICO VAN SCOY
# 2949            252              PPP  PERSONNEL RECRUITING SERVICE CORP
# 2950            252              PPS                       PANUCHO INC.
# 2951            252              PPP                    MP ELEVATOR INC
#
#                                         BorrowerAddress BorrowerCity  ...  \
# 0                          PONCE DE LEON 1431 SUITE 701     SANTURCE  ...
# 1                   35 Diana St, Amelia Industrial Park     GUAYNABO  ...
# 2                           5900 AVE. ISLA VERDE L2 PMB     CAROLINA  ...
# 3                             100 AVE. LUIS MUNOZ MARIN       CAGUAS  ...
# 4                        5 Carr Km 6 Hm 2 Barrio Amelia     GUAYNABO  ...
# ...                                                 ...          ...  ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...     San Juan  ...
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...      Bayamon  ...
# 2949        1244 Ave Munoz Rivera Reparto Universitario        Ponce  ...
# 2950               1762 Calle Loiza Esq. Diez de Andino     San Juan  ...
# 2951               EXT FOREST HILLS  E46 CALLE MARGINAL      BAYAMON  ...
#
#      4DigitNAICS                        SBAOfficeLabel          Loan_Range  \
# 0         5613.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 1         7225.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 2         5616.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 3         6221.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 4         7225.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# ...          ...                                   ...                 ...
# 2947      5414.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2948      6215.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2949      5613.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2950      7225.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2951      4238.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
#
#         job_Range                                           full_add  \
# 0     500 or more         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR
# 1     500 or more  35 Diana St, Amelia Industrial Park, GUAYNABO, PR
# 2     500 or more          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR
# 3     500 or more              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR
# 4     500 or more       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR
# ...           ...                                                ...
# 2947     20 to 49  300 Ave Rincon de Gautier Las Vistas Shopping ...
# 2948     10 to 19  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...
# 2949  500 or more  1244 Ave Munoz Rivera Reparto Universitario, P...
# 2950     10 to 19  1762 Calle Loiza Esq. Diez de Andino, San Juan...
# 2951     10 to 19  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR
#
#             Lat       Long  FIPS_z_x         FIPS_z_y           FIPS_z
# 0     18.388480 -66.062466       NaN  721270096012001  721270096012001
# 1     18.416696 -66.118672       NaN  720610402001013  720610402001013
# 2     18.443043 -66.025696       NaN  720310501131002  720310501131002
# 3     18.217878 -66.030109       NaN  720252018001004  720252018001004
# 4     18.419611 -66.114715       NaN  720610402001013  720610402001013
# ...         ...        ...       ...              ...              ...
# 2947  18.357168 -66.062152       NaN  721270100022014  721270100022014
# 2948  18.315721 -66.203868       NaN  720210322002004  720210322002004
# 2949  18.000550 -66.620863       NaN  721130715003007  721130715003007
# 2950  18.451450 -66.059777       NaN  721270015002000  721270015002000
# 2951  18.383183 -66.161705       NaN  720210315032012  720210315032012
#
# [2952 rows x 75 columns]

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
#fips_merge_drop = fips_merge_drop.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         774589        774589          774589  1724057303      4/28/20
# 1         774590        774590          774590  3828657103      4/12/20
# 2         774591        774591          774591  4150097210      4/27/20
# 3         774592        774592          774592  5502967210      4/27/20
# 4         774593        774593          774593  7953047007       4/8/20
# ...          ...           ...             ...         ...          ...
# 2947      777536        777536          777536  6288858603      3/23/21
# 2948      777537        777537          777537  8218768310      1/29/21
# 2949      777538        777538          777538  9097578505      3/12/21
# 2950      777539        777539          777539  9110348403      2/16/21
# 2951      777540        777540          777540  9394737701       5/1/20
#
#       SBAOfficeCode ProcessingMethod                       BorrowerName  \
# 0               252              PPP   CARIBBEAN TEMPORARY SERVICES LLC
# 1               252              PPP   SOUTH AMERICAN RESTAURANTS CORP.
# 2               252              PPP    GENESIS SECURITY SERVICES, INC.
# 3               252              PPP      CENTRO MEDICO DEL TURABO INC.
# 4               252              PPP          CARIBBEAN RESTAURANTS LLC
# ...             ...              ...                                ...
# 2947            252              PPS                        GLADIUS LLC
# 2948            252              PPS       LABORATORIO CLINICO VAN SCOY
# 2949            252              PPP  PERSONNEL RECRUITING SERVICE CORP
# 2950            252              PPS                       PANUCHO INC.
# 2951            252              PPP                    MP ELEVATOR INC
#
#                                         BorrowerAddress BorrowerCity  ...  \
# 0                          PONCE DE LEON 1431 SUITE 701     SANTURCE  ...
# 1                   35 Diana St, Amelia Industrial Park     GUAYNABO  ...
# 2                           5900 AVE. ISLA VERDE L2 PMB     CAROLINA  ...
# 3                             100 AVE. LUIS MUNOZ MARIN       CAGUAS  ...
# 4                        5 Carr Km 6 Hm 2 Barrio Amelia     GUAYNABO  ...
# ...                                                 ...          ...  ...
# 2947  300 Ave Rincon de Gautier Las Vistas Shopping ...     San Juan  ...
# 2948  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...      Bayamon  ...
# 2949        1244 Ave Munoz Rivera Reparto Universitario        Ponce  ...
# 2950               1762 Calle Loiza Esq. Diez de Andino     San Juan  ...
# 2951               EXT FOREST HILLS  E46 CALLE MARGINAL      BAYAMON  ...
#
#      TRIIndustrySector                                  IndustrySubsector  \
# 0            999 Other                           5613 Employment Services
# 1            999 Other           7225 Restaurants and Other Eating Places
# 2            999 Other           5616 Investigation and Security Services
# 3            999 Other        6221 General Medical and Surgical Hospitals
# 4            999 Other           7225 Restaurants and Other Eating Places
# ...                ...                                                ...
# 2947         999 Other                   5414 Specialized Design Services
# 2948         999 Other           6215 Medical and Diagnostic Laboratories
# 2949         999 Other                           5613 Employment Services
# 2950         999 Other           7225 Restaurants and Other Eating Places
# 2951         999 Other  4238 Machinery, Equipment, and Supplies Mercha...
#
#      4DigitNAICS                        SBAOfficeLabel          Loan_Range  \
# 0         5613.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 1         7225.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 2         5616.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 3         6221.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# 4         7225.0  PUERTO RICO AND USVI DISTRICT OFFICE     e $5-10 million
# ...          ...                                   ...                 ...
# 2947      5414.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2948      6215.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2949      5613.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2950      7225.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
# 2951      4238.0  PUERTO RICO AND USVI DISTRICT OFFICE  a $150,000-350,000
#
#         job_Range                                           full_add  \
# 0     500 or more         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR
# 1     500 or more  35 Diana St, Amelia Industrial Park, GUAYNABO, PR
# 2     500 or more          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR
# 3     500 or more              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR
# 4     500 or more       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR
# ...           ...                                                ...
# 2947     20 to 49  300 Ave Rincon de Gautier Las Vistas Shopping ...
# 2948     10 to 19  Barrio Buena Vista Parcelas VA Carr. 167 Ramal...
# 2949  500 or more  1244 Ave Munoz Rivera Reparto Universitario, P...
# 2950     10 to 19  1762 Calle Loiza Esq. Diez de Andino, San Juan...
# 2951     10 to 19  EXT FOREST HILLS  E46 CALLE MARGINAL, BAYAMON, PR
#
#             Lat       Long           FIPS_z
# 0     18.388480 -66.062466  721270096012001
# 1     18.416696 -66.118672  720610402001013
# 2     18.443043 -66.025696  720310501131002
# 3     18.217878 -66.030109  720252018001004
# 4     18.419611 -66.114715  720610402001013
# ...         ...        ...              ...
# 2947  18.357168 -66.062152  721270100022014
# 2948  18.315721 -66.203868  720210322002004
# 2949  18.000550 -66.620863  721130715003007
# 2950  18.451450 -66.059777  721270015002000
# 2951  18.383183 -66.161705  720210315032012
#
# [2952 rows x 73 columns]

# %%
#fips_merge_drop = fips_merge.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop.loc[fips_merge["FIPS_z"].isnull()] #verify #27 , notna #22799 / 22826
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 84        774673        774673          774673  6466228606      3/23/21
# 111       774700        774700          774700  2954357201      4/16/20
# 351       774940        774940          774940  2942887210      4/16/20
# 672       775261        775261          775261  9390667707       5/1/20
# 1052      775641        775641          775641  6116877007       4/6/20
# 1363      775952        775952          775952  3391277310      4/29/20
# 1654      776243        776243          776243  9603427100      4/15/20
# 1665      776254        776254          776254  2372087203      4/16/20
# 1777      776366        776366          776366  9332887705       5/1/20
# 1799      776388        776388          776388  2760167303      4/29/20
# 1829      776418        776418          776418  3178908600      3/16/21
# 2178      776767        776767          776767  7499078403      2/12/21
# 2280      776869        776869          776869  9455907709       5/1/20
# 2309      776898        776898          776898  3068298508      2/22/21
# 2680      777269        777269          777269  9343657701       5/1/20
# 2862      777451        777451          777451  1670129002      5/13/21
# 2888      777477        777477          777477  2196488604      3/13/21
#
#       SBAOfficeCode ProcessingMethod  \
# 84              252              PPS
# 111             252              PPP
# 351             252              PPP
# 672             252              PPP
# 1052            252              PPP
# 1363            252              PPP
# 1654            252              PPP
# 1665            252              PPP
# 1777            252              PPP
# 1799            252              PPP
# 1829            252              PPS
# 2178            252              PPS
# 2280            252              PPP
# 2309            252              PPS
# 2680            252              PPP
# 2862            252              PPS
# 2888            252              PPS
#
#                                            BorrowerName  \
# 84                                 SERRALLES HOTEL INC.
# 111                     PRIME JANITORIAL SERVICES, CORP
# 351                PRIME JANITORIAL METRO & HEALTH, INC
# 672      GENCO GENERAL CONTRACTORS OF PUERTO RICO CORP.
# 1052                             PARKVILLE ELDERLY HOME
# 1363  SOUTH WESTERN EDUCATION SOCIETY (SESO) SOCIEDA...
# 1654                         VENTURE DISTRIBUTORS CORP.
# 1665                          QUINONES SELF SERVICE LLC
# 1777                                     SIMPLEMENT INC
# 1799               COLEGIO CONGREGACIN MITA INCORPORADO
# 1829                  HI TEC BRAKE MANUFACTURING CO INC
# 2178                                          VRJT INC.
# 2280                          PRIME HEALTH SERVICES INC
# 2309                             PCTM CONSTRUCTION CORP
# 2680  YMCA DE SAN JUAN (THE YOUNG MEN'S CHRISTIAN AS...
# 2862                                   SEPTIX WASTE INC
# 2888                                          TSFPR LLC
#
#                                         BorrowerAddress BorrowerCity  ...  \
# 84                                    Carr. 5506 KM 1.8    Mercedita  ...
# 111     URB INDUSTRIAL SABANETA CALLE HUCAR EDIFICIO M2        PONCE  ...
# 351      URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2        PONCE  ...
# 672                      1402 N CORINTH ST RD SUITE 113       DAllas  ...
# 1052                      Urb. Parkville # 1 Mejico St.     GUAYNABO  ...
# 1363              CARRETERA 108 INTERIOR KM 3.2 BO CUBA     MAYAGUEZ  ...
# 1654                  Frances 39 Amelia Industrial Park     GUAYNABO  ...
# 1665    4ta sec levittown , Centro Comercial Lago Vista     TOA BAJA  ...
# 1777                      1 Northfield Plaza, Suite 300   Northfield  ...
# 1799                                   167 Paris Street     Hato Rey  ...
# 1829              CALLE R LOTE 4 EL COMANDANTE IND PARK     CAROLINA  ...
# 2178               Cabo Caribe Ind Park Calle A lote 23    Vega Baja  ...
# 2280     URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2        PONCE  ...
# 2309  Caguas Norte Ind. Park Lote 12 Calle Desperak ...       Caguas  ...
# 2680  SANTURCE CALLE SAGRADO CORAZON ESQ LOS ANGELES...     SAN JUAN  ...
# 2862                                  Carr. #1 KM 122.4    MERCEDITA  ...
# 2888                          ROAD 869 BO PALMAS BLDG H       PALMAS  ...
#
#                  TRIIndustrySector  \
# 84                       999 Other
# 111                      999 Other
# 351                      999 Other
# 672                      999 Other
# 1052                     999 Other
# 1363                     999 Other
# 1654                     999 Other
# 1665                     999 Other
# 1777                     999 Other
# 1799                     999 Other
# 1829  336 Transportation Equipment
# 2178                     999 Other
# 2280                     999 Other
# 2309                     999 Other
# 2680                     999 Other
# 2862                     999 Other
# 2888                     999 Other
#
#                                       IndustrySubsector 4DigitNAICS  \
# 84                          7211 Traveler Accommodation      7211.0
# 111            5617 Services to Buildings and Dwellings      5617.0
# 351            5617 Services to Buildings and Dwellings      5617.0
# 672   5416 Management, Scientific, and Technical Con...      5416.0
# 1052  6233 Continuing Care Retirement Communities an...      6233.0
# 1363  6114 Business Schools and Computer and Managem...      6114.0
# 1654  4231 Motor Vehicle and Motor Vehicle Parts and...      4231.0
# 1665                               4451 Grocery Stores       4451.0
# 1777                           5112 Software Publishers      5112.0
# 1799              6111 Elementary and Secondary Schools      6111.0
# 1829             3363 Motor Vehicle Parts Manufacturing      3363.0
# 2178           7225 Restaurants and Other Eating Places      7225.0
# 2280        6221 General Medical and Surgical Hospitals      6221.0
# 2309          2362 Nonresidential Building Construction      2362.0
# 2680               8134 Civic and Social Organizations       8134.0
# 2862                             5621 Waste Collection       5621.0
# 2888  4243 Apparel, Piece Goods, and Notions Merchan...      4243.0
#
#                             SBAOfficeLabel            Loan_Range    job_Range  \
# 84    PUERTO RICO AND USVI DISTRICT OFFICE        c $1-2 million   100 to 249
# 111   PUERTO RICO AND USVI DISTRICT OFFICE        c $1-2 million  500 or more
# 351   PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   250 to 499
# 672   PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   100 to 249
# 1052  PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   100 to 249
# 1363  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 1654  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 1665  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000   100 to 249
# 1777  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     10 to 19
# 1799  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 1829  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2178  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 2280  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000   100 to 249
# 2309  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2680  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 2862  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2888  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     10 to 19
#
#                                                full_add        Lat  \
# 84                     Carr. 5506 KM 1.8, Mercedita, PR        NaN
# 111   URB INDUSTRIAL SABANETA CALLE HUCAR EDIFICIO M...   6.150486
# 351   URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...   6.150486
# 672          1402 N CORINTH ST RD SUITE 113, DAllas, PR  32.772884
# 1052        Urb. Parkville # 1 Mejico St., GUAYNABO, PR  23.634501
# 1363  CARRETERA 108 INTERIOR KM 3.2 BO CUBA, MAYAGUE...  21.521757
# 1654    Frances 39 Amelia Industrial Park, GUAYNABO, PR  46.227638
# 1665  4ta sec levittown , Centro Comercial Lago Vist...  30.460197
# 1777      1 Northfield Plaza, Suite 300, Northfield, PR  42.107711
# 1799                     167 Paris Street, Hato Rey, PR  48.856614
# 1829  CALLE R LOTE 4 EL COMANDANTE IND PARK, CAROLIN...  20.593684
# 2178  Cabo Caribe Ind Park Calle A lote 23, Vega Baj...  20.593684
# 2280  URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...   6.150486
# 2309  Caguas Norte Ind. Park Lote 12 Calle Desperak ...  20.593684
# 2680  SANTURCE CALLE SAGRADO CORAZON ESQ LOS ANGELES...  34.052234
# 2862                   Carr. #1 KM 122.4, MERCEDITA, PR        NaN
# 2888              ROAD 869 BO PALMAS BLDG H, PALMAS, PR -26.478873
#
#             Long FIPS_z
# 84           NaN    NaN
# 111   -75.616879    NaN
# 351   -75.616879    NaN
# 672   -96.779098    NaN
# 1052 -102.552784    NaN
# 1363  -77.781167    NaN
# 1654    2.213749    NaN
# 1665  -97.988348    NaN
# 1777  -87.773691    NaN
# 1799    2.352222    NaN
# 1829   78.962880    NaN
# 2178   78.962880    NaN
# 2280  -75.616879    NaN
# 2309   78.962880    NaN
# 2680 -118.243685    NaN
# 2862         NaN    NaN
# 2888  -51.995789    NaN
#
# [17 rows x 73 columns]

# %% [markdown]
# Convert to File

# %%
fips_PR = fips_merge_drop

# %%
fips_PR.to_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_pr_fips = pd.read_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
geo_pr_fips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0           0        774589          774589            774589  1724057303
# 1           1        774590          774590            774590  3828657103
# 2           2        774591          774591            774591  4150097210
# 3           3        774592          774592            774592  5502967210
# 4           4        774593          774593            774593  7953047007
#
#   DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      4/28/20            252              PPP
# 1      4/12/20            252              PPP
# 2      4/27/20            252              PPP
# 3      4/27/20            252              PPP
# 4       4/8/20            252              PPP
#
#                        BorrowerName                      BorrowerAddress  ...  \
# 0  CARIBBEAN TEMPORARY SERVICES LLC         PONCE DE LEON 1431 SUITE 701  ...
# 1  SOUTH AMERICAN RESTAURANTS CORP.  35 Diana St, Amelia Industrial Park  ...
# 2   GENESIS SECURITY SERVICES, INC.          5900 AVE. ISLA VERDE L2 PMB  ...
# 3     CENTRO MEDICO DEL TURABO INC.            100 AVE. LUIS MUNOZ MARIN  ...
# 4         CARIBBEAN RESTAURANTS LLC       5 Carr Km 6 Hm 2 Barrio Amelia  ...
#
#   TRIIndustrySector                            IndustrySubsector  4DigitNAICS  \
# 0         999 Other                     5613 Employment Services       5613.0
# 1         999 Other     7225 Restaurants and Other Eating Places       7225.0
# 2         999 Other     5616 Investigation and Security Services       5616.0
# 3         999 Other  6221 General Medical and Surgical Hospitals       6221.0
# 4         999 Other     7225 Restaurants and Other Eating Places       7225.0
#
#                          SBAOfficeLabel       Loan_Range    job_Range  \
# 0  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 1  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 2  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 3  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
# 4  PUERTO RICO AND USVI DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                             full_add        Lat       Long  \
# 0         PONCE DE LEON 1431 SUITE 701, SANTURCE, PR  18.388480 -66.062466
# 1  35 Diana St, Amelia Industrial Park, GUAYNABO, PR  18.416696 -66.118672
# 2          5900 AVE. ISLA VERDE L2 PMB, CAROLINA, PR  18.443043 -66.025696
# 3              100 AVE. LUIS MUNOZ MARIN, CAGUAS, PR  18.217878 -66.030109
# 4       5 Carr Km 6 Hm 2 Barrio Amelia, GUAYNABO, PR  18.419611 -66.114715
#
#          FIPS_z
# 0  7.212701e+14
# 1  7.206104e+14
# 2  7.203105e+14
# 3  7.202520e+14
# 4  7.206104e+14
#
# [5 rows x 74 columns]

# %%
##### fill in missing Lat, Long, FIPS
geo_pr_fips.loc[geo_pr_fips["FIPS_z"].isnull()] #27
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 84            84        774673          774673            774673  6466228606
# 111          111        774700          774700            774700  2954357201
# 351          351        774940          774940            774940  2942887210
# 672          672        775261          775261            775261  9390667707
# 1052        1052        775641          775641            775641  6116877007
# 1363        1363        775952          775952            775952  3391277310
# 1654        1654        776243          776243            776243  9603427100
# 1665        1665        776254          776254            776254  2372087203
# 1777        1777        776366          776366            776366  9332887705
# 1799        1799        776388          776388            776388  2760167303
# 1829        1829        776418          776418            776418  3178908600
# 2178        2178        776767          776767            776767  7499078403
# 2280        2280        776869          776869            776869  9455907709
# 2309        2309        776898          776898            776898  3068298508
# 2680        2680        777269          777269            777269  9343657701
# 2862        2862        777451          777451            777451  1670129002
# 2888        2888        777477          777477            777477  2196488604
#
#      DateApproved  SBAOfficeCode ProcessingMethod  \
# 84        3/23/21            252              PPS
# 111       4/16/20            252              PPP
# 351       4/16/20            252              PPP
# 672        5/1/20            252              PPP
# 1052       4/6/20            252              PPP
# 1363      4/29/20            252              PPP
# 1654      4/15/20            252              PPP
# 1665      4/16/20            252              PPP
# 1777       5/1/20            252              PPP
# 1799      4/29/20            252              PPP
# 1829      3/16/21            252              PPS
# 2178      2/12/21            252              PPS
# 2280       5/1/20            252              PPP
# 2309      2/22/21            252              PPS
# 2680       5/1/20            252              PPP
# 2862      5/13/21            252              PPS
# 2888      3/13/21            252              PPS
#
#                                            BorrowerName  \
# 84                                 SERRALLES HOTEL INC.
# 111                     PRIME JANITORIAL SERVICES, CORP
# 351                PRIME JANITORIAL METRO & HEALTH, INC
# 672      GENCO GENERAL CONTRACTORS OF PUERTO RICO CORP.
# 1052                             PARKVILLE ELDERLY HOME
# 1363  SOUTH WESTERN EDUCATION SOCIETY (SESO) SOCIEDA...
# 1654                         VENTURE DISTRIBUTORS CORP.
# 1665                          QUINONES SELF SERVICE LLC
# 1777                                     SIMPLEMENT INC
# 1799               COLEGIO CONGREGACIN MITA INCORPORADO
# 1829                  HI TEC BRAKE MANUFACTURING CO INC
# 2178                                          VRJT INC.
# 2280                          PRIME HEALTH SERVICES INC
# 2309                             PCTM CONSTRUCTION CORP
# 2680  YMCA DE SAN JUAN (THE YOUNG MEN'S CHRISTIAN AS...
# 2862                                   SEPTIX WASTE INC
# 2888                                          TSFPR LLC
#
#                                         BorrowerAddress  ...  \
# 84                                    Carr. 5506 KM 1.8  ...
# 111     URB INDUSTRIAL SABANETA CALLE HUCAR EDIFICIO M2  ...
# 351      URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2  ...
# 672                      1402 N CORINTH ST RD SUITE 113  ...
# 1052                      Urb. Parkville # 1 Mejico St.  ...
# 1363              CARRETERA 108 INTERIOR KM 3.2 BO CUBA  ...
# 1654                  Frances 39 Amelia Industrial Park  ...
# 1665    4ta sec levittown , Centro Comercial Lago Vista  ...
# 1777                      1 Northfield Plaza, Suite 300  ...
# 1799                                   167 Paris Street  ...
# 1829              CALLE R LOTE 4 EL COMANDANTE IND PARK  ...
# 2178               Cabo Caribe Ind Park Calle A lote 23  ...
# 2280     URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2  ...
# 2309  Caguas Norte Ind. Park Lote 12 Calle Desperak ...  ...
# 2680  SANTURCE CALLE SAGRADO CORAZON ESQ LOS ANGELES...  ...
# 2862                                  Carr. #1 KM 122.4  ...
# 2888                          ROAD 869 BO PALMAS BLDG H  ...
#
#                  TRIIndustrySector  \
# 84                       999 Other
# 111                      999 Other
# 351                      999 Other
# 672                      999 Other
# 1052                     999 Other
# 1363                     999 Other
# 1654                     999 Other
# 1665                     999 Other
# 1777                     999 Other
# 1799                     999 Other
# 1829  336 Transportation Equipment
# 2178                     999 Other
# 2280                     999 Other
# 2309                     999 Other
# 2680                     999 Other
# 2862                     999 Other
# 2888                     999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 84                          7211 Traveler Accommodation       7211.0
# 111            5617 Services to Buildings and Dwellings       5617.0
# 351            5617 Services to Buildings and Dwellings       5617.0
# 672   5416 Management, Scientific, and Technical Con...       5416.0
# 1052  6233 Continuing Care Retirement Communities an...       6233.0
# 1363  6114 Business Schools and Computer and Managem...       6114.0
# 1654  4231 Motor Vehicle and Motor Vehicle Parts and...       4231.0
# 1665                               4451 Grocery Stores        4451.0
# 1777                           5112 Software Publishers       5112.0
# 1799              6111 Elementary and Secondary Schools       6111.0
# 1829             3363 Motor Vehicle Parts Manufacturing       3363.0
# 2178           7225 Restaurants and Other Eating Places       7225.0
# 2280        6221 General Medical and Surgical Hospitals       6221.0
# 2309          2362 Nonresidential Building Construction       2362.0
# 2680               8134 Civic and Social Organizations        8134.0
# 2862                             5621 Waste Collection        5621.0
# 2888  4243 Apparel, Piece Goods, and Notions Merchan...       4243.0
#
#                             SBAOfficeLabel            Loan_Range    job_Range  \
# 84    PUERTO RICO AND USVI DISTRICT OFFICE        c $1-2 million   100 to 249
# 111   PUERTO RICO AND USVI DISTRICT OFFICE        c $1-2 million  500 or more
# 351   PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   250 to 499
# 672   PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   100 to 249
# 1052  PUERTO RICO AND USVI DISTRICT OFFICE  b $350,000-1 million   100 to 249
# 1363  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 1654  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 1665  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000   100 to 249
# 1777  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     10 to 19
# 1799  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 1829  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2178  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 2280  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000   100 to 249
# 2309  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2680  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     50 to 99
# 2862  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 2888  PUERTO RICO AND USVI DISTRICT OFFICE    a $150,000-350,000     10 to 19
#
#                                                full_add        Lat  \
# 84                     Carr. 5506 KM 1.8, Mercedita, PR        NaN
# 111   URB INDUSTRIAL SABANETA CALLE HUCAR EDIFICIO M...   6.150486
# 351   URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...   6.150486
# 672          1402 N CORINTH ST RD SUITE 113, DAllas, PR  32.772884
# 1052        Urb. Parkville # 1 Mejico St., GUAYNABO, PR  23.634501
# 1363  CARRETERA 108 INTERIOR KM 3.2 BO CUBA, MAYAGUE...  21.521757
# 1654    Frances 39 Amelia Industrial Park, GUAYNABO, PR  46.227638
# 1665  4ta sec levittown , Centro Comercial Lago Vist...  30.460197
# 1777      1 Northfield Plaza, Suite 300, Northfield, PR  42.107711
# 1799                     167 Paris Street, Hato Rey, PR  48.856614
# 1829  CALLE R LOTE 4 EL COMANDANTE IND PARK, CAROLIN...  20.593684
# 2178  Cabo Caribe Ind Park Calle A lote 23, Vega Baj...  20.593684
# 2280  URB INDUSTRIAL SABANETA CALLE UCAR EDIFICIO M2...   6.150486
# 2309  Caguas Norte Ind. Park Lote 12 Calle Desperak ...  20.593684
# 2680  SANTURCE CALLE SAGRADO CORAZON ESQ LOS ANGELES...  34.052234
# 2862                   Carr. #1 KM 122.4, MERCEDITA, PR        NaN
# 2888              ROAD 869 BO PALMAS BLDG H, PALMAS, PR -26.478873
#
#             Long  FIPS_z
# 84           NaN     NaN
# 111   -75.616879     NaN
# 351   -75.616879     NaN
# 672   -96.779098     NaN
# 1052 -102.552784     NaN
# 1363  -77.781167     NaN
# 1654    2.213749     NaN
# 1665  -97.988348     NaN
# 1777  -87.773691     NaN
# 1799    2.352222     NaN
# 1829   78.962880     NaN
# 2178   78.962880     NaN
# 2280  -75.616879     NaN
# 2309   78.962880     NaN
# 2680 -118.243685     NaN
# 2862         NaN     NaN
# 2888  -51.995789     NaN
#
# [17 rows x 74 columns]

# %%
geo_pr_fips["BusinessType"] = geo_pr_fips["BusinessType"].fillna('Not Available')
geo_pr_fips["BusinessType"].unique()
geo_pr_fips.to_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
geo_pr_fips =pd.read_csv("../../data/state_data/geo/geo_fips/PR_fips_scraped.csv") 
geo_pr_fips["BusinessType"].unique()
# Out:
# array(['Limited Liability Company(LLC)', 'Subchapter S Corporation',
#        'Corporation', 'Partnership', 'Limited Liability Partnership',
#        '501(c)3 – Non Profit', 'Employee Stock Ownership Plan(ESOP)',
#        'Professional Association', 'Sole Proprietorship',
#        'Non-Profit Organization', 'Not Available', 'Joint Venture',
#        'Cooperative', '501(c)6 – Non Profit Membership',
#        'Self-Employed Individuals', 'Trust', 'Independent Contractors',
#        'Non-Profit Childcare Center', 'Single Member LLC',
#        'Tenant in Common', 'Qualified Joint-Venture (spouses)'],
#       dtype=object)
