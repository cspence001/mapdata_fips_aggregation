# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as BraveService
from webdriver_manager.core.utils import ChromeType
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_ut.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check
# Out:
#       Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0         886823  4440597205      4/27/20            883              PPP
# 1         886824  5333267308      4/30/20            883              PPP
# 2         886825  7850817707       5/1/20            883              PPP
# 3         886826  8803828610      3/25/21            883              PPP
# 4         886827  9607187010       4/9/20            883              PPP
# ...          ...         ...          ...            ...              ...
# 9290      896113  9048067208      4/28/20            883              PPP
# 9291      896114  9342157005       4/9/20            883              PPP
# 9292      896115  9527478402      2/17/21            883              PPS
# 9293      896116  9736917000       4/9/20            883              PPP
# 9294      896117  9839018501      3/12/21            883              PPS
#
#                                 BorrowerName           BorrowerAddress  \
# 0            ALLISON BAVER ENTERTAINMENT LLC      6219 S. Saunter Lane
# 1     INTERMOUNTAIN EMPLOYMENT SERVICE, INC.       450 East 1000 North
# 2                     CENTRAL UTAH CLINIC PC       1055 North 500 West
# 3                WOLVERINE FUELS HOLDING LLC  9815 S Monroe St Ste 203
# 4                      SIZZLING CAESARS, LLC       348 E WINCHESTER ST
# ...                                      ...                       ...
# 9290               PRO TOWER MAINTENANCE LLC    676 LAVA POINTE DR #50
# 9291                 EDWARDS AUTOMOTIVE, INC           61 E GORDON AVE
# 9292                            RUBYSNAP LLC               756 S 300 W
# 9293           CODY EKKER CONSTRUCTION, INC.            412 E. 3200 N.
# 9294                    GRASSROOTS SALON INC     1320 E 3000 N STE A-1
#
#          BorrowerCity BorrowerState  BorrowerZip  ... TRIIndustrySector  \
# 0      SALT LAKE CITY            UT      84123.0  ...         999 Other
# 1     NORTH SALT LAKE            UT      84054.0  ...         999 Other
# 2               Provo            UT      84604.0  ...         999 Other
# 3               Sandy            UT      84070.0  ...  2121 Coal Mining
# 4      SALT LAKE CITY            UT      84107.0  ...         999 Other
# ...               ...           ...          ...  ...               ...
# 9290     SAINT GEORGE            UT      84770.0  ...         999 Other
# 9291   SALT LAKE CITY            UT      84107.0  ...         999 Other
# 9292   Salt Lake City            UT      84101.0  ...         999 Other
# 9293             LEHI            UT      84043.0  ...         999 Other
# 9294           LAYTON            UT      84040.0  ...         999 Other
#
#                                 IndustrySubsector  4DigitNAICS  \
# 0        5121 Motion Picture and Video Industries       5121.0
# 1                        5613 Employment Services       5613.0
# 2     6221 General Medical and Surgical Hospitals       6221.0
# 3                                2121 Coal Mining       2121.0
# 4        7225 Restaurants and Other Eating Places       7225.0
# ...                                           ...          ...
# 9290          2383 Building Finishing Contractors       2383.0
# 9291       8111 Automotive Repair and Maintenance       8111.0
# 9292     3118 Bakeries and Tortilla Manufacturing       3118.0
# 9293    2362 Nonresidential Building Construction       2362.0
# 9294                 8121 Personal Care Services        8121.0
#
#             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     UTAH DISTRICT OFFICE     e $5-10 million   250 to 499
# 1     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 2     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 3     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 4     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# ...                    ...                 ...          ...
# 9290  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9291  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9292  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9293  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9294  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat        Long FIPS_z
# 0     6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047    NaN
# 1     450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968    NaN
# 2               1055 North 500 West, Provo, UT  40.248562 -111.668402    NaN
# 3          9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991    NaN
# 4      348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457    NaN
# ...                                        ...        ...         ...    ...
# 9290  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327 -113.599085    NaN
# 9291       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543 -111.889893    NaN
# 9292           756 S 300 W, Salt Lake City, UT  40.752633 -111.900108    NaN
# 9293                  412 E. 3200 N., LEHI, UT  40.427645 -111.842536    NaN
# 9294         1320 E 3000 N STE A-1, LAYTON, UT  41.100101 -111.941576    NaN
#
# [9295 rows x 71 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan #3
# Out:
# Empty DataFrame
# Columns: [LoanNumber, full_add, Lat, Long]
# Index: []

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #15866
# Out:
#    LoanNumber                                  full_add        Lat        Long
# 0  4440597205  6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047
# 1  5333267308  450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968
# 2  7850817707            1055 North 500 West, Provo, UT  40.248562 -111.668402
# 3  8803828610       9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991
# 4  9607187010   348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("../../data/state_data/geo/geo_fips/UT_fips_scraped.csv") 
fips_check_scraped.head() #15869

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #15866

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #5503

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
#driver = webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))
#executable_path = {'executable_path': webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))}
executable_path = {'executable_path': ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()}
option = webdriver.ChromeOptions()
option.binary_location = "/Applications/Brave Browser.app/Contents/MacOS/Brave Browser"
driver = Browser('chrome', **executable_path, options=option, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('geoCoordX').clear()
        driver.find_by_id('geoCoordY').clear()
        driver.find_by_id('geoCoordX').fill(long[i])
        driver.find_by_id('geoCoordY').fill(lat[i])
        driver.find_by_id('geoCoordsSubmit').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='geoCoordsJsonOutput')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('49')] #UT
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                #print(f"{i},{lat[i]},{long[i]} Not Found")
                not_found.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
#   0%|          | 0/9295 [00:00<?, ?it/s]

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 9295

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:25062]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
#       LoanNumber                                  full_add        Lat  \
# 0     4440597205  6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779
# 1     5333267308  450 East 1000 North, NORTH SALT LAKE, UT  40.859421
# 2     7850817707            1055 North 500 West, Provo, UT  40.248562
# 3     8803828610       9815 S Monroe St Ste 203, Sandy, UT  40.573544
# 4     9607187010   348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246
# ...          ...                                       ...        ...
# 9290  9048067208  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327
# 9291  9342157005       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543
# 9292  9527478402           756 S 300 W, Salt Lake City, UT  40.752633
# 9293  9736917000                  412 E. 3200 N., LEHI, UT  40.427645
# 9294  9839018501         1320 E 3000 N STE A-1, LAYTON, UT  41.100101
#
#             Long             FIPS_z
# 0    -111.891047  [490351140002011]
# 1    -111.900968  [490111270024066]
# 2    -111.668402  [490490020013000]
# 3    -111.897991  [490351126213007]
# 4    -111.880457  [490351123023021]
# ...          ...                ...
# 9290 -113.599085  [490532715021002]
# 9291 -111.889893  [490351116012016]
# 9292 -111.900108  [490351140003025]
# 9293 -111.842536  [490490102163000]
# 9294 -111.941576  [490111258044010]
#
# [9295 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
#       LoanNumber                                  full_add        Lat  \
# 0     4440597205  6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779
# 1     5333267308  450 East 1000 North, NORTH SALT LAKE, UT  40.859421
# 2     7850817707            1055 North 500 West, Provo, UT  40.248562
# 3     8803828610       9815 S Monroe St Ste 203, Sandy, UT  40.573544
# 4     9607187010   348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246
# ...          ...                                       ...        ...
# 9290  9048067208  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327
# 9291  9342157005       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543
# 9292  9527478402           756 S 300 W, Salt Lake City, UT  40.752633
# 9293  9736917000                  412 E. 3200 N., LEHI, UT  40.427645
# 9294  9839018501         1320 E 3000 N STE A-1, LAYTON, UT  41.100101
#
#             Long           FIPS_z
# 0    -111.891047  490351140002011
# 1    -111.900968  490111270024066
# 2    -111.668402  490490020013000
# 3    -111.897991  490351126213007
# 4    -111.880457  490351123023021
# ...          ...              ...
# 9290 -113.599085  490532715021002
# 9291 -111.889893  490351116012016
# 9292 -111.900108  490351140003025
# 9293 -111.842536  490490102163000
# 9294 -111.941576  490111258044010
#
# [9295 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check #24
# Out:
#       LoanNumber                    full_add        Lat       Long FIPS_z
# 603   3842137205        1337 N 750 E, UT, UT  30.069203 -99.118273    NaN
# 9239  5601547110  1750 E. Hwy 40, VERNAL, UT  39.001899 -92.733623    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#       LoanNumber           FIPS_z
# 0     4440597205  490351140002011
# 1     5333267308  490111270024066
# 2     7850817707  490490020013000
# 3     8803828610  490351126213007
# 4     9607187010  490351123023021
# ...          ...              ...
# 9290  9048067208  490532715021002
# 9291  9342157005  490351116012016
# 9292  9527478402  490351140003025
# 9293  9736917000  490490102163000
# 9294  9839018501  490111258044010
#
# [9295 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_ut.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check.head()

#if from FIPS file
#fips_check = pd.read_csv("../../data/state_data/geo/geo_fips/UT_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #22826
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0      886823        886823          886823  4440597205      4/27/20
# 1      886824        886824          886824  5333267308      4/30/20
# 2      886825        886825          886825  7850817707       5/1/20
# 3      886826        886826          886826  8803828610      3/25/21
# 4      886827        886827          886827  9607187010       4/9/20
#
#    SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0            883              PPP         ALLISON BAVER ENTERTAINMENT LLC
# 1            883              PPP  INTERMOUNTAIN EMPLOYMENT SERVICE, INC.
# 2            883              PPP                  CENTRAL UTAH CLINIC PC
# 3            883              PPP             WOLVERINE FUELS HOLDING LLC
# 4            883              PPP                   SIZZLING CAESARS, LLC
#
#             BorrowerAddress     BorrowerCity  ... TRIIndustrySector  \
# 0      6219 S. Saunter Lane   SALT LAKE CITY  ...         999 Other
# 1       450 East 1000 North  NORTH SALT LAKE  ...         999 Other
# 2       1055 North 500 West            Provo  ...         999 Other
# 3  9815 S Monroe St Ste 203            Sandy  ...  2121 Coal Mining
# 4       348 E WINCHESTER ST   SALT LAKE CITY  ...         999 Other
#
#                              IndustrySubsector 4DigitNAICS  \
# 0     5121 Motion Picture and Video Industries      5121.0
# 1                     5613 Employment Services      5613.0
# 2  6221 General Medical and Surgical Hospitals      6221.0
# 3                             2121 Coal Mining      2121.0
# 4     7225 Restaurants and Other Eating Places      7225.0
#
#          SBAOfficeLabel       Loan_Range    job_Range  \
# 0  UTAH DISTRICT OFFICE  e $5-10 million   250 to 499
# 1  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 2  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 3  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 4  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                    full_add        Lat        Long FIPS_z
# 0  6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047    NaN
# 1  450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968    NaN
# 2            1055 North 500 West, Provo, UT  40.248562 -111.668402    NaN
# 3       9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991    NaN
# 4   348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457    NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         886823        886823          886823  4440597205      4/27/20
# 1         886824        886824          886824  5333267308      4/30/20
# 2         886825        886825          886825  7850817707       5/1/20
# 3         886826        886826          886826  8803828610      3/25/21
# 4         886827        886827          886827  9607187010       4/9/20
# ...          ...           ...             ...         ...          ...
# 9290      896113        896113          896113  9048067208      4/28/20
# 9291      896114        896114          896114  9342157005       4/9/20
# 9292      896115        896115          896115  9527478402      2/17/21
# 9293      896116        896116          896116  9736917000       4/9/20
# 9294      896117        896117          896117  9839018501      3/12/21
#
#       SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0               883              PPP         ALLISON BAVER ENTERTAINMENT LLC
# 1               883              PPP  INTERMOUNTAIN EMPLOYMENT SERVICE, INC.
# 2               883              PPP                  CENTRAL UTAH CLINIC PC
# 3               883              PPP             WOLVERINE FUELS HOLDING LLC
# 4               883              PPP                   SIZZLING CAESARS, LLC
# ...             ...              ...                                     ...
# 9290            883              PPP               PRO TOWER MAINTENANCE LLC
# 9291            883              PPP                 EDWARDS AUTOMOTIVE, INC
# 9292            883              PPS                            RUBYSNAP LLC
# 9293            883              PPP           CODY EKKER CONSTRUCTION, INC.
# 9294            883              PPS                    GRASSROOTS SALON INC
#
#                BorrowerAddress     BorrowerCity  ...  \
# 0         6219 S. Saunter Lane   SALT LAKE CITY  ...
# 1          450 East 1000 North  NORTH SALT LAKE  ...
# 2          1055 North 500 West            Provo  ...
# 3     9815 S Monroe St Ste 203            Sandy  ...
# 4          348 E WINCHESTER ST   SALT LAKE CITY  ...
# ...                        ...              ...  ...
# 9290    676 LAVA POINTE DR #50     SAINT GEORGE  ...
# 9291           61 E GORDON AVE   SALT LAKE CITY  ...
# 9292               756 S 300 W   Salt Lake City  ...
# 9293            412 E. 3200 N.             LEHI  ...
# 9294     1320 E 3000 N STE A-1           LAYTON  ...
#
#                                 IndustrySubsector  4DigitNAICS  \
# 0        5121 Motion Picture and Video Industries       5121.0
# 1                        5613 Employment Services       5613.0
# 2     6221 General Medical and Surgical Hospitals       6221.0
# 3                                2121 Coal Mining       2121.0
# 4        7225 Restaurants and Other Eating Places       7225.0
# ...                                           ...          ...
# 9290          2383 Building Finishing Contractors       2383.0
# 9291       8111 Automotive Repair and Maintenance       8111.0
# 9292     3118 Bakeries and Tortilla Manufacturing       3118.0
# 9293    2362 Nonresidential Building Construction       2362.0
# 9294                 8121 Personal Care Services        8121.0
#
#             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     UTAH DISTRICT OFFICE     e $5-10 million   250 to 499
# 1     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 2     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 3     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 4     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# ...                    ...                 ...          ...
# 9290  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9291  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9292  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9293  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9294  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat        Long  \
# 0     6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047
# 1     450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968
# 2               1055 North 500 West, Provo, UT  40.248562 -111.668402
# 3          9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991
# 4      348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457
# ...                                        ...        ...         ...
# 9290  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327 -113.599085
# 9291       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543 -111.889893
# 9292           756 S 300 W, Salt Lake City, UT  40.752633 -111.900108
# 9293                  412 E. 3200 N., LEHI, UT  40.427645 -111.842536
# 9294         1320 E 3000 N STE A-1, LAYTON, UT  41.100101 -111.941576
#
#       FIPS_z_x         FIPS_z_y
# 0          NaN  490351140002011
# 1          NaN  490111270024066
# 2          NaN  490490020013000
# 3          NaN  490351126213007
# 4          NaN  490351123023021
# ...        ...              ...
# 9290       NaN  490532715021002
# 9291       NaN  490351116012016
# 9292       NaN  490351140003025
# 9293       NaN  490490102163000
# 9294       NaN  490111258044010
#
# [9295 rows x 74 columns]

# %% [markdown]
# <b>Fill FIPS Columns - if FIPS file

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         886823        886823          886823  4440597205      4/27/20
# 1         886824        886824          886824  5333267308      4/30/20
# 2         886825        886825          886825  7850817707       5/1/20
# 3         886826        886826          886826  8803828610      3/25/21
# 4         886827        886827          886827  9607187010       4/9/20
# ...          ...           ...             ...         ...          ...
# 9290      896113        896113          896113  9048067208      4/28/20
# 9291      896114        896114          896114  9342157005       4/9/20
# 9292      896115        896115          896115  9527478402      2/17/21
# 9293      896116        896116          896116  9736917000       4/9/20
# 9294      896117        896117          896117  9839018501      3/12/21
#
#       SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0               883              PPP         ALLISON BAVER ENTERTAINMENT LLC
# 1               883              PPP  INTERMOUNTAIN EMPLOYMENT SERVICE, INC.
# 2               883              PPP                  CENTRAL UTAH CLINIC PC
# 3               883              PPP             WOLVERINE FUELS HOLDING LLC
# 4               883              PPP                   SIZZLING CAESARS, LLC
# ...             ...              ...                                     ...
# 9290            883              PPP               PRO TOWER MAINTENANCE LLC
# 9291            883              PPP                 EDWARDS AUTOMOTIVE, INC
# 9292            883              PPS                            RUBYSNAP LLC
# 9293            883              PPP           CODY EKKER CONSTRUCTION, INC.
# 9294            883              PPS                    GRASSROOTS SALON INC
#
#                BorrowerAddress     BorrowerCity  ... 4DigitNAICS  \
# 0         6219 S. Saunter Lane   SALT LAKE CITY  ...      5121.0
# 1          450 East 1000 North  NORTH SALT LAKE  ...      5613.0
# 2          1055 North 500 West            Provo  ...      6221.0
# 3     9815 S Monroe St Ste 203            Sandy  ...      2121.0
# 4          348 E WINCHESTER ST   SALT LAKE CITY  ...      7225.0
# ...                        ...              ...  ...         ...
# 9290    676 LAVA POINTE DR #50     SAINT GEORGE  ...      2383.0
# 9291           61 E GORDON AVE   SALT LAKE CITY  ...      8111.0
# 9292               756 S 300 W   Salt Lake City  ...      3118.0
# 9293            412 E. 3200 N.             LEHI  ...      2362.0
# 9294     1320 E 3000 N STE A-1           LAYTON  ...      8121.0
#
#             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     UTAH DISTRICT OFFICE     e $5-10 million   250 to 499
# 1     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 2     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 3     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 4     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# ...                    ...                 ...          ...
# 9290  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9291  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9292  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9293  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9294  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat        Long  \
# 0     6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047
# 1     450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968
# 2               1055 North 500 West, Provo, UT  40.248562 -111.668402
# 3          9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991
# 4      348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457
# ...                                        ...        ...         ...
# 9290  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327 -113.599085
# 9291       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543 -111.889893
# 9292           756 S 300 W, Salt Lake City, UT  40.752633 -111.900108
# 9293                  412 E. 3200 N., LEHI, UT  40.427645 -111.842536
# 9294         1320 E 3000 N STE A-1, LAYTON, UT  41.100101 -111.941576
#
#       FIPS_z_x         FIPS_z_y           FIPS_z
# 0          NaN  490351140002011  490351140002011
# 1          NaN  490111270024066  490111270024066
# 2          NaN  490490020013000  490490020013000
# 3          NaN  490351126213007  490351126213007
# 4          NaN  490351123023021  490351123023021
# ...        ...              ...              ...
# 9290       NaN  490532715021002  490532715021002
# 9291       NaN  490351116012016  490351116012016
# 9292       NaN  490351140003025  490351140003025
# 9293       NaN  490490102163000  490490102163000
# 9294       NaN  490111258044010  490111258044010
#
# [9295 rows x 75 columns]

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
#fips_merge_drop = fips_merge_drop.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         886823        886823          886823  4440597205      4/27/20
# 1         886824        886824          886824  5333267308      4/30/20
# 2         886825        886825          886825  7850817707       5/1/20
# 3         886826        886826          886826  8803828610      3/25/21
# 4         886827        886827          886827  9607187010       4/9/20
# ...          ...           ...             ...         ...          ...
# 9290      896113        896113          896113  9048067208      4/28/20
# 9291      896114        896114          896114  9342157005       4/9/20
# 9292      896115        896115          896115  9527478402      2/17/21
# 9293      896116        896116          896116  9736917000       4/9/20
# 9294      896117        896117          896117  9839018501      3/12/21
#
#       SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0               883              PPP         ALLISON BAVER ENTERTAINMENT LLC
# 1               883              PPP  INTERMOUNTAIN EMPLOYMENT SERVICE, INC.
# 2               883              PPP                  CENTRAL UTAH CLINIC PC
# 3               883              PPP             WOLVERINE FUELS HOLDING LLC
# 4               883              PPP                   SIZZLING CAESARS, LLC
# ...             ...              ...                                     ...
# 9290            883              PPP               PRO TOWER MAINTENANCE LLC
# 9291            883              PPP                 EDWARDS AUTOMOTIVE, INC
# 9292            883              PPS                            RUBYSNAP LLC
# 9293            883              PPP           CODY EKKER CONSTRUCTION, INC.
# 9294            883              PPS                    GRASSROOTS SALON INC
#
#                BorrowerAddress     BorrowerCity  ... TRIIndustrySector  \
# 0         6219 S. Saunter Lane   SALT LAKE CITY  ...         999 Other
# 1          450 East 1000 North  NORTH SALT LAKE  ...         999 Other
# 2          1055 North 500 West            Provo  ...         999 Other
# 3     9815 S Monroe St Ste 203            Sandy  ...  2121 Coal Mining
# 4          348 E WINCHESTER ST   SALT LAKE CITY  ...         999 Other
# ...                        ...              ...  ...               ...
# 9290    676 LAVA POINTE DR #50     SAINT GEORGE  ...         999 Other
# 9291           61 E GORDON AVE   SALT LAKE CITY  ...         999 Other
# 9292               756 S 300 W   Salt Lake City  ...         999 Other
# 9293            412 E. 3200 N.             LEHI  ...         999 Other
# 9294     1320 E 3000 N STE A-1           LAYTON  ...         999 Other
#
#                                 IndustrySubsector 4DigitNAICS  \
# 0        5121 Motion Picture and Video Industries      5121.0
# 1                        5613 Employment Services      5613.0
# 2     6221 General Medical and Surgical Hospitals      6221.0
# 3                                2121 Coal Mining      2121.0
# 4        7225 Restaurants and Other Eating Places      7225.0
# ...                                           ...         ...
# 9290          2383 Building Finishing Contractors      2383.0
# 9291       8111 Automotive Repair and Maintenance      8111.0
# 9292     3118 Bakeries and Tortilla Manufacturing      3118.0
# 9293    2362 Nonresidential Building Construction      2362.0
# 9294                 8121 Personal Care Services       8121.0
#
#             SBAOfficeLabel          Loan_Range    job_Range  \
# 0     UTAH DISTRICT OFFICE     e $5-10 million   250 to 499
# 1     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 2     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 3     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# 4     UTAH DISTRICT OFFICE     e $5-10 million  500 or more
# ...                    ...                 ...          ...
# 9290  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9291  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9292  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 9293  UTAH DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 9294  UTAH DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                       full_add        Lat        Long  \
# 0     6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047
# 1     450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968
# 2               1055 North 500 West, Provo, UT  40.248562 -111.668402
# 3          9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991
# 4      348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457
# ...                                        ...        ...         ...
# 9290  676 LAVA POINTE DR #50, SAINT GEORGE, UT  37.076327 -113.599085
# 9291       61 E GORDON AVE, SALT LAKE CITY, UT  40.683543 -111.889893
# 9292           756 S 300 W, Salt Lake City, UT  40.752633 -111.900108
# 9293                  412 E. 3200 N., LEHI, UT  40.427645 -111.842536
# 9294         1320 E 3000 N STE A-1, LAYTON, UT  41.100101 -111.941576
#
#                FIPS_z
# 0     490351140002011
# 1     490111270024066
# 2     490490020013000
# 3     490351126213007
# 4     490351123023021
# ...               ...
# 9290  490532715021002
# 9291  490351116012016
# 9292  490351140003025
# 9293  490490102163000
# 9294  490111258044010
#
# [9295 rows x 73 columns]

# %%
#fips_merge_drop = fips_merge.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop.loc[fips_merge["FIPS_z"].isnull()] #verify #27 , notna #22799 / 22826
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 603       887426        887426          887426  3842137205      4/27/20
# 9239      896062        896062          896062  5601547110      4/13/20
#
#       SBAOfficeCode ProcessingMethod         BorrowerName BorrowerAddress  \
# 603             883              PPP    LEGALLY MINE, LLC    1337 N 750 E
# 9239            883              PPP  UDELLS CABINETS INC  1750 E. Hwy 40
#
#      BorrowerCity  ... TRIIndustrySector  \
# 603            UT  ...         999 Other
# 9239       VERNAL  ...     337 Furniture
#
#                                       IndustrySubsector 4DigitNAICS  \
# 603                                 5411 Legal Services      5411.0
# 9239  3371 Household and Institutional Furniture and...      3371.0
#
#             SBAOfficeLabel          Loan_Range  job_Range  \
# 603   UTAH DISTRICT OFFICE      c $1-2 million   50 to 99
# 9239  UTAH DISTRICT OFFICE  a $150,000-350,000   10 to 19
#
#                         full_add        Lat       Long FIPS_z
# 603         1337 N 750 E, UT, UT  30.069203 -99.118273    NaN
# 9239  1750 E. Hwy 40, VERNAL, UT  39.001899 -92.733623    NaN
#
# [2 rows x 73 columns]

# %% [markdown]
# Convert to File

# %%
fips_UT = fips_merge_drop

# %%
fips_UT.to_csv("../../data/state_data/geo/geo_fips/UT_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_ut_fips = pd.read_csv("../../data/state_data/geo/geo_fips/UT_fips_scraped.csv") 
geo_ut_fips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0           0        886823          886823            886823  4440597205
# 1           1        886824          886824            886824  5333267308
# 2           2        886825          886825            886825  7850817707
# 3           3        886826          886826            886826  8803828610
# 4           4        886827          886827            886827  9607187010
#
#   DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      4/27/20            883              PPP
# 1      4/30/20            883              PPP
# 2       5/1/20            883              PPP
# 3      3/25/21            883              PPP
# 4       4/9/20            883              PPP
#
#                              BorrowerName           BorrowerAddress  ...  \
# 0         ALLISON BAVER ENTERTAINMENT LLC      6219 S. Saunter Lane  ...
# 1  INTERMOUNTAIN EMPLOYMENT SERVICE, INC.       450 East 1000 North  ...
# 2                  CENTRAL UTAH CLINIC PC       1055 North 500 West  ...
# 3             WOLVERINE FUELS HOLDING LLC  9815 S Monroe St Ste 203  ...
# 4                   SIZZLING CAESARS, LLC       348 E WINCHESTER ST  ...
#
#   TRIIndustrySector                            IndustrySubsector  4DigitNAICS  \
# 0         999 Other     5121 Motion Picture and Video Industries       5121.0
# 1         999 Other                     5613 Employment Services       5613.0
# 2         999 Other  6221 General Medical and Surgical Hospitals       6221.0
# 3  2121 Coal Mining                             2121 Coal Mining       2121.0
# 4         999 Other     7225 Restaurants and Other Eating Places       7225.0
#
#          SBAOfficeLabel       Loan_Range    job_Range  \
# 0  UTAH DISTRICT OFFICE  e $5-10 million   250 to 499
# 1  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 2  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 3  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
# 4  UTAH DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                    full_add        Lat        Long  \
# 0  6219 S. Saunter Lane, SALT LAKE CITY, UT  40.760779 -111.891047
# 1  450 East 1000 North, NORTH SALT LAKE, UT  40.859421 -111.900968
# 2            1055 North 500 West, Provo, UT  40.248562 -111.668402
# 3       9815 S Monroe St Ste 203, Sandy, UT  40.573544 -111.897991
# 4   348 E WINCHESTER ST, SALT LAKE CITY, UT  40.632246 -111.880457
#
#          FIPS_z
# 0  4.903511e+14
# 1  4.901113e+14
# 2  4.904900e+14
# 3  4.903511e+14
# 4  4.903511e+14
#
# [5 rows x 74 columns]

# %%
##### fill in missing Lat, Long, FIPS
geo_ut_fips.loc[geo_ut_fips["FIPS_z"].isnull()] #27
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 603          603        887426          887426            887426  3842137205
# 9239        9239        896062          896062            896062  5601547110
#
#      DateApproved  SBAOfficeCode ProcessingMethod         BorrowerName  \
# 603       4/27/20            883              PPP    LEGALLY MINE, LLC
# 9239      4/13/20            883              PPP  UDELLS CABINETS INC
#
#      BorrowerAddress  ... TRIIndustrySector  \
# 603     1337 N 750 E  ...         999 Other
# 9239  1750 E. Hwy 40  ...     337 Furniture
#
#                                       IndustrySubsector  4DigitNAICS  \
# 603                                 5411 Legal Services       5411.0
# 9239  3371 Household and Institutional Furniture and...       3371.0
#
#             SBAOfficeLabel          Loan_Range  job_Range  \
# 603   UTAH DISTRICT OFFICE      c $1-2 million   50 to 99
# 9239  UTAH DISTRICT OFFICE  a $150,000-350,000   10 to 19
#
#                         full_add        Lat       Long  FIPS_z
# 603         1337 N 750 E, UT, UT  30.069203 -99.118273     NaN
# 9239  1750 E. Hwy 40, VERNAL, UT  39.001899 -92.733623     NaN
#
# [2 rows x 74 columns]
