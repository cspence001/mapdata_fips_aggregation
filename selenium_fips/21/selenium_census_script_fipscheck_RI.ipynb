# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as BraveService
from webdriver_manager.core.utils import ChromeType
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_ri.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check
# Out:
#       Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0         777541  9179517702       5/1/20            165              PPP
# 1         777542  9713307002       4/9/20            165              PPP
# 2         777543  5711067207      4/27/20            165              PPP
# 3         777544  4819187009       4/4/20            165              PPP
# 4         777545  3895377102      4/12/20            165              PPP
# ...          ...         ...          ...            ...              ...
# 3787      781328  8379078305      1/29/21            165              PPS
# 3788      781329  8836008607      3/25/21            165              PPS
# 3789      781330  8960777006       4/9/20            165              PPP
# 3790      781331  9102547103      4/15/20            165              PPP
# 3791      781332  9451938303      1/30/21            165              PPS
#
#                            BorrowerName            BorrowerAddress  \
# 0                 COASTAL MEDICAL, INC.  10 Davol Square Suite 300
# 1                        BROWN MEDICINE                 110 ELM ST
# 2                              TACO INC           1160 CRANSTON ST
# 3          UNIVERSITY ORTHOPEDICS, INC.      1 Kettle Point Avenue
# 4                  H. CARR & SONS, INC.     100 Royal Little Drive
# ...                                 ...                        ...
# 3787            GRAPHIC INNOVATIONS INC   380 Jefferson Blvd Ste C
# 3788            NEW ENGLAND DRYWALL CO.       816 Middle Rd Unit 5
# 3789  WATER DAMAGE DRYING SERVICES INC.              12 GAVITT AVE
# 3790             STORMTITE COMPANY INC.           1065 WARWICK AVE
# 3791              RUGGIERI FLOORING INC           1191 Pontiac Ave
#
#          BorrowerCity BorrowerState  BorrowerZip  ...  \
# 0           Providnce            RI       2903.0  ...
# 1          PROVIDENCE            RI       2903.0  ...
# 2            CRANSTON            RI       2920.0  ...
# 3     EAST PROVIDENCE            RI       2914.0  ...
# 4          PROVIDENCE            RI       2904.0  ...
# ...               ...           ...          ...  ...
# 3787          Warwick            RI       2886.0  ...
# 3788   East Greenwich            RI       2818.0  ...
# 3789         WESTERLY            RI       2891.0  ...
# 3790          WARWICK            RI       2888.0  ...
# 3791         Cranston            RI       2920.0  ...
#
#               TRIIndustrySector  \
# 0                     999 Other
# 1                     999 Other
# 2                 333 Machinery
# 3                     999 Other
# 4                     999 Other
# ...                         ...
# 3787  323 Printing & Publishing
# 3788                  999 Other
# 3789                  999 Other
# 3790                  999 Other
# 3791                  999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0                            6211 Offices of Physicians       6211.0
# 1                            6211 Offices of Physicians       6211.0
# 2     3334 Ventilation, Heating, Air-Conditioning, a...       3334.0
# 3                            6211 Offices of Physicians       6211.0
# 4                   2383 Building Finishing Contractors       2383.0
# ...                                                 ...          ...
# 3787       3231 Printing and Related Support Activities       3231.0
# 3788                2383 Building Finishing Contractors       2383.0
# 3789             2389 Other Specialty Trade Contractors       2389.0
# 3790             2361 Residential Building Construction       2361.0
# 3791                2383 Building Finishing Contractors       2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     RHODE ISLAND DISTRICT OFFICE     e $5-10 million  500 or more
# 1     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 2     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 3     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 4     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 3787  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3788  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3789  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3790  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3791  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                         full_add        Lat       Long  \
# 0       10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                     110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2                 1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3     1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4         100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
# ...                                          ...        ...        ...
# 3787       380 Jefferson Blvd Ste C, Warwick, RI  41.738247 -71.439550
# 3788    816 Middle Rd Unit 5, East Greenwich, RI  41.645916 -71.489230
# 3789                 12 GAVITT AVE, WESTERLY, RI  41.383280 -71.820860
# 3790               1065 WARWICK AVE, WARWICK, RI  41.746986 -71.405410
# 3791              1191 Pontiac Ave, Cranston, RI  41.752150 -71.451416
#
#             FIPS_z
# 0     4.400700e+14
# 1     4.400700e+14
# 2     4.400701e+14
# 3     4.400701e+14
# 4     4.400700e+14
# ...            ...
# 3787  4.400302e+14
# 3788  4.400302e+14
# 3789  4.400905e+14
# 3790  4.400302e+14
# 3791  4.400701e+14
#
# [3792 rows x 71 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan #3
# Out:
# Empty DataFrame
# Columns: [LoanNumber, full_add, Lat, Long]
# Index: []

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #15866
# Out:
#    LoanNumber                                    full_add        Lat  \
# 0  9179517702    10 Davol Square Suite 300, Providnce, RI  41.804245
# 1  9713307002                  110 ELM ST, PROVIDENCE, RI  41.817000
# 2  5711067207              1160 CRANSTON ST, CRANSTON, RI  41.795063
# 3  4819187009  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700
# 4  3895377102      100 Royal Little Drive, PROVIDENCE, RI  41.847070
#
#         Long
# 0 -71.420240
# 1 -71.410620
# 2 -71.449750
# 3 -71.375510
# 4 -71.413536

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("../../data/state_data/geo/geo_fips/RI_fips_scraped.csv") 
fips_check_scraped.head() #15869
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0           0        777541          777541            777541  9179517702
# 1           1        777542          777542            777542  9713307002
# 2           2        777543          777543            777543  5711067207
# 3           3        777544          777544            777544  4819187009
# 4           4        777545          777545            777545  3895377102
#
#   DateApproved  SBAOfficeCode ProcessingMethod                  BorrowerName  \
# 0       5/1/20            165              PPP         COASTAL MEDICAL, INC.
# 1       4/9/20            165              PPP                BROWN MEDICINE
# 2      4/27/20            165              PPP                      TACO INC
# 3       4/4/20            165              PPP  UNIVERSITY ORTHOPEDICS, INC.
# 4      4/12/20            165              PPP          H. CARR & SONS, INC.
#
#              BorrowerAddress  ... TRIIndustrySector  \
# 0  10 Davol Square Suite 300  ...         999 Other
# 1                 110 ELM ST  ...         999 Other
# 2           1160 CRANSTON ST  ...     333 Machinery
# 3      1 Kettle Point Avenue  ...         999 Other
# 4     100 Royal Little Drive  ...         999 Other
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0                         6211 Offices of Physicians       6211.0
# 1                         6211 Offices of Physicians       6211.0
# 2  3334 Ventilation, Heating, Air-Conditioning, a...       3334.0
# 3                         6211 Offices of Physicians       6211.0
# 4                2383 Building Finishing Contractors       2383.0
#
#                  SBAOfficeLabel       Loan_Range    job_Range  \
# 0  RHODE ISLAND DISTRICT OFFICE  e $5-10 million  500 or more
# 1  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 2  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 3  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 4  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
#
#                                      full_add        Lat       Long  \
# 0    10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                  110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2              1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4      100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
#
#          FIPS_z
# 0  4.400700e+14
# 1  4.400700e+14
# 2  4.400701e+14
# 3  4.400701e+14
# 4  4.400700e+14
#
# [5 rows x 74 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #15866
# Out:
#       LoanNumber                                    full_add        Lat  \
# 0     9179517702    10 Davol Square Suite 300, Providnce, RI  41.804245
# 1     9713307002                  110 ELM ST, PROVIDENCE, RI  41.817000
# 2     5711067207              1160 CRANSTON ST, CRANSTON, RI  41.795063
# 3     4819187009  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700
# 4     3895377102      100 Royal Little Drive, PROVIDENCE, RI  41.847070
# ...          ...                                         ...        ...
# 3787  8379078305       380 Jefferson Blvd Ste C, Warwick, RI  41.738247
# 3788  8836008607    816 Middle Rd Unit 5, East Greenwich, RI  41.645916
# 3789  8960777006                 12 GAVITT AVE, WESTERLY, RI  41.383280
# 3790  9102547103               1065 WARWICK AVE, WARWICK, RI  41.746986
# 3791  9451938303              1191 Pontiac Ave, Cranston, RI  41.752150
#
#            Long        FIPS_z
# 0    -71.420240  4.400700e+14
# 1    -71.410620  4.400700e+14
# 2    -71.449750  4.400701e+14
# 3    -71.375510  4.400701e+14
# 4    -71.413536  4.400700e+14
# ...         ...           ...
# 3787 -71.439550  4.400302e+14
# 3788 -71.489230  4.400302e+14
# 3789 -71.820860  4.400905e+14
# 3790 -71.405410  4.400302e+14
# 3791 -71.451416  4.400701e+14
#
# [3792 rows x 5 columns]

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #5503
# Out:
#       LoanNumber                                           full_add  \
# 3310  1620187106                 2700 PLAINFIELD PIKE, CRANSTON, RI
# 3317  7313537003      567 SOUTH COUNTY TRAIL SUITE  107, EXETER, RI
# 3334  3649398708                     541 HARTFORD AVE, JOHNSTON, RI
# 3335  8830027006                   P.O. Box 132, LITTLE COMPTON, RI
# 3355  4574717003                15 Patrol Road, NORTH KINGSTOWN, RI
# 3363  6111687108  1485 South County Trail Unit 302 South, EAST G...
# 3365  1327547206              16 TERRY LANE, UNIT 3A, Glocester, RI
# 3373  6888298409            147 Industrial Dr, North Smithfield, RI
# 3374  1289998609                   300 Wampanoag Trl, Riverside, RI
# 3375  8125607106           300 Wampanaog Trail, East Providence, RI
# 3383  8126147101                26 Tyler Point Road, Barrington, RI
# 3399  6631318309                       1 Garnett Ln, Greenville, RI
# 3404  5605398400                 600 Clock Tower Sq, Portsmouth, RI
# 3411  9423688303                      939 W Main Rd, Middletown, RI
# 3439  6084657310                267 JENCKES HILL RD, SMITHFIELD, RI
# 3447  8096737807         300 Centerville Rd Suite 103S, WARWICK, RI
# 3448  4963597705           300 CENTERVILLE RD STE 303S, WARWICK, RI
# 3469  8728917006       147 Industrial Dr. #10, NORTH SMITHFIELD, RI
# 3475  5012937405           300 CENTERVILLE RD STE 250E, WARWICK, RI
# 3478  8125257108                 PO Box 2 264 Exeter Rd, Slocum, RI
# 3481  5794847700           1 TURKS HEAD PL STE 1308, PROVIDENCE, RI
# 3494  1159517208                        PO Box 7368, Cumberland, RI
# 3499  4485837100             1 Sayers Wharf PO Box 141, NEWPORT, RI
# 3501  4765258300                        1 Sayers Wharf, Newport, RI
# 3512  5023147007        275 WEST NATICK ROAD SUITE 500, WARWICK, RI
# 3513  6816267002            20 NEWMAN AVE., SUITE 3003, RUMFORD, RI
# 3521  6108757006                205 NOOSENECK HILL RD, COVENTRY, RI
# 3526  1173307200              355 chestnut hill road, glocester, RI
# 3537  6718658407                6 Blackstone Valley Pl, Lincoln, RI
# 3558  3547918403                 2700 Plainfield Pike, Cranston, RI
# 3569  1979457307        1 West Exchange Street 1602, Providence, RI
# 3611  8552578503             22 Cross Park Ave, North Kingstown, RI
# 3612  8504697002             22 CROSS PARK AVE, NORTH KINGSTOWN, RI
# 3622  2911368309         17 Ashton Park Way Ste 208, Cumberland, RI
# 3628  8112217108           927 Warren Avenue A, East Providence, RI
# 3633  4891157310                  PO Box 14411, East Providence, RI
# 3637  6194408302                     33 PLAN WAY BLD 7, WARWICK, RI
# 3638  4742517307                33 Plan Way Building 7, Warwick, RI
# 3644  5887147004                    1 TURKS HEAD PL, PROVIDENCE, RI
# 3653  3066808404                1 Sims Ave Unit 101, Providence, RI
# 3654  6038987706                1 SIMS AVE UNIT 101, PROVIDENCE, RI
# 3674  8670777008        175 METRO CENTER BLVD Suite 10, WARWICK, RI
# 3681  1749458406       6 Blackstone Valley Pl Ste 306A, Lincoln, RI
# 3692  9268667104                      400 BALD HILL RD, WARWICK, RI
# 3693  1666877107             6 BLACKSTONE VALLEY PLACE, LINCOLN, RI
# 3697  5065737103                              LAVAN ST, WARWICK, RI
# 3705  2784367200          1 TURKS HEAD PL SUITE 550, PROVIDENCE, RI
# 3714  3680568306                1 Maritime Dr Ste 5, Portsmouth, RI
# 3716  4576697003                 One Maritime Drive, PORTSMOUTH, RI
# 3726  4901097005                     PO BOX 856, EAST GREENWICH, RI
# 3741  8126567109       1725 Mendon Road   Suite 209, Cumber;and, RI
# 3744  5643847104      7 Technology Drive Ste 203, CENTRAL FALLS, RI
# 3763  8128517109               One park Row Suite 5, Providence, RI
# 3765  1991368608                6 Blackstone Valley Pl, Lincoln, RI
# 3779  5863207004          1 TURKS HEAD PL SUITE 900, PROVIDENCE, RI
# 3782  6583288503              400 Bald Hill Rd Ste 503, Warwick, RI
#
#             Lat       Long  FIPS_z
# 3310  41.789741 -71.538455     NaN
# 3317  41.527457 -71.552202     NaN
# 3334  41.819151 -71.461754     NaN
# 3335  41.510103 -71.171156     NaN
# 3355  41.619406 -71.409574     NaN
# 3363  41.656178 -71.498483     NaN
# 3365  41.903695 -71.646085     NaN
# 3373  41.990678 -71.563354     NaN
# 3374  41.796317 -71.350428     NaN
# 3375  41.796317 -71.350428     NaN
# 3383  41.735120 -71.290975     NaN
# 3399  41.873788 -71.557554     NaN
# 3404  41.590980 -71.267496     NaN
# 3411  41.527765 -71.295605     NaN
# 3439  41.919603 -71.483103     NaN
# 3447  41.694617 -71.471593     NaN
# 3448  41.694617 -71.471593     NaN
# 3469  41.990678 -71.563354     NaN
# 3475  41.694617 -71.471593     NaN
# 3478  41.542084 -71.507150     NaN
# 3481  41.824575 -71.410049     NaN
# 3494  41.972182 -71.406188     NaN
# 3499  41.490102 -71.312828     NaN
# 3501  41.490102 -71.312828     NaN
# 3512  41.729743 -71.482802     NaN
# 3513  41.840472 -71.354345     NaN
# 3521  41.648526 -71.607229     NaN
# 3526  41.896056 -71.690718     NaN
# 3537  41.936131 -71.455701     NaN
# 3558  41.789741 -71.538455     NaN
# 3569  41.825126 -71.417135     NaN
# 3611  41.613942 -71.431467     NaN
# 3612  41.613942 -71.431467     NaN
# 3622  41.933857 -71.429055     NaN
# 3628  41.807376 -71.346531     NaN
# 3633  41.813712 -71.370054     NaN
# 3637  41.736882 -71.447567     NaN
# 3638  41.736882 -71.447567     NaN
# 3644  41.824575 -71.410049     NaN
# 3653  41.826770 -71.433933     NaN
# 3654  41.826770 -71.433933     NaN
# 3674  41.724257 -71.457019     NaN
# 3681  41.936131 -71.455701     NaN
# 3692  41.724962 -71.478796     NaN
# 3693  41.936131 -71.455701     NaN
# 3697  41.755843 -71.433172     NaN
# 3705  41.824575 -71.410049     NaN
# 3714  41.585165 -71.283636     NaN
# 3716  41.584136 -71.285131     NaN
# 3726  41.634262 -71.513044     NaN
# 3741  41.996421 -71.482229     NaN
# 3744  41.890655 -71.392279     NaN
# 3763  41.828561 -71.410142     NaN
# 3765  41.936131 -71.455701     NaN
# 3779  41.824575 -71.410049     NaN
# 3782  41.726911 -71.479282     NaN

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
#lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
#long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
#driver = webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))
#executable_path = {'executable_path': webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))}
executable_path = {'executable_path': ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()}
option = webdriver.ChromeOptions()
option.binary_location = "/Applications/Brave Browser.app/Contents/MacOS/Brave Browser"
driver = Browser('chrome', **executable_path, options=option, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('geoCoordX').clear()
        driver.find_by_id('geoCoordY').clear()
        driver.find_by_id('geoCoordX').fill(long[i])
        driver.find_by_id('geoCoordY').fill(lat[i])
        driver.find_by_id('geoCoordsSubmit').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='geoCoordsJsonOutput')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('44')] #RI
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                #print(f"{i},{lat[i]},{long[i]} Not Found")
                not_found.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 56

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
#fips_fill = fips_check_notna.iloc[:3308] #confirm pair to notna DataFrame
#if FIPS available
fips_fill = fips_check_scraped_null

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       LoanNumber                                           full_add  \
# 3310  1620187106                 2700 PLAINFIELD PIKE, CRANSTON, RI
# 3317  7313537003      567 SOUTH COUNTY TRAIL SUITE  107, EXETER, RI
# 3334  3649398708                     541 HARTFORD AVE, JOHNSTON, RI
# 3335  8830027006                   P.O. Box 132, LITTLE COMPTON, RI
# 3355  4574717003                15 Patrol Road, NORTH KINGSTOWN, RI
# 3363  6111687108  1485 South County Trail Unit 302 South, EAST G...
# 3365  1327547206              16 TERRY LANE, UNIT 3A, Glocester, RI
# 3373  6888298409            147 Industrial Dr, North Smithfield, RI
# 3374  1289998609                   300 Wampanoag Trl, Riverside, RI
# 3375  8125607106           300 Wampanaog Trail, East Providence, RI
# 3383  8126147101                26 Tyler Point Road, Barrington, RI
# 3399  6631318309                       1 Garnett Ln, Greenville, RI
# 3404  5605398400                 600 Clock Tower Sq, Portsmouth, RI
# 3411  9423688303                      939 W Main Rd, Middletown, RI
# 3439  6084657310                267 JENCKES HILL RD, SMITHFIELD, RI
# 3447  8096737807         300 Centerville Rd Suite 103S, WARWICK, RI
# 3448  4963597705           300 CENTERVILLE RD STE 303S, WARWICK, RI
# 3469  8728917006       147 Industrial Dr. #10, NORTH SMITHFIELD, RI
# 3475  5012937405           300 CENTERVILLE RD STE 250E, WARWICK, RI
# 3478  8125257108                 PO Box 2 264 Exeter Rd, Slocum, RI
# 3481  5794847700           1 TURKS HEAD PL STE 1308, PROVIDENCE, RI
# 3494  1159517208                        PO Box 7368, Cumberland, RI
# 3499  4485837100             1 Sayers Wharf PO Box 141, NEWPORT, RI
# 3501  4765258300                        1 Sayers Wharf, Newport, RI
# 3512  5023147007        275 WEST NATICK ROAD SUITE 500, WARWICK, RI
# 3513  6816267002            20 NEWMAN AVE., SUITE 3003, RUMFORD, RI
# 3521  6108757006                205 NOOSENECK HILL RD, COVENTRY, RI
# 3526  1173307200              355 chestnut hill road, glocester, RI
# 3537  6718658407                6 Blackstone Valley Pl, Lincoln, RI
# 3558  3547918403                 2700 Plainfield Pike, Cranston, RI
# 3569  1979457307        1 West Exchange Street 1602, Providence, RI
# 3611  8552578503             22 Cross Park Ave, North Kingstown, RI
# 3612  8504697002             22 CROSS PARK AVE, NORTH KINGSTOWN, RI
# 3622  2911368309         17 Ashton Park Way Ste 208, Cumberland, RI
# 3628  8112217108           927 Warren Avenue A, East Providence, RI
# 3633  4891157310                  PO Box 14411, East Providence, RI
# 3637  6194408302                     33 PLAN WAY BLD 7, WARWICK, RI
# 3638  4742517307                33 Plan Way Building 7, Warwick, RI
# 3644  5887147004                    1 TURKS HEAD PL, PROVIDENCE, RI
# 3653  3066808404                1 Sims Ave Unit 101, Providence, RI
# 3654  6038987706                1 SIMS AVE UNIT 101, PROVIDENCE, RI
# 3674  8670777008        175 METRO CENTER BLVD Suite 10, WARWICK, RI
# 3681  1749458406       6 Blackstone Valley Pl Ste 306A, Lincoln, RI
# 3692  9268667104                      400 BALD HILL RD, WARWICK, RI
# 3693  1666877107             6 BLACKSTONE VALLEY PLACE, LINCOLN, RI
# 3697  5065737103                              LAVAN ST, WARWICK, RI
# 3705  2784367200          1 TURKS HEAD PL SUITE 550, PROVIDENCE, RI
# 3714  3680568306                1 Maritime Dr Ste 5, Portsmouth, RI
# 3716  4576697003                 One Maritime Drive, PORTSMOUTH, RI
# 3726  4901097005                     PO BOX 856, EAST GREENWICH, RI
# 3741  8126567109       1725 Mendon Road   Suite 209, Cumber;and, RI
# 3744  5643847104      7 Technology Drive Ste 203, CENTRAL FALLS, RI
# 3763  8128517109               One park Row Suite 5, Providence, RI
# 3765  1991368608                6 Blackstone Valley Pl, Lincoln, RI
# 3779  5863207004          1 TURKS HEAD PL SUITE 900, PROVIDENCE, RI
# 3782  6583288503              400 Bald Hill Rd Ste 503, Warwick, RI
#
#             Lat       Long             FIPS_z
# 3310  41.789741 -71.538455  [440070146002006]
# 3317  41.527457 -71.552202  [440090505001036]
# 3334  41.819151 -71.461754  [440070018001017]
# 3335  41.510103 -71.171156  [440050414003021]
# 3355  41.619406 -71.409574  [440090501032004]
# 3363  41.656178 -71.498483  [440030209031023]
# 3365  41.903695 -71.646085  [440070131021004]
# 3373  41.990678 -71.563354  [440070128031034]
# 3374  41.796317 -71.350428  [440070105011032]
# 3375  41.796317 -71.350428  [440070105011032]
# 3383  41.735120 -71.290975  [440010303001025]
# 3399  41.873788 -71.557554  [440070127013047]
# 3404  41.590980 -71.267496  [440050401053028]
# 3411  41.527765 -71.295605  [440050403042006]
# 3439  41.919603 -71.483103  [440070126024004]
# 3447  41.694617 -71.471593  [440030222011008]
# 3448  41.694617 -71.471593  [440030222011008]
# 3469  41.990678 -71.563354  [440070128031034]
# 3475  41.694617 -71.471593  [440030222011008]
# 3478  41.542084 -71.507150  [440090504011030]
# 3481  41.824575 -71.410049  [440070008003017]
# 3494  41.972182 -71.406188  [440070114053011]
# 3499  41.490102 -71.312828  [440050410001007]
# 3501  41.490102 -71.312828  [440050410001007]
# 3512  41.729743 -71.482802  [440030223003005]
# 3513  41.840472 -71.354345  [440070101024004]
# 3521  41.648526 -71.607229  [440030208002008]
# 3526  41.896056 -71.690718  [440070131011014]
# 3537  41.936131 -71.455701  [440070116005004]
# 3558  41.789741 -71.538455  [440070146002006]
# 3569  41.825126 -71.417135  [440070008001049]
# 3611  41.613942 -71.431467  [440090501032020]
# 3612  41.613942 -71.431467  [440090501032020]
# 3622  41.933857 -71.429055  [440070113012002]
# 3628  41.807376 -71.346531  [440070105011007]
# 3633  41.813712 -71.370054  [440070104001002]
# 3637  41.736882 -71.447567  [440030211004021]
# 3638  41.736882 -71.447567  [440030211004021]
# 3644  41.824575 -71.410049  [440070008003017]
# 3653  41.826770 -71.433933  [440070025003035]
# 3654  41.826770 -71.433933  [440070025003035]
# 3674  41.724257 -71.457019  [440030221001013]
# 3681  41.936131 -71.455701  [440070116005004]
# 3692  41.724962 -71.478796  [440030223003018]
# 3693  41.936131 -71.455701  [440070116005004]
# 3697  41.755843 -71.433172  [440030211002001]
# 3705  41.824575 -71.410049  [440070008003017]
# 3714  41.585165 -71.283636  [440050401041004]
# 3716  41.584136 -71.285131  [440050401041004]
# 3726  41.634262 -71.513044  [440030209032013]
# 3741  41.996421 -71.482229  [440070185002018]
# 3744  41.890655 -71.392279  [440070110002003]
# 3763  41.828561 -71.410142  [440070008001000]
# 3765  41.936131 -71.455701  [440070116005004]
# 3779  41.824575 -71.410049  [440070008003017]
# 3782  41.726911 -71.479282  [440030223003018]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       LoanNumber                                           full_add  \
# 3310  1620187106                 2700 PLAINFIELD PIKE, CRANSTON, RI
# 3317  7313537003      567 SOUTH COUNTY TRAIL SUITE  107, EXETER, RI
# 3334  3649398708                     541 HARTFORD AVE, JOHNSTON, RI
# 3335  8830027006                   P.O. Box 132, LITTLE COMPTON, RI
# 3355  4574717003                15 Patrol Road, NORTH KINGSTOWN, RI
# 3363  6111687108  1485 South County Trail Unit 302 South, EAST G...
# 3365  1327547206              16 TERRY LANE, UNIT 3A, Glocester, RI
# 3373  6888298409            147 Industrial Dr, North Smithfield, RI
# 3374  1289998609                   300 Wampanoag Trl, Riverside, RI
# 3375  8125607106           300 Wampanaog Trail, East Providence, RI
# 3383  8126147101                26 Tyler Point Road, Barrington, RI
# 3399  6631318309                       1 Garnett Ln, Greenville, RI
# 3404  5605398400                 600 Clock Tower Sq, Portsmouth, RI
# 3411  9423688303                      939 W Main Rd, Middletown, RI
# 3439  6084657310                267 JENCKES HILL RD, SMITHFIELD, RI
# 3447  8096737807         300 Centerville Rd Suite 103S, WARWICK, RI
# 3448  4963597705           300 CENTERVILLE RD STE 303S, WARWICK, RI
# 3469  8728917006       147 Industrial Dr. #10, NORTH SMITHFIELD, RI
# 3475  5012937405           300 CENTERVILLE RD STE 250E, WARWICK, RI
# 3478  8125257108                 PO Box 2 264 Exeter Rd, Slocum, RI
# 3481  5794847700           1 TURKS HEAD PL STE 1308, PROVIDENCE, RI
# 3494  1159517208                        PO Box 7368, Cumberland, RI
# 3499  4485837100             1 Sayers Wharf PO Box 141, NEWPORT, RI
# 3501  4765258300                        1 Sayers Wharf, Newport, RI
# 3512  5023147007        275 WEST NATICK ROAD SUITE 500, WARWICK, RI
# 3513  6816267002            20 NEWMAN AVE., SUITE 3003, RUMFORD, RI
# 3521  6108757006                205 NOOSENECK HILL RD, COVENTRY, RI
# 3526  1173307200              355 chestnut hill road, glocester, RI
# 3537  6718658407                6 Blackstone Valley Pl, Lincoln, RI
# 3558  3547918403                 2700 Plainfield Pike, Cranston, RI
# 3569  1979457307        1 West Exchange Street 1602, Providence, RI
# 3611  8552578503             22 Cross Park Ave, North Kingstown, RI
# 3612  8504697002             22 CROSS PARK AVE, NORTH KINGSTOWN, RI
# 3622  2911368309         17 Ashton Park Way Ste 208, Cumberland, RI
# 3628  8112217108           927 Warren Avenue A, East Providence, RI
# 3633  4891157310                  PO Box 14411, East Providence, RI
# 3637  6194408302                     33 PLAN WAY BLD 7, WARWICK, RI
# 3638  4742517307                33 Plan Way Building 7, Warwick, RI
# 3644  5887147004                    1 TURKS HEAD PL, PROVIDENCE, RI
# 3653  3066808404                1 Sims Ave Unit 101, Providence, RI
# 3654  6038987706                1 SIMS AVE UNIT 101, PROVIDENCE, RI
# 3674  8670777008        175 METRO CENTER BLVD Suite 10, WARWICK, RI
# 3681  1749458406       6 Blackstone Valley Pl Ste 306A, Lincoln, RI
# 3692  9268667104                      400 BALD HILL RD, WARWICK, RI
# 3693  1666877107             6 BLACKSTONE VALLEY PLACE, LINCOLN, RI
# 3697  5065737103                              LAVAN ST, WARWICK, RI
# 3705  2784367200          1 TURKS HEAD PL SUITE 550, PROVIDENCE, RI
# 3714  3680568306                1 Maritime Dr Ste 5, Portsmouth, RI
# 3716  4576697003                 One Maritime Drive, PORTSMOUTH, RI
# 3726  4901097005                     PO BOX 856, EAST GREENWICH, RI
# 3741  8126567109       1725 Mendon Road   Suite 209, Cumber;and, RI
# 3744  5643847104      7 Technology Drive Ste 203, CENTRAL FALLS, RI
# 3763  8128517109               One park Row Suite 5, Providence, RI
# 3765  1991368608                6 Blackstone Valley Pl, Lincoln, RI
# 3779  5863207004          1 TURKS HEAD PL SUITE 900, PROVIDENCE, RI
# 3782  6583288503              400 Bald Hill Rd Ste 503, Warwick, RI
#
#             Lat       Long           FIPS_z
# 3310  41.789741 -71.538455  440070146002006
# 3317  41.527457 -71.552202  440090505001036
# 3334  41.819151 -71.461754  440070018001017
# 3335  41.510103 -71.171156  440050414003021
# 3355  41.619406 -71.409574  440090501032004
# 3363  41.656178 -71.498483  440030209031023
# 3365  41.903695 -71.646085  440070131021004
# 3373  41.990678 -71.563354  440070128031034
# 3374  41.796317 -71.350428  440070105011032
# 3375  41.796317 -71.350428  440070105011032
# 3383  41.735120 -71.290975  440010303001025
# 3399  41.873788 -71.557554  440070127013047
# 3404  41.590980 -71.267496  440050401053028
# 3411  41.527765 -71.295605  440050403042006
# 3439  41.919603 -71.483103  440070126024004
# 3447  41.694617 -71.471593  440030222011008
# 3448  41.694617 -71.471593  440030222011008
# 3469  41.990678 -71.563354  440070128031034
# 3475  41.694617 -71.471593  440030222011008
# 3478  41.542084 -71.507150  440090504011030
# 3481  41.824575 -71.410049  440070008003017
# 3494  41.972182 -71.406188  440070114053011
# 3499  41.490102 -71.312828  440050410001007
# 3501  41.490102 -71.312828  440050410001007
# 3512  41.729743 -71.482802  440030223003005
# 3513  41.840472 -71.354345  440070101024004
# 3521  41.648526 -71.607229  440030208002008
# 3526  41.896056 -71.690718  440070131011014
# 3537  41.936131 -71.455701  440070116005004
# 3558  41.789741 -71.538455  440070146002006
# 3569  41.825126 -71.417135  440070008001049
# 3611  41.613942 -71.431467  440090501032020
# 3612  41.613942 -71.431467  440090501032020
# 3622  41.933857 -71.429055  440070113012002
# 3628  41.807376 -71.346531  440070105011007
# 3633  41.813712 -71.370054  440070104001002
# 3637  41.736882 -71.447567  440030211004021
# 3638  41.736882 -71.447567  440030211004021
# 3644  41.824575 -71.410049  440070008003017
# 3653  41.826770 -71.433933  440070025003035
# 3654  41.826770 -71.433933  440070025003035
# 3674  41.724257 -71.457019  440030221001013
# 3681  41.936131 -71.455701  440070116005004
# 3692  41.724962 -71.478796  440030223003018
# 3693  41.936131 -71.455701  440070116005004
# 3697  41.755843 -71.433172  440030211002001
# 3705  41.824575 -71.410049  440070008003017
# 3714  41.585165 -71.283636  440050401041004
# 3716  41.584136 -71.285131  440050401041004
# 3726  41.634262 -71.513044  440030209032013
# 3741  41.996421 -71.482229  440070185002018
# 3744  41.890655 -71.392279  440070110002003
# 3763  41.828561 -71.410142  440070008001000
# 3765  41.936131 -71.455701  440070116005004
# 3779  41.824575 -71.410049  440070008003017
# 3782  41.726911 -71.479282  440030223003018

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check #24
# Out:
# Empty DataFrame
# Columns: [LoanNumber, full_add, Lat, Long, FIPS_z]
# Index: []

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#       LoanNumber           FIPS_z
# 3310  1620187106  440070146002006
# 3317  7313537003  440090505001036
# 3334  3649398708  440070018001017
# 3335  8830027006  440050414003021
# 3355  4574717003  440090501032004
# 3363  6111687108  440030209031023
# 3365  1327547206  440070131021004
# 3373  6888298409  440070128031034
# 3374  1289998609  440070105011032
# 3375  8125607106  440070105011032
# 3383  8126147101  440010303001025
# 3399  6631318309  440070127013047
# 3404  5605398400  440050401053028
# 3411  9423688303  440050403042006
# 3439  6084657310  440070126024004
# 3447  8096737807  440030222011008
# 3448  4963597705  440030222011008
# 3469  8728917006  440070128031034
# 3475  5012937405  440030222011008
# 3478  8125257108  440090504011030
# 3481  5794847700  440070008003017
# 3494  1159517208  440070114053011
# 3499  4485837100  440050410001007
# 3501  4765258300  440050410001007
# 3512  5023147007  440030223003005
# 3513  6816267002  440070101024004
# 3521  6108757006  440030208002008
# 3526  1173307200  440070131011014
# 3537  6718658407  440070116005004
# 3558  3547918403  440070146002006
# 3569  1979457307  440070008001049
# 3611  8552578503  440090501032020
# 3612  8504697002  440090501032020
# 3622  2911368309  440070113012002
# 3628  8112217108  440070105011007
# 3633  4891157310  440070104001002
# 3637  6194408302  440030211004021
# 3638  4742517307  440030211004021
# 3644  5887147004  440070008003017
# 3653  3066808404  440070025003035
# 3654  6038987706  440070025003035
# 3674  8670777008  440030221001013
# 3681  1749458406  440070116005004
# 3692  9268667104  440030223003018
# 3693  1666877107  440070116005004
# 3697  5065737103  440030211002001
# 3705  2784367200  440070008003017
# 3714  3680568306  440050401041004
# 3716  4576697003  440050401041004
# 3726  4901097005  440030209032013
# 3741  8126567109  440070185002018
# 3744  5643847104  440070110002003
# 3763  8128517109  440070008001000
# 3765  1991368608  440070116005004
# 3779  5863207004  440070008003017
# 3782  6583288503  440030223003018

# %% [markdown]
# Read in base data

# %%
#if from geocode file
#fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_ri.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
#fips_check.head()

#if from FIPS file
fips_check = pd.read_csv("../../data/state_data/geo/geo_fips/RI_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
fips_check.head() #22826
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0           0        777541          777541            777541  9179517702
# 1           1        777542          777542            777542  9713307002
# 2           2        777543          777543            777543  5711067207
# 3           3        777544          777544            777544  4819187009
# 4           4        777545          777545            777545  3895377102
#
#   DateApproved  SBAOfficeCode ProcessingMethod                  BorrowerName  \
# 0       5/1/20            165              PPP         COASTAL MEDICAL, INC.
# 1       4/9/20            165              PPP                BROWN MEDICINE
# 2      4/27/20            165              PPP                      TACO INC
# 3       4/4/20            165              PPP  UNIVERSITY ORTHOPEDICS, INC.
# 4      4/12/20            165              PPP          H. CARR & SONS, INC.
#
#              BorrowerAddress  ... TRIIndustrySector  \
# 0  10 Davol Square Suite 300  ...         999 Other
# 1                 110 ELM ST  ...         999 Other
# 2           1160 CRANSTON ST  ...     333 Machinery
# 3      1 Kettle Point Avenue  ...         999 Other
# 4     100 Royal Little Drive  ...         999 Other
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0                         6211 Offices of Physicians       6211.0
# 1                         6211 Offices of Physicians       6211.0
# 2  3334 Ventilation, Heating, Air-Conditioning, a...       3334.0
# 3                         6211 Offices of Physicians       6211.0
# 4                2383 Building Finishing Contractors       2383.0
#
#                  SBAOfficeLabel       Loan_Range    job_Range  \
# 0  RHODE ISLAND DISTRICT OFFICE  e $5-10 million  500 or more
# 1  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 2  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 3  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 4  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
#
#                                      full_add        Lat       Long  \
# 0    10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                  110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2              1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4      100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
#
#          FIPS_z
# 0  4.400700e+14
# 1  4.400700e+14
# 2  4.400701e+14
# 3  4.400701e+14
# 4  4.400700e+14
#
# [5 rows x 74 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0              0        777541          777541            777541  9179517702
# 1              1        777542          777542            777542  9713307002
# 2              2        777543          777543            777543  5711067207
# 3              3        777544          777544            777544  4819187009
# 4              4        777545          777545            777545  3895377102
# ...          ...           ...             ...               ...         ...
# 3787        3787        781328          781328            781328  8379078305
# 3788        3788        781329          781329            781329  8836008607
# 3789        3789        781330          781330            781330  8960777006
# 3790        3790        781331          781331            781331  9102547103
# 3791        3791        781332          781332            781332  9451938303
#
#      DateApproved  SBAOfficeCode ProcessingMethod  \
# 0          5/1/20            165              PPP
# 1          4/9/20            165              PPP
# 2         4/27/20            165              PPP
# 3          4/4/20            165              PPP
# 4         4/12/20            165              PPP
# ...           ...            ...              ...
# 3787      1/29/21            165              PPS
# 3788      3/25/21            165              PPS
# 3789       4/9/20            165              PPP
# 3790      4/15/20            165              PPP
# 3791      1/30/21            165              PPS
#
#                            BorrowerName            BorrowerAddress  ...  \
# 0                 COASTAL MEDICAL, INC.  10 Davol Square Suite 300  ...
# 1                        BROWN MEDICINE                 110 ELM ST  ...
# 2                              TACO INC           1160 CRANSTON ST  ...
# 3          UNIVERSITY ORTHOPEDICS, INC.      1 Kettle Point Avenue  ...
# 4                  H. CARR & SONS, INC.     100 Royal Little Drive  ...
# ...                                 ...                        ...  ...
# 3787            GRAPHIC INNOVATIONS INC   380 Jefferson Blvd Ste C  ...
# 3788            NEW ENGLAND DRYWALL CO.       816 Middle Rd Unit 5  ...
# 3789  WATER DAMAGE DRYING SERVICES INC.              12 GAVITT AVE  ...
# 3790             STORMTITE COMPANY INC.           1065 WARWICK AVE  ...
# 3791              RUGGIERI FLOORING INC           1191 Pontiac Ave  ...
#
#                                       IndustrySubsector 4DigitNAICS  \
# 0                            6211 Offices of Physicians      6211.0
# 1                            6211 Offices of Physicians      6211.0
# 2     3334 Ventilation, Heating, Air-Conditioning, a...      3334.0
# 3                            6211 Offices of Physicians      6211.0
# 4                   2383 Building Finishing Contractors      2383.0
# ...                                                 ...         ...
# 3787       3231 Printing and Related Support Activities      3231.0
# 3788                2383 Building Finishing Contractors      2383.0
# 3789             2389 Other Specialty Trade Contractors      2389.0
# 3790             2361 Residential Building Construction      2361.0
# 3791                2383 Building Finishing Contractors      2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     RHODE ISLAND DISTRICT OFFICE     e $5-10 million  500 or more
# 1     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 2     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 3     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 4     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 3787  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3788  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3789  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3790  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3791  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                         full_add        Lat       Long  \
# 0       10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                     110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2                 1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3     1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4         100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
# ...                                          ...        ...        ...
# 3787       380 Jefferson Blvd Ste C, Warwick, RI  41.738247 -71.439550
# 3788    816 Middle Rd Unit 5, East Greenwich, RI  41.645916 -71.489230
# 3789                 12 GAVITT AVE, WESTERLY, RI  41.383280 -71.820860
# 3790               1065 WARWICK AVE, WARWICK, RI  41.746986 -71.405410
# 3791              1191 Pontiac Ave, Cranston, RI  41.752150 -71.451416
#
#           FIPS_z_x  FIPS_z_y
# 0     4.400700e+14       NaN
# 1     4.400700e+14       NaN
# 2     4.400701e+14       NaN
# 3     4.400701e+14       NaN
# 4     4.400700e+14       NaN
# ...            ...       ...
# 3787  4.400302e+14       NaN
# 3788  4.400302e+14       NaN
# 3789  4.400905e+14       NaN
# 3790  4.400302e+14       NaN
# 3791  4.400701e+14       NaN
#
# [3792 rows x 75 columns]

# %% [markdown]
# <b>Fill FIPS Columns - if FIPS file

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0              0        777541          777541            777541  9179517702
# 1              1        777542          777542            777542  9713307002
# 2              2        777543          777543            777543  5711067207
# 3              3        777544          777544            777544  4819187009
# 4              4        777545          777545            777545  3895377102
# ...          ...           ...             ...               ...         ...
# 3787        3787        781328          781328            781328  8379078305
# 3788        3788        781329          781329            781329  8836008607
# 3789        3789        781330          781330            781330  8960777006
# 3790        3790        781331          781331            781331  9102547103
# 3791        3791        781332          781332            781332  9451938303
#
#      DateApproved  SBAOfficeCode ProcessingMethod  \
# 0          5/1/20            165              PPP
# 1          4/9/20            165              PPP
# 2         4/27/20            165              PPP
# 3          4/4/20            165              PPP
# 4         4/12/20            165              PPP
# ...           ...            ...              ...
# 3787      1/29/21            165              PPS
# 3788      3/25/21            165              PPS
# 3789       4/9/20            165              PPP
# 3790      4/15/20            165              PPP
# 3791      1/30/21            165              PPS
#
#                            BorrowerName            BorrowerAddress  ...  \
# 0                 COASTAL MEDICAL, INC.  10 Davol Square Suite 300  ...
# 1                        BROWN MEDICINE                 110 ELM ST  ...
# 2                              TACO INC           1160 CRANSTON ST  ...
# 3          UNIVERSITY ORTHOPEDICS, INC.      1 Kettle Point Avenue  ...
# 4                  H. CARR & SONS, INC.     100 Royal Little Drive  ...
# ...                                 ...                        ...  ...
# 3787            GRAPHIC INNOVATIONS INC   380 Jefferson Blvd Ste C  ...
# 3788            NEW ENGLAND DRYWALL CO.       816 Middle Rd Unit 5  ...
# 3789  WATER DAMAGE DRYING SERVICES INC.              12 GAVITT AVE  ...
# 3790             STORMTITE COMPANY INC.           1065 WARWICK AVE  ...
# 3791              RUGGIERI FLOORING INC           1191 Pontiac Ave  ...
#
#      4DigitNAICS                SBAOfficeLabel          Loan_Range  \
# 0         6211.0  RHODE ISLAND DISTRICT OFFICE     e $5-10 million
# 1         6211.0  RHODE ISLAND DISTRICT OFFICE     e $5-10 million
# 2         3334.0  RHODE ISLAND DISTRICT OFFICE     e $5-10 million
# 3         6211.0  RHODE ISLAND DISTRICT OFFICE     e $5-10 million
# 4         2383.0  RHODE ISLAND DISTRICT OFFICE     e $5-10 million
# ...          ...                           ...                 ...
# 3787      3231.0  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000
# 3788      2383.0  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000
# 3789      2389.0  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000
# 3790      2361.0  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000
# 3791      2383.0  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000
#
#         job_Range                                    full_add        Lat  \
# 0     500 or more    10 Davol Square Suite 300, Providnce, RI  41.804245
# 1      250 to 499                  110 ELM ST, PROVIDENCE, RI  41.817000
# 2      250 to 499              1160 CRANSTON ST, CRANSTON, RI  41.795063
# 3      250 to 499  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700
# 4      250 to 499      100 Royal Little Drive, PROVIDENCE, RI  41.847070
# ...           ...                                         ...        ...
# 3787     10 to 19       380 Jefferson Blvd Ste C, Warwick, RI  41.738247
# 3788     10 to 19    816 Middle Rd Unit 5, East Greenwich, RI  41.645916
# 3789     10 to 19                 12 GAVITT AVE, WESTERLY, RI  41.383280
# 3790     10 to 19               1065 WARWICK AVE, WARWICK, RI  41.746986
# 3791     10 to 19              1191 Pontiac Ave, Cranston, RI  41.752150
#
#            Long      FIPS_z_x  FIPS_z_y             FIPS_z
# 0    -71.420240  4.400700e+14       NaN  440070003022004.0
# 1    -71.410620  4.400700e+14       NaN  440070006001018.0
# 2    -71.449750  4.400701e+14       NaN  440070141003052.0
# 3    -71.375510  4.400701e+14       NaN  440070105021015.0
# 4    -71.413536  4.400700e+14       NaN  440070029004015.0
# ...         ...           ...       ...                ...
# 3787 -71.439550  4.400302e+14       NaN  440030211004009.0
# 3788 -71.489230  4.400302e+14       NaN  440030209032001.0
# 3789 -71.820860  4.400905e+14       NaN  440090508012001.0
# 3790 -71.405410  4.400302e+14       NaN  440030212002020.0
# 3791 -71.451416  4.400701e+14       NaN  440070142002001.0
#
# [3792 rows x 76 columns]

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
#fips_merge_drop = fips_merge_drop.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0              0        777541          777541            777541  9179517702
# 1              1        777542          777542            777542  9713307002
# 2              2        777543          777543            777543  5711067207
# 3              3        777544          777544            777544  4819187009
# 4              4        777545          777545            777545  3895377102
# ...          ...           ...             ...               ...         ...
# 3787        3787        781328          781328            781328  8379078305
# 3788        3788        781329          781329            781329  8836008607
# 3789        3789        781330          781330            781330  8960777006
# 3790        3790        781331          781331            781331  9102547103
# 3791        3791        781332          781332            781332  9451938303
#
#      DateApproved  SBAOfficeCode ProcessingMethod  \
# 0          5/1/20            165              PPP
# 1          4/9/20            165              PPP
# 2         4/27/20            165              PPP
# 3          4/4/20            165              PPP
# 4         4/12/20            165              PPP
# ...           ...            ...              ...
# 3787      1/29/21            165              PPS
# 3788      3/25/21            165              PPS
# 3789       4/9/20            165              PPP
# 3790      4/15/20            165              PPP
# 3791      1/30/21            165              PPS
#
#                            BorrowerName            BorrowerAddress  ...  \
# 0                 COASTAL MEDICAL, INC.  10 Davol Square Suite 300  ...
# 1                        BROWN MEDICINE                 110 ELM ST  ...
# 2                              TACO INC           1160 CRANSTON ST  ...
# 3          UNIVERSITY ORTHOPEDICS, INC.      1 Kettle Point Avenue  ...
# 4                  H. CARR & SONS, INC.     100 Royal Little Drive  ...
# ...                                 ...                        ...  ...
# 3787            GRAPHIC INNOVATIONS INC   380 Jefferson Blvd Ste C  ...
# 3788            NEW ENGLAND DRYWALL CO.       816 Middle Rd Unit 5  ...
# 3789  WATER DAMAGE DRYING SERVICES INC.              12 GAVITT AVE  ...
# 3790             STORMTITE COMPANY INC.           1065 WARWICK AVE  ...
# 3791              RUGGIERI FLOORING INC           1191 Pontiac Ave  ...
#
#               TRIIndustrySector  \
# 0                     999 Other
# 1                     999 Other
# 2                 333 Machinery
# 3                     999 Other
# 4                     999 Other
# ...                         ...
# 3787  323 Printing & Publishing
# 3788                  999 Other
# 3789                  999 Other
# 3790                  999 Other
# 3791                  999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0                            6211 Offices of Physicians       6211.0
# 1                            6211 Offices of Physicians       6211.0
# 2     3334 Ventilation, Heating, Air-Conditioning, a...       3334.0
# 3                            6211 Offices of Physicians       6211.0
# 4                   2383 Building Finishing Contractors       2383.0
# ...                                                 ...          ...
# 3787       3231 Printing and Related Support Activities       3231.0
# 3788                2383 Building Finishing Contractors       2383.0
# 3789             2389 Other Specialty Trade Contractors       2389.0
# 3790             2361 Residential Building Construction       2361.0
# 3791                2383 Building Finishing Contractors       2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     RHODE ISLAND DISTRICT OFFICE     e $5-10 million  500 or more
# 1     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 2     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 3     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# 4     RHODE ISLAND DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                            ...                 ...          ...
# 3787  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3788  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3789  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3790  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 3791  RHODE ISLAND DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                         full_add        Lat       Long  \
# 0       10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                     110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2                 1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3     1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4         100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
# ...                                          ...        ...        ...
# 3787       380 Jefferson Blvd Ste C, Warwick, RI  41.738247 -71.439550
# 3788    816 Middle Rd Unit 5, East Greenwich, RI  41.645916 -71.489230
# 3789                 12 GAVITT AVE, WESTERLY, RI  41.383280 -71.820860
# 3790               1065 WARWICK AVE, WARWICK, RI  41.746986 -71.405410
# 3791              1191 Pontiac Ave, Cranston, RI  41.752150 -71.451416
#
#                  FIPS_z
# 0     440070003022004.0
# 1     440070006001018.0
# 2     440070141003052.0
# 3     440070105021015.0
# 4     440070029004015.0
# ...                 ...
# 3787  440030211004009.0
# 3788  440030209032001.0
# 3789  440090508012001.0
# 3790  440030212002020.0
# 3791  440070142002001.0
#
# [3792 rows x 74 columns]

# %%
#fips_merge_drop = fips_merge.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop.loc[fips_merge["FIPS_z"].isnull()] #verify #27 , notna #22799 / 22826
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, Unnamed: 0.1.1.1, LoanNumber, DateApproved, SBAOfficeCode, ProcessingMethod, BorrowerName, BorrowerAddress, BorrowerCity, BorrowerState, BorrowerZip, LoanStatusDate, LoanStatus, Term, SBAGuarantyPercentage, InitialApprovalAmount, CurrentApprovalAmount, UndisbursedAmount, FranchiseName, ServicingLenderLocationID, ServicingLenderName, ServicingLenderAddress, ServicingLenderCity, ServicingLenderState, ServicingLenderZip, RuralUrbanIndicator, HubzoneIndicator, LMIIndicator, BusinessAgeDescription, ProjectCity, ProjectCountyName, ProjectState, ProjectZip, CD, JobsReported, NAICSCode, Race, Ethnicity, UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED, DEBT_INTEREST_PROCEED, BusinessType, OriginatingLenderLocationID, OriginatingLender, OriginatingLenderCity, OriginatingLenderState, Gender, Veteran, NonProfit, ForgivenessAmount, ForgivenessDate, NA, Estimated_LenderPercent, Estimated_LenderProfit, DateApproved_ts, ForgivenessDate_ts, Industry, LongName, TRIIndustrySector, IndustrySubsector, 4DigitNAICS, SBAOfficeLabel, Loan_Range, job_Range, full_add, Lat, Long, FIPS_z]
# Index: []
#
# [0 rows x 74 columns]

# %% [markdown]
# Convert to File

# %%
fips_ri = fips_merge_drop

# %%
fips_ri.to_csv("../../data/state_data/geo/geo_fips/RI_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_ri_fips = pd.read_csv("../../data/state_data/geo/geo_fips/RI_fips_scraped.csv") 
geo_ri_fips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0          777541            777541
# 1           1             1          777542            777542
# 2           2             2          777543            777543
# 3           3             3          777544            777544
# 4           4             4          777545            777545
#
#    Unnamed: 0.1.1.1.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0              777541  9179517702       5/1/20            165
# 1              777542  9713307002       4/9/20            165
# 2              777543  5711067207      4/27/20            165
# 3              777544  4819187009       4/4/20            165
# 4              777545  3895377102      4/12/20            165
#
#   ProcessingMethod                  BorrowerName  ... TRIIndustrySector  \
# 0              PPP         COASTAL MEDICAL, INC.  ...         999 Other
# 1              PPP                BROWN MEDICINE  ...         999 Other
# 2              PPP                      TACO INC  ...     333 Machinery
# 3              PPP  UNIVERSITY ORTHOPEDICS, INC.  ...         999 Other
# 4              PPP          H. CARR & SONS, INC.  ...         999 Other
#
#                                    IndustrySubsector 4DigitNAICS  \
# 0                         6211 Offices of Physicians      6211.0
# 1                         6211 Offices of Physicians      6211.0
# 2  3334 Ventilation, Heating, Air-Conditioning, a...      3334.0
# 3                         6211 Offices of Physicians      6211.0
# 4                2383 Building Finishing Contractors      2383.0
#
#                  SBAOfficeLabel       Loan_Range    job_Range  \
# 0  RHODE ISLAND DISTRICT OFFICE  e $5-10 million  500 or more
# 1  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 2  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 3  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
# 4  RHODE ISLAND DISTRICT OFFICE  e $5-10 million   250 to 499
#
#                                      full_add        Lat       Long  \
# 0    10 Davol Square Suite 300, Providnce, RI  41.804245 -71.420240
# 1                  110 ELM ST, PROVIDENCE, RI  41.817000 -71.410620
# 2              1160 CRANSTON ST, CRANSTON, RI  41.795063 -71.449750
# 3  1 Kettle Point Avenue, EAST PROVIDENCE, RI  41.796700 -71.375510
# 4      100 Royal Little Drive, PROVIDENCE, RI  41.847070 -71.413536
#
#          FIPS_z
# 0  4.400700e+14
# 1  4.400700e+14
# 2  4.400701e+14
# 3  4.400701e+14
# 4  4.400700e+14
#
# [5 rows x 75 columns]

# %%
##### fill in missing Lat, Long, FIPS
geo_ri_fips.loc[geo_ri_fips["FIPS_z"].isnull()] #27
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Unnamed: 0.1.1, Unnamed: 0.1.1.1, Unnamed: 0.1.1.1.1, LoanNumber, DateApproved, SBAOfficeCode, ProcessingMethod, BorrowerName, BorrowerAddress, BorrowerCity, BorrowerState, BorrowerZip, LoanStatusDate, LoanStatus, Term, SBAGuarantyPercentage, InitialApprovalAmount, CurrentApprovalAmount, UndisbursedAmount, FranchiseName, ServicingLenderLocationID, ServicingLenderName, ServicingLenderAddress, ServicingLenderCity, ServicingLenderState, ServicingLenderZip, RuralUrbanIndicator, HubzoneIndicator, LMIIndicator, BusinessAgeDescription, ProjectCity, ProjectCountyName, ProjectState, ProjectZip, CD, JobsReported, NAICSCode, Race, Ethnicity, UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED, DEBT_INTEREST_PROCEED, BusinessType, OriginatingLenderLocationID, OriginatingLender, OriginatingLenderCity, OriginatingLenderState, Gender, Veteran, NonProfit, ForgivenessAmount, ForgivenessDate, NA, Estimated_LenderPercent, Estimated_LenderProfit, DateApproved_ts, ForgivenessDate_ts, Industry, LongName, TRIIndustrySector, IndustrySubsector, 4DigitNAICS, SBAOfficeLabel, Loan_Range, job_Range, full_add, Lat, Long, FIPS_z]
# Index: []
#
# [0 rows x 75 columns]
