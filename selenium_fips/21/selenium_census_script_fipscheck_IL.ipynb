# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_il.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0"], axis =1) 
fips_check.head() #10912
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9724667708       5/1/20            101              PPP
# 1  1060027105       4/9/20            507              PPP
# 2  1255837210      4/15/20            507              PPP
# 3  1314447103      4/10/20            507              PPP
# 4  2083627203      4/15/20            507              PPP
#
#                                 BorrowerName  \
# 0           FERNANDINA BEACH HOTEL GROUP LLC
# 1                         MVP WORKFORCE, LLC
# 2                            PLS GROUP, INC.
# 3             RELIABLE STAFFING SERVICES INC
# 4  LAUNCH TECHNICAL WORKFORCE SOLUTIONS, LLC
#
#                       BorrowerAddress       BorrowerCity BorrowerState  \
# 0               55 East Jackson Blvd             Chicago            IL
# 1       1751 Lake Cook Road Suite 600          DEERFIELD            IL
# 2  One South Wacker Drive, 36th Floor            CHICAGO            IL
# 3                     870 Oak ST. 0.0  Lake in the Hills            IL
# 4        700 Commerce Drive Suite 140          Oak Brook            IL
#
#    BorrowerZip LoanStatusDate  ...  \
# 0          NaN        8/17/21  ...
# 1      60015.0        7/17/21  ...
# 2      60606.0       10/19/21  ...
# 3      60156.0            NaN  ...
# 4      60523.0       10/20/21  ...
#
#                                             LongName  \
# 0          Hotels (except Casino Hotels) and Motels
# 1                     Employment Placement Agencies
# 2  Other Activities Related to Credit Intermediat...
# 3                     Employment Placement Agencies
# 4                            Aircraft Manufacturing
#
#               TRIIndustrySector  \
# 0                     999 Other
# 1                     999 Other
# 2                     999 Other
# 3                     999 Other
# 4  336 Transportation Equipment
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0                        7211 Traveler Accommodation       7211.0
# 1                           5613 Employment Services       5613.0
# 2  5223 Activities Related to Credit Intermediation        5223.0
# 3                           5613 Employment Services       5613.0
# 4     3364 Aerospace Product and Parts Manufacturing       3364.0
#
#                   SBAOfficeLabel          Loan_Range    job_Range  \
# 0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 1       ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 2       ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 3       ILLINOIS DISTRICT OFFICE     e $5-10 million   250 to 499
# 4       ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
#
#                                           full_add        Lat       Long
# 0               55 East Jackson Blvd , Chicago, IL  41.878011 -87.625465
# 1     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930 -87.870512
# 2  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166 -87.636672
# 3           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417 -88.309248
# 4      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485 -87.937622
#
# [5 rows x 69 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan
# Out:
#        LoanNumber                                   full_add  Lat  Long
# 9815   8342537301  7000 S ADAMS ST STE 250, WILLOW BROOK, IL  NaN   NaN
# 33678  2821508310                          847, EVANSTON, IL  NaN   NaN

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #10904
# Out:
#    LoanNumber                                         full_add        Lat  \
# 0  9724667708               55 East Jackson Blvd , Chicago, IL  41.878011
# 1  1060027105     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930
# 2  1255837210  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166
# 3  1314447103           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417
# 4  2083627203      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485
#
#         Long
# 0 -87.625465
# 1 -87.870512
# 2 -87.636672
# 3 -88.309248
# 4 -87.937622

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("data/state_data/geo/geo_fips/IL_fips_scraped.csv") 
fips_check_scraped.head()

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #40813

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #1239

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
    
executable_path = {'executable_path': ChromeDriverManager().install()}
driver = Browser('chrome', **executable_path, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('_x_id').clear()
        driver.find_by_id('_y_id').clear()
        driver.find_by_id('_x_id').fill(long[i])
        driver.find_by_id('_y_id').fill(lat[i])
        driver.find_by_id('proceed').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='pl_gov_census_geo_geocoder_domain_GeographyResult')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('17')] #IL
            fips_elements =[element for element in startswith if len(element)==15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                print(f"{i},{lat[i]},{long[i]} Not Found")
                notfound.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/99.0.4844.51/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/ciaraspencer/.wdm/drivers/chromedriver/mac64/99.0.4844.51]
# HBox(children=(FloatProgress(value=0.0, max=40813.0), HTML(value='')))

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 40813

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:1239]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
# <ipython-input-11-08e9c917fe2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fips_fill["FIPS_z"] = geo_id_list
#        LoanNumber                                         full_add        Lat  \
# 0      9724667708               55 East Jackson Blvd , Chicago, IL  41.878011
# 1      1060027105     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930
# 2      1255837210  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166
# 3      1314447103           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417
# 4      2083627203      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485
# ...           ...                                              ...        ...
# 40810  9752217002         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038
# 40811  9780317408                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393
# 40812  9883677109          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747
# 40813  9887958310                     2095 N Rand Rd, Palatine, IL  42.148603
# 40814  9996588403        17070 S Park Ave Ste E, South Holland, IL  41.584893
#
#             Long             FIPS_z
# 0     -87.625465  [170313204001021]
# 1     -87.870512  [170318016011002]
# 2     -87.636672  [170318391002007]
# 3     -88.309248  [171118712051000]
# 4     -87.937622  [170438446011053]
# ...          ...                ...
# 40810 -87.941377  [170438400002003]
# 40811 -88.027819  [170438458082006]
# 40812 -88.047553  [170318046033000]
# 40813 -88.030347  [170318036083005]
# 40814 -87.607775  [170318278051011]
#
# [40813 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
#fips_fill['FIPS_z'] = geo_id
fips_loc = fips_fill
#coordinates with more than one return:
test = fips_loc[fips_loc['FIPS_z'].str.len() > 1]
test
# Out:
#        LoanNumber                            full_add        Lat       Long  \
# 46     6786427000           1501 RIVER DR, MOLINE, IL  41.508526 -90.517157
# 274    8853117001    120 E Clark Street, FREEPORT, IL  42.301466 -89.620088
# 286    6899737006       300 Hamilton Blvd, PEORIA, IL  40.693498 -89.588734
# 317    2412247100       1200 W STATE ST, ROCKFORD, IL  42.275120 -89.108312
# 337    7881847000  766 Research Parkway, ROCKFORD, IL  42.218582 -89.085242
# ...           ...                                 ...        ...        ...
# 40590  1642518302          201 E 3rd St, Sterling, IL  41.788415 -89.692748
# 40601  1977747100          201 N 6th St, ROCKFORD, IL  42.268593 -89.081328
# 40692  4755497204         4370 7th Street, MOLINE, IL  41.467211 -90.526233
# 40712  6000388301          621 Main St, Hillsdale, IL  41.612486 -90.190552
# 40760  7717837104          621 MAIN ST, HILLSDALE, IL  41.612486 -90.190552
#
#                                    FIPS_z
# 46     [179494934492020, 171610223001041]
# 274    [179494934492020, 171770008003002]
# 286    [179494934492020, 171430012002031]
# 317    [179494934492020, 172010026002007]
# 337    [179494934492020, 172019800001003]
# ...                                   ...
# 40590  [179494934492020, 171950011022079]
# 40601  [179494934492020, 172010011001000]
# 40692  [179494934492020, 171610219001063]
# 40712  [179494934492020, 171610201011013]
# 40760  [179494934492020, 171610201011013]
#
# [1597 rows x 5 columns]

# %%
test[['FIPS_w','FIPS_x', 'FIPS_y', 'FIPS_z']]  = test['FIPS_z'].apply(lambda x: pd.Series(str(x).split(",")))
test

# %%
pd.set_option('display.max_rows', 1600)
test

# %%
test = test.drop(['FIPS_w','FIPS_z'], axis=1)
test["FIPS_z"] = test["FIPS_y"]
test['FIPS_z']= test['FIPS_z'].replace(']', '', regex=True)
test['FIPS_z']= test['FIPS_z'].replace(' ', '', regex=True)
test['FIPS_z']= test['FIPS_z'].replace("'", '', regex=True)
test

# %%
test['FIPS_z']= test['FIPS_z'].fillna(test['FIPS_x'])
test['FIPS_z']= test['FIPS_z'].replace(']', '', regex=True)
test['FIPS_z']= test['FIPS_z'].replace(' ', '', regex=True)
test['FIPS_z']= test['FIPS_z'].replace("'", '', regex=True)
test

# %%
cols = ['LoanNumber', 'FIPS_z']
test = test[cols]
test

# %%
fips_check_notna = fips_check_notna.merge(test, on="LoanNumber", how="left")
fips_check_notna
# Out:
#        LoanNumber                                         full_add        Lat  \
# 0      9724667708               55 East Jackson Blvd , Chicago, IL  41.878011
# 1      1060027105     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930
# 2      1255837210  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166
# 3      1314447103           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417
# 4      2083627203      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485
# ...           ...                                              ...        ...
# 40808  9752217002         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038
# 40809  9780317408                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393
# 40810  9883677109          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747
# 40811  9887958310                     2095 N Rand Rd, Palatine, IL  42.148603
# 40812  9996588403        17070 S Park Ave Ste E, South Holland, IL  41.584893
#
#             Long FIPS_z
# 0     -87.625465    NaN
# 1     -87.870512    NaN
# 2     -87.636672    NaN
# 3     -88.309248    NaN
# 4     -87.937622    NaN
# ...          ...    ...
# 40808 -87.941377    NaN
# 40809 -88.027819    NaN
# 40810 -88.047553    NaN
# 40811 -88.030347    NaN
# 40812 -87.607775    NaN
#
# [40813 rows x 5 columns]

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
#        LoanNumber                                         full_add        Lat  \
# 0      9724667708               55 East Jackson Blvd , Chicago, IL  41.878011
# 1      1060027105     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930
# 2      1255837210  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166
# 3      1314447103           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417
# 4      2083627203      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485
# ...           ...                                              ...        ...
# 40810  9752217002         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038
# 40811  9780317408                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393
# 40812  9883677109          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747
# 40813  9887958310                     2095 N Rand Rd, Palatine, IL  42.148603
# 40814  9996588403        17070 S Park Ave Ste E, South Holland, IL  41.584893
#
#             Long           FIPS_z
# 0     -87.625465  170313204001021
# 1     -87.870512  170318016011002
# 2     -87.636672  170318391002007
# 3     -88.309248  171118712051000
# 4     -87.937622  170438446011053
# ...          ...              ...
# 40810 -87.941377  170438400002003
# 40811 -88.027819  170438458082006
# 40812 -88.047553  170318046033000
# 40813 -88.030347  170318036083005
# 40814 -87.607775  170318278051011
#
# [40813 rows x 5 columns]

# %%
fips_fill= fips_fill[cols]
fips_fill
# Out:
#        LoanNumber           FIPS_z
# 0      9724667708  170313204001021
# 1      1060027105  170318016011002
# 2      1255837210  170318391002007
# 3      1314447103  171118712051000
# 4      2083627203  170438446011053
# ...           ...              ...
# 40810  9752217002  170438400002003
# 40811  9780317408  170438458082006
# 40812  9883677109  170318046033000
# 40813  9887958310  170318036083005
# 40814  9996588403  170318278051011
#
# [40813 rows x 2 columns]

# %%
fips_check_notna = fips_check_notna.merge(fips_fill, on="LoanNumber", how="left")

# %%
fips_check_notna["FIPS_z"] = fips_check_notna["FIPS_z_x"].fillna(fips_check_notna["FIPS_z_y"])
fips_check_notna = fips_check_notna.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
fips_check_notna
# Out:
#        LoanNumber                                         full_add        Lat  \
# 0      9724667708               55 East Jackson Blvd , Chicago, IL  41.878011
# 1      1060027105     1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930
# 2      1255837210  One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166
# 3      1314447103           870 Oak ST. 0.0, Lake in the Hills, IL  42.189417
# 4      2083627203      700 Commerce Drive Suite 140, Oak Brook, IL  41.851485
# ...           ...                                              ...        ...
# 40808  9752217002         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038
# 40809  9780317408                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393
# 40810  9883677109          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747
# 40811  9887958310                     2095 N Rand Rd, Palatine, IL  42.148603
# 40812  9996588403        17070 S Park Ave Ste E, South Holland, IL  41.584893
#
#             Long           FIPS_z
# 0     -87.625465  170313204001021
# 1     -87.870512  170318016011002
# 2     -87.636672  170318391002007
# 3     -88.309248  171118712051000
# 4     -87.937622  170438446011053
# ...          ...              ...
# 40808 -87.941377  170438400002003
# 40809 -88.027819  170438458082006
# 40810 -88.047553  170318046033000
# 40811 -88.030347  170318036083005
# 40812 -87.607775  170318278051011
#
# [40813 rows x 5 columns]

# %%
fips_check_notna.loc[fips_check_notna["FIPS_z"].isnull()] #check
# Out:
#        LoanNumber                                           full_add  \
# 1330   4357417000             18960 County Hwy 5 W, EAST DUBUQUE, IL
# 1978   6227707103                 22069 US HIGHWAY 34, PRINCETON, IL
# 2002   4428188509                 22069 US Highway 34, Princeton, IL
# 2088   3984847201                      14 N 845 US-20, Hampshire, IL
# 3153   2252087100                   14 N 850 Route 20, HAMPSHIRE, IL
# 3197   3313488304                    43451 N US Highway 41, Zion, IL
# 3559   6478417409         1501 W. MAIN ST PO Drawer E, FAIRFIELD, IL
# 3631   6829277004                      43451 US HIGHWAY 41, ZION, IL
# 3813   6463967004               11600 Sterling Parkway, RICHMOND, IL
# 3844   7639977104                  7505 S Us Highway 66, GARDNER, IL
# 4115   4791837000                     11022 S. Route 20, MARENGO, IL
# 4723   7249568405  4508 W 46th St 6445 E Houghton Lake Dr Houghto...
# 9232   4263327203                     2000 US HIGHWAY 30, OSWEGO, IL
# 9974   5924068305      43 W 752 Highway 30 Suite 2F, Sugar Grove, IL
# 10511  1957667103            43 W 730 US Highway 30, SUGAR GROVE, IL
# 10880  5482217101                         215 Elmwood Ave, UNION, IL
# 12048  1328317808            1200 West Linden Avenue, Logansport, IL
# 12767  4808097109                   1000 E. US Highway 34, PLANO, IL
# 15035  9164158400                    1000 E US Highway 34, Plano, IL
# 17725  6090997009        1980 W US HWY 30, Suite 11, SUGAR GROVE, IL
# 17854  2112178304                    18162 Harwood Ave, Homewood, IL
# 18066  9354057704                         639 W MAIN ST, BATAVIA, IL
# 19607  1774927705  C/O La Forice Nealy 6310 S CLAREMONT AVE, CHIC...
# 19847  3557387102  3000 woodcreek drive, Suite 300, Downers Grove...
# 20454  4735788305                         2290 Point Blvd, Elgin, IL
# 27837  6400167101         16 Technology Drive  Suite 111, Irvine, IL
# 28094  1199707810                   105 E JOILET ST, SCHEREVILLE, IL
# 35668  2391268309                             2850 US-34, OSWEGO, IL
# 35842  3209857105                 47619 W. US Route 30, BIG ROCK, IL
# 37833  2408737701                 7736 STATE ROUTE 34, YORKVILLE, IL
# 38087  4389107300                         301 S PARK ST, GIFFORD, IL
# 39259  2174297707              4937 WILSHIRE BLVD, CNTRY CLB HLS, IL
# 40462  5068958308                 1410 US Highway 45 N, Eldorado, IL
# 40796  9418607006                 47 W 529 US Route 30, BIG ROCK, IL
#
#              Lat        Long FIPS_z
# 1330   42.508105  -90.565332    NaN
# 1978   40.392967 -104.634462    NaN
# 2002   40.392967 -104.634462    NaN
# 2088   44.370091 -108.038415    NaN
# 3153   42.468637  -73.419886    NaN
# 3197   35.242488  -85.690479    NaN
# 3559   38.033561  -78.497707    NaN
# 3631   47.046908  -88.518619    NaN
# 3813   42.495414  -88.320057    NaN
# 3844   36.145096  -96.002364    NaN
# 4115   42.902196 -106.494403    NaN
# 4723   44.369346  -84.692139    NaN
# 9232   41.830975  -90.701615    NaN
# 9974   42.063715  -94.857290    NaN
# 10511  41.468463  -87.207119    NaN
# 10880  40.698010  -74.280309    NaN
# 12048  40.755215  -86.385976    NaN
# 12767  41.026674  -94.014404    NaN
# 15035  41.026674  -94.014404    NaN
# 17725  39.858227  -77.298102    NaN
# 17854  41.559420  -87.668894    NaN
# 18066  38.031585  -78.489502    NaN
# 19607  41.778938  -87.682691    NaN
# 19847  41.831377  -88.035963    NaN
# 20454  42.083396  -88.333610    NaN
# 27837  33.650602 -117.736467    NaN
# 28094  41.492044  -87.448921    NaN
# 35668  40.997234  -91.815673    NaN
# 35842  44.956449 -117.938204    NaN
# 37833  43.055693  -76.558131    NaN
# 38087  43.063867  -89.400267    NaN
# 39259  34.062174 -118.338767    NaN
# 40462  45.526731  -89.161915    NaN
# 40796  40.451443  -80.251737    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_check_notna[cols]
fips_fill_parsed
# Out:
#        LoanNumber           FIPS_z
# 0      9724667708  170313204001021
# 1      1060027105  170318016011002
# 2      1255837210  170318391002007
# 3      1314447103  171118712051000
# 4      2083627203  170438446011053
# ...           ...              ...
# 40808  9752217002  170438400002003
# 40809  9780317408  170438458082006
# 40810  9883677109  170318046033000
# 40811  9887958310  170318036083005
# 40812  9996588403  170318278051011
#
# [40813 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_il.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check

#if from FIPS file
#fips_check = pd.read_csv("data/state_data/geo/geo_fips/IL_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #15796
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0              11            11  9724667708       5/1/20            101
# 1          309918        309918  1060027105       4/9/20            507
# 2          309919        309919  1255837210      4/15/20            507
# 3          309920        309920  1314447103      4/10/20            507
# 4          309921        309921  2083627203      4/15/20            507
# ...           ...           ...         ...          ...            ...
# 40810      350727        350727  9752217002       4/9/20            507
# 40811      350728        350728  9780317408      5/20/20            507
# 40812      350729        350729  9883677109      4/15/20            507
# 40813      350730        350730  9887958310      1/31/21            507
# 40814      350731        350731  9996588403      2/18/21            507
#
#       ProcessingMethod                               BorrowerName  \
# 0                  PPP           FERNANDINA BEACH HOTEL GROUP LLC
# 1                  PPP                         MVP WORKFORCE, LLC
# 2                  PPP                            PLS GROUP, INC.
# 3                  PPP             RELIABLE STAFFING SERVICES INC
# 4                  PPP  LAUNCH TECHNICAL WORKFORCE SOLUTIONS, LLC
# ...                ...                                        ...
# 40810              PPP                           D & S WIRE, INC.
# 40811              PPP         PREFERRED METAL TECHNOLOGIES, INC.
# 40812              PPP            CORE PSYCHOTHERAPY CENTER, LTD.
# 40813              PPS        THE  ARLINGTON AUTOMOTIVE GROUP INC
# 40814              PPS               OUR NATION'S ENTERPRISE INC.
#
#                           BorrowerAddress       BorrowerCity BorrowerState  \
# 0                   55 East Jackson Blvd             Chicago            IL
# 1           1751 Lake Cook Road Suite 600          DEERFIELD            IL
# 2      One South Wacker Drive, 36th Floor            CHICAGO            IL
# 3                         870 Oak ST. 0.0  Lake in the Hills            IL
# 4            700 Commerce Drive Suite 140          Oak Brook            IL
# ...                                   ...                ...           ...
# 40810                   2531 E. Devon Ave  ELK GROVE VILLAGE            IL
# 40811                  9341 Adam Don Pkwy          WOODRIDGE            IL
# 40812             1305 WILEY ROAD STE 125         SCHAUMBURG            IL
# 40813                      2095 N Rand Rd           Palatine            IL
# 40814              17070 S Park Ave Ste E      South Holland            IL
#
#        ...                                           LongName  \
# 0      ...          Hotels (except Casino Hotels) and Motels
# 1      ...                     Employment Placement Agencies
# 2      ...  Other Activities Related to Credit Intermediat...
# 3      ...                     Employment Placement Agencies
# 4      ...                            Aircraft Manufacturing
# ...    ...                                                ...
# 40810  ...                                Steel Wire Drawing
# 40811  ...  Plumbing, Heating, and Air-Conditioning Contra...
# 40812  ...  Offices of Physicians, Mental Health Specialists
# 40813  ...                                   New Car Dealers
# 40814  ...           Offices of Certified Public Accountants
#
#                   TRIIndustrySector  \
# 0                         999 Other
# 1                         999 Other
# 2                         999 Other
# 3                         999 Other
# 4      336 Transportation Equipment
# ...                             ...
# 40810            331 Primary Metals
# 40811                     999 Other
# 40812                     999 Other
# 40813                     999 Other
# 40814                     999 Other
#
#                                        IndustrySubsector  4DigitNAICS  \
# 0                            7211 Traveler Accommodation       7211.0
# 1                               5613 Employment Services       5613.0
# 2      5223 Activities Related to Credit Intermediation        5223.0
# 3                               5613 Employment Services       5613.0
# 4         3364 Aerospace Product and Parts Manufacturing       3364.0
# ...                                                  ...          ...
# 40810  3312 Steel Product Manufacturing from Purchase...       3312.0
# 40811                2382 Building Equipment Contractors       2382.0
# 40812                         6211 Offices of Physicians       6211.0
# 40813                           4411 Automobile Dealers        4411.0
# 40814  5412 Accounting, Tax Preparation, Bookkeeping,...       5412.0
#
#                       SBAOfficeLabel          Loan_Range    job_Range  \
# 0      MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 1           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 2           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 3           ILLINOIS DISTRICT OFFICE     e $5-10 million   250 to 499
# 4           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# ...                              ...                 ...          ...
# 40810       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40811       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   250 to 499
# 40812       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40813       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   100 to 249
# 40814       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                               full_add        Lat       Long
# 0                   55 East Jackson Blvd , Chicago, IL  41.878011 -87.625465
# 1         1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930 -87.870512
# 2      One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166 -87.636672
# 3               870 Oak ST. 0.0, Lake in the Hills, IL  42.189417 -88.309248
# 4          700 Commerce Drive Suite 140, Oak Brook, IL  41.851485 -87.937622
# ...                                                ...        ...        ...
# 40810         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038 -87.941377
# 40811                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393 -88.027819
# 40812          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747 -88.047553
# 40813                     2095 N Rand Rd, Palatine, IL  42.148603 -88.030347
# 40814        17070 S Park Ave Ste E, South Holland, IL  41.584893 -87.607775
#
# [40815 rows x 71 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0              11            11  9724667708       5/1/20            101
# 1          309918        309918  1060027105       4/9/20            507
# 2          309919        309919  1255837210      4/15/20            507
# 3          309920        309920  1314447103      4/10/20            507
# 4          309921        309921  2083627203      4/15/20            507
# ...           ...           ...         ...          ...            ...
# 40810      350727        350727  9752217002       4/9/20            507
# 40811      350728        350728  9780317408      5/20/20            507
# 40812      350729        350729  9883677109      4/15/20            507
# 40813      350730        350730  9887958310      1/31/21            507
# 40814      350731        350731  9996588403      2/18/21            507
#
#       ProcessingMethod                               BorrowerName  \
# 0                  PPP           FERNANDINA BEACH HOTEL GROUP LLC
# 1                  PPP                         MVP WORKFORCE, LLC
# 2                  PPP                            PLS GROUP, INC.
# 3                  PPP             RELIABLE STAFFING SERVICES INC
# 4                  PPP  LAUNCH TECHNICAL WORKFORCE SOLUTIONS, LLC
# ...                ...                                        ...
# 40810              PPP                           D & S WIRE, INC.
# 40811              PPP         PREFERRED METAL TECHNOLOGIES, INC.
# 40812              PPP            CORE PSYCHOTHERAPY CENTER, LTD.
# 40813              PPS        THE  ARLINGTON AUTOMOTIVE GROUP INC
# 40814              PPS               OUR NATION'S ENTERPRISE INC.
#
#                           BorrowerAddress       BorrowerCity BorrowerState  \
# 0                   55 East Jackson Blvd             Chicago            IL
# 1           1751 Lake Cook Road Suite 600          DEERFIELD            IL
# 2      One South Wacker Drive, 36th Floor            CHICAGO            IL
# 3                         870 Oak ST. 0.0  Lake in the Hills            IL
# 4            700 Commerce Drive Suite 140          Oak Brook            IL
# ...                                   ...                ...           ...
# 40810                   2531 E. Devon Ave  ELK GROVE VILLAGE            IL
# 40811                  9341 Adam Don Pkwy          WOODRIDGE            IL
# 40812             1305 WILEY ROAD STE 125         SCHAUMBURG            IL
# 40813                      2095 N Rand Rd           Palatine            IL
# 40814              17070 S Park Ave Ste E      South Holland            IL
#
#        ...             TRIIndustrySector  \
# 0      ...                     999 Other
# 1      ...                     999 Other
# 2      ...                     999 Other
# 3      ...                     999 Other
# 4      ...  336 Transportation Equipment
# ...    ...                           ...
# 40810  ...            331 Primary Metals
# 40811  ...                     999 Other
# 40812  ...                     999 Other
# 40813  ...                     999 Other
# 40814  ...                     999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 0                            7211 Traveler Accommodation      7211.0
# 1                               5613 Employment Services      5613.0
# 2      5223 Activities Related to Credit Intermediation       5223.0
# 3                               5613 Employment Services      5613.0
# 4         3364 Aerospace Product and Parts Manufacturing      3364.0
# ...                                                  ...         ...
# 40810  3312 Steel Product Manufacturing from Purchase...      3312.0
# 40811                2382 Building Equipment Contractors      2382.0
# 40812                         6211 Offices of Physicians      6211.0
# 40813                           4411 Automobile Dealers       4411.0
# 40814  5412 Accounting, Tax Preparation, Bookkeeping,...      5412.0
#
#                       SBAOfficeLabel          Loan_Range    job_Range  \
# 0      MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 1           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 2           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 3           ILLINOIS DISTRICT OFFICE     e $5-10 million   250 to 499
# 4           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# ...                              ...                 ...          ...
# 40810       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40811       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   250 to 499
# 40812       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40813       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   100 to 249
# 40814       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                               full_add        Lat       Long  \
# 0                   55 East Jackson Blvd , Chicago, IL  41.878011 -87.625465
# 1         1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930 -87.870512
# 2      One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166 -87.636672
# 3               870 Oak ST. 0.0, Lake in the Hills, IL  42.189417 -88.309248
# 4          700 Commerce Drive Suite 140, Oak Brook, IL  41.851485 -87.937622
# ...                                                ...        ...        ...
# 40810         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038 -87.941377
# 40811                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393 -88.027819
# 40812          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747 -88.047553
# 40813                     2095 N Rand Rd, Palatine, IL  42.148603 -88.030347
# 40814        17070 S Park Ave Ste E, South Holland, IL  41.584893 -87.607775
#
#                 FIPS_z
# 0      170313204001021
# 1      170318016011002
# 2      170318391002007
# 3      171118712051000
# 4      170438446011053
# ...                ...
# 40810  170438400002003
# 40811  170438458082006
# 40812  170318046033000
# 40813  170318036083005
# 40814  170318278051011
#
# [40815 rows x 72 columns]

# %% [markdown]
# If FIPS Encoded

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge

fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
fips_merge_drop

# %% [markdown]
# Convert to File

# %%
geo_IL_fips = fips_merge

# %%
geo_IL_fips.to_csv("data/state_data/geo/geo_fips/IL_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_IL_fips.loc[geo_IL_fips["LoanNumber"] == 8477327904, "Lat"] = 37.37855
geo_IL_fips.loc[geo_IL_fips["LoanNumber"] == 8477327904, "Long"] = -89.161644
geo_IL_fips.loc[geo_IL_fips["LoanNumber"] == 8477327904, "FIPS_z"] = 171819505002071

# %%
geo_IL_fips = pd.read_csv("data/state_data/geo/geo_fips/IL_fips_scraped.csv") 
geo_IL_fips
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0               0            11              11  9724667708       5/1/20
# 1               1        309918          309918  1060027105       4/9/20
# 2               2        309919          309919  1255837210      4/15/20
# 3               3        309920          309920  1314447103      4/10/20
# 4               4        309921          309921  2083627203      4/15/20
# ...           ...           ...             ...         ...          ...
# 40810       40810        350727          350727  9752217002       4/9/20
# 40811       40811        350728          350728  9780317408      5/20/20
# 40812       40812        350729          350729  9883677109      4/15/20
# 40813       40813        350730          350730  9887958310      1/31/21
# 40814       40814        350731          350731  9996588403      2/18/21
#
#        SBAOfficeCode ProcessingMethod  \
# 0                101              PPP
# 1                507              PPP
# 2                507              PPP
# 3                507              PPP
# 4                507              PPP
# ...              ...              ...
# 40810            507              PPP
# 40811            507              PPP
# 40812            507              PPP
# 40813            507              PPS
# 40814            507              PPS
#
#                                     BorrowerName  \
# 0               FERNANDINA BEACH HOTEL GROUP LLC
# 1                             MVP WORKFORCE, LLC
# 2                                PLS GROUP, INC.
# 3                 RELIABLE STAFFING SERVICES INC
# 4      LAUNCH TECHNICAL WORKFORCE SOLUTIONS, LLC
# ...                                          ...
# 40810                           D & S WIRE, INC.
# 40811         PREFERRED METAL TECHNOLOGIES, INC.
# 40812            CORE PSYCHOTHERAPY CENTER, LTD.
# 40813        THE  ARLINGTON AUTOMOTIVE GROUP INC
# 40814               OUR NATION'S ENTERPRISE INC.
#
#                           BorrowerAddress       BorrowerCity  ...  \
# 0                   55 East Jackson Blvd             Chicago  ...
# 1           1751 Lake Cook Road Suite 600          DEERFIELD  ...
# 2      One South Wacker Drive, 36th Floor            CHICAGO  ...
# 3                         870 Oak ST. 0.0  Lake in the Hills  ...
# 4            700 Commerce Drive Suite 140          Oak Brook  ...
# ...                                   ...                ...  ...
# 40810                   2531 E. Devon Ave  ELK GROVE VILLAGE  ...
# 40811                  9341 Adam Don Pkwy          WOODRIDGE  ...
# 40812             1305 WILEY ROAD STE 125         SCHAUMBURG  ...
# 40813                      2095 N Rand Rd           Palatine  ...
# 40814              17070 S Park Ave Ste E      South Holland  ...
#
#                   TRIIndustrySector  \
# 0                         999 Other
# 1                         999 Other
# 2                         999 Other
# 3                         999 Other
# 4      336 Transportation Equipment
# ...                             ...
# 40810            331 Primary Metals
# 40811                     999 Other
# 40812                     999 Other
# 40813                     999 Other
# 40814                     999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 0                            7211 Traveler Accommodation      7211.0
# 1                               5613 Employment Services      5613.0
# 2      5223 Activities Related to Credit Intermediation       5223.0
# 3                               5613 Employment Services      5613.0
# 4         3364 Aerospace Product and Parts Manufacturing      3364.0
# ...                                                  ...         ...
# 40810  3312 Steel Product Manufacturing from Purchase...      3312.0
# 40811                2382 Building Equipment Contractors      2382.0
# 40812                         6211 Offices of Physicians      6211.0
# 40813                           4411 Automobile Dealers       4411.0
# 40814  5412 Accounting, Tax Preparation, Bookkeeping,...      5412.0
#
#                       SBAOfficeLabel          Loan_Range    job_Range  \
# 0      MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 1           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 2           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# 3           ILLINOIS DISTRICT OFFICE     e $5-10 million   250 to 499
# 4           ILLINOIS DISTRICT OFFICE     e $5-10 million  500 or more
# ...                              ...                 ...          ...
# 40810       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40811       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   250 to 499
# 40812       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 40813       ILLINOIS DISTRICT OFFICE  a $150,000-350,000   100 to 249
# 40814       ILLINOIS DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                               full_add        Lat       Long  \
# 0                   55 East Jackson Blvd , Chicago, IL  41.878011 -87.625465
# 1         1751 Lake Cook Road Suite 600, DEERFIELD, IL  42.150930 -87.870512
# 2      One South Wacker Drive, 36th Floor, CHICAGO, IL  41.878166 -87.636672
# 3               870 Oak ST. 0.0, Lake in the Hills, IL  42.189417 -88.309248
# 4          700 Commerce Drive Suite 140, Oak Brook, IL  41.851485 -87.937622
# ...                                                ...        ...        ...
# 40810         2531 E. Devon Ave, ELK GROVE VILLAGE, IL  41.993038 -87.941377
# 40811                9341 Adam Don Pkwy, WOODRIDGE, IL  41.713393 -88.027819
# 40812          1305 WILEY ROAD STE 125, SCHAUMBURG, IL  42.058747 -88.047553
# 40813                     2095 N Rand Rd, Palatine, IL  42.148603 -88.030347
# 40814        17070 S Park Ave Ste E, South Holland, IL  41.584893 -87.607775
#
#              FIPS_z
# 0      1.703132e+14
# 1      1.703180e+14
# 2      1.703184e+14
# 3      1.711187e+14
# 4      1.704384e+14
# ...             ...
# 40810  1.704384e+14
# 40811  1.704385e+14
# 40812  1.703180e+14
# 40813  1.703180e+14
# 40814  1.703183e+14
#
# [40815 rows x 73 columns]

# %%
#fill in missing Lat, Long, FIPS
geo_IL_fips.loc[geo_IL_fips["FIPS_z"].isnull()] #36
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 1330         1330        311247          311247  4357417000       4/3/20
# 1978         1978        311895          311895  6227707103      4/14/20
# 2002         2002        311919          311919  4428188509      2/25/21
# 2088         2088        312005          312005  3984847201      4/27/20
# 3153         3153        313070          313070  2252087100      4/10/20
# 3197         3197        313114          313114  3313488304      1/21/21
# 3559         3559        313476          313476  6478417409      5/14/20
# 3631         3631        313548          313548  6829277004       4/7/20
# 3813         3813        313730          313730  6463967004       4/7/20
# 3844         3844        313761          313761  7639977104      4/14/20
# 4115         4115        314032          314032  4791837000       4/4/20
# 4723         4723        314640          314640  7249568405      2/11/21
# 9232         9232        319149          319149  4263327203      4/27/20
# 9815         9815        319732          319732  8342537301       5/1/20
# 9975         9975        319892          319892  5924068305      1/26/21
# 10512       10512        320429          320429  1957667103      4/10/20
# 10881       10881        320798          320798  5482217101      4/13/20
# 12049       12049        321966          321966  1328317808       5/1/20
# 12768       12768        322685          322685  4808097109      4/13/20
# 15036       15036        324953          324953  9164158400      2/16/21
# 17726       17726        327643          327643  6090997009       4/6/20
# 17855       17855        327772          327772  2112178304      1/20/21
# 18067       18067        327984          327984  9354057704       5/1/20
# 19608       19608        329525          329525  1774927705       5/1/20
# 19848       19848        329765          329765  3557387102      4/11/20
# 20455       20455        330372          330372  4735788305      1/23/21
# 27838       27838        337755          337755  6400167101      4/14/20
# 28095       28095        338012          338012  1199707810       5/1/20
# 33678       33678        343595          343595  2821508310      1/21/21
# 35670       35670        345587          345587  2391268309      1/20/21
# 35844       35844        345761          345761  3209857105      4/11/20
# 37835       37835        347752          347752  2408737701       5/1/20
# 38089       38089        348006          348006  4389107300      4/29/20
# 39261       39261        349178          349178  2174297707       5/1/20
# 40464       40464        350381          350381  5068958308      1/25/21
# 40798       40798        350715          350715  9418607006       4/9/20
#
#        SBAOfficeCode ProcessingMethod  \
# 1330             507              PPP
# 1978             507              PPP
# 2002             507              PPS
# 2088             507              PPP
# 3153             507              PPP
# 3197             507              PPS
# 3559             507              PPP
# 3631             507              PPP
# 3813             507              PPP
# 3844             507              PPP
# 4115             507              PPP
# 4723             507              PPS
# 9232             507              PPP
# 9815             507              PPP
# 9975             507              PPS
# 10512            507              PPP
# 10881            507              PPP
# 12049            562              PPP
# 12768            507              PPP
# 15036            507              PPS
# 17726            507              PPP
# 17855            507              PPS
# 18067            507              PPP
# 19608            507              PPP
# 19848            507              PPP
# 20455            507              PPS
# 27838            507              PPP
# 28095            507              PPP
# 33678            507              PPS
# 35670            507              PPS
# 35844            507              PPP
# 37835            507              PPP
# 38089            507              PPP
# 39261            507              PPP
# 40464            507              PPS
# 40798            507              PPP
#
#                                     BorrowerName  \
# 1330                    LEIBOLD IRRIGATION, INC.
# 1978                      BUREAU SERVICE COMPANY
# 2002                      BUREAU SERVICE COMPANY
# 2088                             MINUTEMAN, INC.
# 3153                     HAMPSHIRE HOLDINGS, LLC
# 3197                         CAMOSY INCORPORATED
# 3559   WAYNE-WHITE COUNTIES ELECTRIC COOPERATIVE
# 3631                         CAMOSY INCORPORATED
# 3813                                       CALCO
# 3844                       DIBBLE TRUCKING, INC.
# 4115             SCHROEDER ASPHALT SERVICES, INC
# 4723              SOUTHEAST LINEN ASSOCIATES LLC
# 9232                         RIVER VIEW FORD INC
# 9815        AUSTIN HIGHLANDS DEVELOPMENT COMPANY
# 9975      AEROCARE MEDICAL TRANSPORT SYSTEMS INC
# 10512                      JOLIET AVIONICS, INC.
# 10881                                   NATC LLC
# 12049             LOGANSPORT MACHINE COMPANY INC
# 12768                   SAGINAW BAY HEMP COMPANY
# 15036         DEMPSEY DODGE CHRYSLER JEEP II INC
# 17726                     TRICO MECHANICAL, INC.
# 17855              AURELIOS PIZZA SOUTH LOOP LLC
# 18067         CARROLL WEISS &AMP; ASSOCIATES INC
# 19608                       OLIVE BRANCH MISSION
# 19848                               WELKINS, LLC
# 20455                  JIMMYS CHARHOUSE OF ELGIN
# 27838                  RUSSTECH ENGINEERING INC.
# 28095                    THE ADVENTURE CLUB, INC
# 33678               MULTILINGUAL CONNECTIONS LLC
# 35670                          RZ3285 OSWEGO LLC
# 35844               DEKANE EQUIPMENT CORPORATION
# 37835    TEACHER INNOVATIONS INC DBA PLANBOOKCOM
# 38089                   FARMERS AG SERVICE, INC.
# 39261                  GLOBAL INFRASTRUCTURE LLC
# 40464              RED BIRD MACHINERY REPAIR LLC
# 40798                           VACATIONLAND INC
#
#                                          BorrowerAddress   BorrowerCity  ...  \
# 1330                                18960 County Hwy 5 W   EAST DUBUQUE  ...
# 1978                                 22069 US HIGHWAY 34      PRINCETON  ...
# 2002                                 22069 US Highway 34      Princeton  ...
# 2088                                      14 N 845 US-20      Hampshire  ...
# 3153                                   14 N 850 Route 20      HAMPSHIRE  ...
# 3197                               43451 N US Highway 41           Zion  ...
# 3559                         1501 W. MAIN ST PO Drawer E      FAIRFIELD  ...
# 3631                                 43451 US HIGHWAY 41           ZION  ...
# 3813                              11600 Sterling Parkway       RICHMOND  ...
# 3844                                7505 S Us Highway 66        GARDNER  ...
# 4115                                   11022 S. Route 20        MARENGO  ...
# 4723   4508 W 46th St 6445 E Houghton Lake Dr Houghto...        Chicago  ...
# 9232                                  2000 US HIGHWAY 30         OSWEGO  ...
# 9815                             7000 S ADAMS ST STE 250   WILLOW BROOK  ...
# 9975                        43 W 752 Highway 30 Suite 2F    Sugar Grove  ...
# 10512                             43 W 730 US Highway 30    SUGAR GROVE  ...
# 10881                                    215 Elmwood Ave          UNION  ...
# 12049                            1200 West Linden Avenue     Logansport  ...
# 12768                              1000 E. US Highway 34          PLANO  ...
# 15036                               1000 E US Highway 34          Plano  ...
# 17726                         1980 W US HWY 30, Suite 11    SUGAR GROVE  ...
# 17855                                  18162 Harwood Ave       Homewood  ...
# 18067                                      639 W MAIN ST        BATAVIA  ...
# 19608           C/O La Forice Nealy 6310 S CLAREMONT AVE        CHICAGO  ...
# 19848                    3000 woodcreek drive, Suite 300  Downers Grove  ...
# 20455                                    2290 Point Blvd          Elgin  ...
# 27838                     16 Technology Drive  Suite 111         Irvine  ...
# 28095                                    105 E JOILET ST    SCHEREVILLE  ...
# 33678                                                847       EVANSTON  ...
# 35670                                         2850 US-34         OSWEGO  ...
# 35844                               47619 W. US Route 30       BIG ROCK  ...
# 37835                                7736 STATE ROUTE 34      YORKVILLE  ...
# 38089                                      301 S PARK ST        GIFFORD  ...
# 39261                                 4937 WILSHIRE BLVD  CNTRY CLB HLS  ...
# 40464                               1410 US Highway 45 N       Eldorado  ...
# 40798                               47 W 529 US Route 30       BIG ROCK  ...
#
#                   TRIIndustrySector  \
# 1330                      999 Other
# 1978                      999 Other
# 2002                      999 Other
# 2088                  333 Machinery
# 3153                      999 Other
# 3197                      999 Other
# 3559        2211 Electric Utilities
# 3631                      999 Other
# 3813              321 Wood Products
# 3844                      999 Other
# 4115                      999 Other
# 4723                      999 Other
# 9232                      999 Other
# 9815                      999 Other
# 9975                      999 Other
# 10512                     999 Other
# 10881                 333 Machinery
# 12049                 333 Machinery
# 12768                     999 Other
# 15036                     999 Other
# 17726                     999 Other
# 17855                     999 Other
# 18067                     999 Other
# 19608                     999 Other
# 19848                     999 Other
# 20455                     999 Other
# 27838  336 Transportation Equipment
# 28095                     999 Other
# 33678                     999 Other
# 35670                     999 Other
# 35844                     999 Other
# 37835                           NaN
# 38089                     999 Other
# 39261                     999 Other
# 40464                     999 Other
# 40798                     999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 1330               2213 Water, Sewage and Other Systems       2213.0
# 1978   4249 Miscellaneous Nondurable Goods Merchant W...      4249.0
# 2002   4249 Miscellaneous Nondurable Goods Merchant W...      4249.0
# 2088   3333 Commercial and Service Industry Machinery...      3333.0
# 3153   4442 Lawn and Garden Equipment and Supplies St...      4442.0
# 3197           2362 Nonresidential Building Construction      2362.0
# 3559   2211 Electric Power Generation, Transmission a...      2211.0
# 3631           2362 Nonresidential Building Construction      2362.0
# 3813               3219 Other Wood Product Manufacturing      3219.0
# 3844                       4841 General Freight Trucking      4841.0
# 4115       2373 Highway, Street, and Bridge Construction      2373.0
# 4723              8123 Drycleaning and Laundry Services       8123.0
# 9232                            4411 Automobile Dealers       4411.0
# 9815                         5311 Lessors of Real Estate      5311.0
# 9975          6219 Other Ambulatory Health Care Services      6219.0
# 10512     4881 Support Activities for Air Transportation      4881.0
# 10881          3335 Metalworking Machinery Manufacturing      3335.0
# 12049          3335 Metalworking Machinery Manufacturing      3335.0
# 12768                           4411 Automobile Dealers       4411.0
# 15036                           4411 Automobile Dealers       4411.0
# 17726                2382 Building Equipment Contractors      2382.0
# 17855           7225 Restaurants and Other Eating Places      7225.0
# 18067                2382 Building Equipment Contractors      2382.0
# 19608  6242 Community Food and Housing, and Emergency...      6242.0
# 19848                   5612 Facilities Support Services      5612.0
# 20455           7225 Restaurants and Other Eating Places      7225.0
# 27838     3364 Aerospace Product and Parts Manufacturing      3364.0
# 28095  8139 Business, Professional, Labor, Political,...      8139.0
# 33678  5419 Other Professional, Scientific, and Techn...      5419.0
# 35670           7225 Restaurants and Other Eating Places      7225.0
# 35844                        5311 Lessors of Real Estate      5311.0
# 37835                                                NaN         NaN
# 38089  4238 Machinery, Equipment, and Supplies Mercha...      4238.0
# 39261                        5619 Other Support Services      5619.0
# 40464  8113 Commercial and Industrial Machinery and E...      8113.0
# 40798                  4412 Other Motor Vehicle Dealers       4412.0
#
#                  SBAOfficeLabel            Loan_Range   job_Range  \
# 1330   ILLINOIS DISTRICT OFFICE        d $2-5 million  100 to 249
# 1978   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 2002   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 2088   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 3153   ILLINOIS DISTRICT OFFICE        c $1-2 million  250 to 499
# 3197   ILLINOIS DISTRICT OFFICE        c $1-2 million    50 to 99
# 3559   ILLINOIS DISTRICT OFFICE        c $1-2 million    20 to 49
# 3631   ILLINOIS DISTRICT OFFICE        c $1-2 million    50 to 99
# 3813   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 3844   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 4115   ILLINOIS DISTRICT OFFICE        c $1-2 million    50 to 99
# 4723   ILLINOIS DISTRICT OFFICE        c $1-2 million  100 to 249
# 9232   ILLINOIS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 9815   ILLINOIS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 9975   ILLINOIS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 10512  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 10881  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 12049   INDIANA DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 12768  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 15036  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 17726  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    10 to 19
# 17855  ILLINOIS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 18067  ILLINOIS DISTRICT OFFICE    a $150,000-350,000      5 to 9
# 19608  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 19848  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 20455  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 27838  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 28095  ILLINOIS DISTRICT OFFICE    a $150,000-350,000  100 to 249
# 33678  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 35670  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 35844  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 37835  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    50 to 99
# 38089  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 39261  ILLINOIS DISTRICT OFFICE    a $150,000-350,000      5 to 9
# 40464  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 40798  ILLINOIS DISTRICT OFFICE    a $150,000-350,000    10 to 19
#
#                                                 full_add        Lat  \
# 1330              18960 County Hwy 5 W, EAST DUBUQUE, IL  42.508105
# 1978                  22069 US HIGHWAY 34, PRINCETON, IL  40.392967
# 2002                  22069 US Highway 34, Princeton, IL  40.392967
# 2088                       14 N 845 US-20, Hampshire, IL  44.370091
# 3153                    14 N 850 Route 20, HAMPSHIRE, IL  42.468637
# 3197                     43451 N US Highway 41, Zion, IL  35.242488
# 3559          1501 W. MAIN ST PO Drawer E, FAIRFIELD, IL  38.033561
# 3631                       43451 US HIGHWAY 41, ZION, IL  47.046908
# 3813                11600 Sterling Parkway, RICHMOND, IL  42.495414
# 3844                   7505 S Us Highway 66, GARDNER, IL  36.145096
# 4115                      11022 S. Route 20, MARENGO, IL  42.902196
# 4723   4508 W 46th St 6445 E Houghton Lake Dr Houghto...  44.369346
# 9232                      2000 US HIGHWAY 30, OSWEGO, IL  41.830975
# 9815           7000 S ADAMS ST STE 250, WILLOW BROOK, IL        NaN
# 9975       43 W 752 Highway 30 Suite 2F, Sugar Grove, IL  42.063715
# 10512            43 W 730 US Highway 30, SUGAR GROVE, IL  41.468463
# 10881                         215 Elmwood Ave, UNION, IL  40.698010
# 12049            1200 West Linden Avenue, Logansport, IL  40.755215
# 12768                   1000 E. US Highway 34, PLANO, IL  41.026674
# 15036                    1000 E US Highway 34, Plano, IL  41.026674
# 17726        1980 W US HWY 30, Suite 11, SUGAR GROVE, IL  39.858227
# 17855                    18162 Harwood Ave, Homewood, IL  41.559420
# 18067                         639 W MAIN ST, BATAVIA, IL  38.031585
# 19608  C/O La Forice Nealy 6310 S CLAREMONT AVE, CHIC...  41.778938
# 19848  3000 woodcreek drive, Suite 300, Downers Grove...  41.831377
# 20455                         2290 Point Blvd, Elgin, IL  42.083396
# 27838         16 Technology Drive  Suite 111, Irvine, IL  33.650602
# 28095                   105 E JOILET ST, SCHEREVILLE, IL  41.492044
# 33678                                  847, EVANSTON, IL        NaN
# 35670                             2850 US-34, OSWEGO, IL  40.997234
# 35844                 47619 W. US Route 30, BIG ROCK, IL  44.956449
# 37835                 7736 STATE ROUTE 34, YORKVILLE, IL  43.055693
# 38089                         301 S PARK ST, GIFFORD, IL  43.063867
# 39261              4937 WILSHIRE BLVD, CNTRY CLB HLS, IL  34.062174
# 40464                 1410 US Highway 45 N, Eldorado, IL  45.526731
# 40798                 47 W 529 US Route 30, BIG ROCK, IL  40.451443
#
#              Long FIPS_z
# 1330   -90.565332    NaN
# 1978  -104.634462    NaN
# 2002  -104.634462    NaN
# 2088  -108.038415    NaN
# 3153   -73.419886    NaN
# 3197   -85.690479    NaN
# 3559   -78.497707    NaN
# 3631   -88.518619    NaN
# 3813   -88.320057    NaN
# 3844   -96.002364    NaN
# 4115  -106.494403    NaN
# 4723   -84.692139    NaN
# 9232   -90.701615    NaN
# 9815          NaN    NaN
# 9975   -94.857290    NaN
# 10512  -87.207119    NaN
# 10881  -74.280309    NaN
# 12049  -86.385976    NaN
# 12768  -94.014404    NaN
# 15036  -94.014404    NaN
# 17726  -77.298102    NaN
# 17855  -87.668894    NaN
# 18067  -78.489502    NaN
# 19608  -87.682691    NaN
# 19848  -88.035963    NaN
# 20455  -88.333610    NaN
# 27838 -117.736467    NaN
# 28095  -87.448921    NaN
# 33678         NaN    NaN
# 35670  -91.815673    NaN
# 35844 -117.938204    NaN
# 37835  -76.558131    NaN
# 38089  -89.400267    NaN
# 39261 -118.338767    NaN
# 40464  -89.161915    NaN
# 40798  -80.251737    NaN
#
# [36 rows x 73 columns]

# %% [markdown]
# <b>Value Re-verification - (if no pairing found in state aggregation)

# %%
#['17491', '17697', '17731', '17766', '17859', '17949', '17987']
geo_il_ver = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17949']
geo_il_ver2 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17941']
geo_il_ver3 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17697']
geo_il_ver4 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17731']
geo_il_ver5 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17766']
geo_il_ver6 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17859']
geo_il_ver7 = geo_IL_fips.loc[geo_IL_fips["FIPS_z"].astype(str).str[:5] == '17987']

frames = [geo_il_ver, geo_il_ver2, geo_il_ver3, geo_il_ver4, geo_il_ver5, geo_il_ver6, geo_il_ver7]
result = pd.concat(frames)
result
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 46             46            46  6786427000       4/7/20            507
# 274           274           274  8853117001       4/9/20            507
# 286           286           286  6899737006       4/7/20            507
# 317           317           317  2412247100      4/10/20            507
# 337           337           337  7881847000       4/8/20            507
# ...           ...           ...         ...          ...            ...
# 6343         6343          6343  1526607105      4/10/20            507
# 4969         4969          4969  8477327904      6/18/20            507
# 4878         4878          4878  5853367002       4/6/20            507
# 40227       40227         40227  1847467210      4/15/20            507
# 35844       35844         35844  3209857105      4/11/20            507
#
#       ProcessingMethod                            BorrowerName  \
# 46                 PPP                       HOA HOLDINGS, LLC
# 274                PPP                    FURST-MCNESS COMPANY
# 286                PPP       HEYL, ROYSTER, VOELKER & ALLEN PC
# 317                PPP    CRUSADERS CENTRAL CLINIC ASSOCIATION
# 337                PPP                ROCKFORD TOOLCRAFT, INC.
# ...                ...                                     ...
# 6343               PPP      GRASSER'S PLUMBING & HEATING, INC.
# 4969               PPP  SOUTHERN ILLINOIS ELECTRIC COOPERATIVE
# 4878               PPP                    MCKAY AUTO PARTS INC
# 40227              PPP    251 PUB, INC. DBA WOODS CREEK TAVERN
# 35844              PPP            DEKANE EQUIPMENT CORPORATION
#
#             BorrowerAddress       BorrowerCity BorrowerState  ...  \
# 46            1501 RIVER DR             MOLINE            IL  ...
# 274      120 E Clark Street           FREEPORT            IL  ...
# 286       300 Hamilton Blvd             PEORIA            IL  ...
# 317         1200 W STATE ST           ROCKFORD            IL  ...
# 337    766 Research Parkway           ROCKFORD            IL  ...
# ...                     ...                ...           ...  ...
# 6343         404 W. MAIN ST            MC NABB            IL  ...
# 4969   7420 US HIGHWAY 51 S            DONGOLA            IL  ...
# 4878     414 N OLD ROUTE 66         LITCHFIELD            IL  ...
# 40227      251 N RANDALL RD  LAKE IN THE HILLS            IL  ...
# 35844  47619 W. US Route 30           BIG ROCK            IL  ...
#
#                    TRIIndustrySector  \
# 46                         999 Other
# 274                         311 Food
# 286                        999 Other
# 317                        999 Other
# 337    332 Fabricated Metal Products
# ...                              ...
# 6343                       999 Other
# 4969         2211 Electric Utilities
# 4878                       999 Other
# 40227                      999 Other
# 35844                      999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 46                           7211 Traveler Accommodation      7211.0
# 274                       3111 Animal Food Manufacturing      3111.0
# 286                                  5411 Legal Services      5411.0
# 317                  6241 Individual and Family Services      6241.0
# 337                            3321 Forging and Stamping      3321.0
# ...                                                  ...         ...
# 6343        4441 Building Material and Supplies Dealers       4441.0
# 4969   2211 Electric Power Generation, Transmission a...      2211.0
# 4878   4413 Automotive Parts, Accessories, and Tire S...      4413.0
# 40227         7224 Drinking Places (Alcoholic Beverages)      7224.0
# 35844                        5311 Lessors of Real Estate      5311.0
#
#                  SBAOfficeLabel            Loan_Range    job_Range  \
# 46     ILLINOIS DISTRICT OFFICE       e $5-10 million  500 or more
# 274    ILLINOIS DISTRICT OFFICE        d $2-5 million   250 to 499
# 286    ILLINOIS DISTRICT OFFICE        d $2-5 million   250 to 499
# 317    ILLINOIS DISTRICT OFFICE        d $2-5 million   250 to 499
# 337    ILLINOIS DISTRICT OFFICE        d $2-5 million   250 to 499
# ...                         ...                   ...          ...
# 6343   ILLINOIS DISTRICT OFFICE  b $350,000-1 million     50 to 99
# 4969   ILLINOIS DISTRICT OFFICE        c $1-2 million     20 to 49
# 4878   ILLINOIS DISTRICT OFFICE        c $1-2 million   100 to 249
# 40227  ILLINOIS DISTRICT OFFICE    a $150,000-350,000     20 to 49
# 35844  ILLINOIS DISTRICT OFFICE    a $150,000-350,000     10 to 19
#
#                                       full_add        Lat        Long  \
# 46                   1501 RIVER DR, MOLINE, IL  41.508526  -90.517157
# 274           120 E Clark Street, FREEPORT, IL  42.301466  -89.620088
# 286              300 Hamilton Blvd, PEORIA, IL  40.693498  -89.588734
# 317              1200 W STATE ST, ROCKFORD, IL  42.275120  -89.108312
# 337         766 Research Parkway, ROCKFORD, IL  42.218582  -89.085242
# ...                                        ...        ...         ...
# 6343               404 W. MAIN ST, MC NABB, IL  41.176980  -89.209252
# 4969         7420 US HIGHWAY 51 S, DONGOLA, IL  35.828391  -89.451707
# 4878        414 N OLD ROUTE 66, LITCHFIELD, IL  39.177663  -89.665934
# 40227  251 N RANDALL RD, LAKE IN THE HILLS, IL  42.178597  -88.334748
# 35844       47619 W. US Route 30, BIG ROCK, IL  44.956449 -117.938204
#
#              FIPS_z
# 46     1.794949e+14
# 274    1.794949e+14
# 286    1.794949e+14
# 317    1.794949e+14
# 337    1.794949e+14
# ...             ...
# 6343   1.769799e+14
# 4969   1.773142e+14
# 4878   1.776627e+14
# 40227  1.785969e+14
# 35844  1.798779e+15
#
# [1566 rows x 72 columns]
