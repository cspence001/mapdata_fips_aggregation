# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as BraveService
from webdriver_manager.core.utils import ChromeType
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_sd.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check
# Out:
#       Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0         792074  3507637205      4/27/20            876              PPP
# 1         792075  1221237209      4/15/20            876              PPP
# 2         792076  4673147200      4/27/20            876              PPP
# 3         792077  6663527703       5/1/20            876              PPP
# 4         792078  7971747009       4/8/20            876              PPP
# ...          ...         ...          ...            ...              ...
# 2690      794764  8914837010       4/9/20            876              PPP
# 2691      794765  9178718708       4/8/21            876              PPS
# 2692      794766  9304517103      4/15/20            876              PPP
# 2693      794767  9378667203      4/28/20            876              PPP
# 2694      794768  9879198503      3/12/21            876              PPS
#
#                                  BorrowerName              BorrowerAddress  \
# 0                       EMPIRICAL FOODS, INC.            891 TWO RIVERS DR
# 1     COCA-COLA BOTTLING COMPANY HIGH COUNTRY            2150 COCA COLA LN
# 2                      DAKOTA PROVISIONS, LLC          40253 US Highway 14
# 3                        SONIFI SOLUTIONS INC         3900 W Innovation St
# 4                     SHOWPLACE WOOD PRODUCTS              1 Enterprise St
# ...                                       ...                          ...
# 2690          EKHOLM ENTERPRISES INCORPORATED  1101 West Glen Eagle Circle
# 2691         CARLSON'S NORTHSIDE SERVICE INC.             320 Dakota Ave N
# 2692   HART RANCHING CAMPING RESORT CLUB, INC               23756 ARENA DR
# 2693                 TRADEMARK UNIFORMS, INC.               2011 W 45TH ST
# 2694                         RMK PAINTING INC           713 S Phillips Ave
#
#       BorrowerCity BorrowerState  BorrowerZip  ...  \
# 0     DAKOTA DUNES            SD      57049.0  ...
# 1       RAPID CITY            SD      57702.0  ...
# 2            Huron            SD      57350.0  ...
# 3      Sioux Falls            SD      57107.0  ...
# 4       HARRISBURG            SD      57032.0  ...
# ...            ...           ...          ...  ...
# 2690   Sioux Falls            SD      57108.0  ...
# 2691         Huron            SD      57350.0  ...
# 2692    RAPID CITY            SD      57702.0  ...
# 2693   SIOUX FALLS            SD      57105.0  ...
# 2694   Sioux Falls            SD      57104.0  ...
#
#                       TRIIndustrySector  \
# 0                              311 Food
# 1     312 Beverage and Tobacco Products
# 2                              311 Food
# 3                             999 Other
# 4                         337 Furniture
# ...                                 ...
# 2690                          999 Other
# 2691                          999 Other
# 2692                          999 Other
# 2693                          999 Other
# 2694                          999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0               3116 Animal Slaughtering and Processing       3116.0
# 1                           3121 Beverage Manufacturing       3121.0
# 2               3116 Animal Slaughtering and Processing       3116.0
# 3              5121 Motion Picture and Video Industries       5121.0
# 4     3371 Household and Institutional Furniture and...       3371.0
# ...                                                 ...          ...
# 2690                             5621 Waste Collection        5621.0
# 2691                            4471 Gasoline Stations        4471.0
# 2692  7212 RV (Recreational Vehicle) Parks and Recre...       7212.0
# 2693             8123 Drycleaning and Laundry Services        8123.0
# 2694                2383 Building Finishing Contractors       2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 1     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 2     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 3     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 4     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# ...                            ...                 ...          ...
# 2690  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2691  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000       5 to 9
# 2692  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2693  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2694  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                           full_add        Lat        Long  \
# 0              891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281
# 1                2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592
# 2                   40253 US Highway 14, Huron, SD  44.369109  -98.163177
# 3            3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704
# 4                  1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415
# ...                                            ...        ...         ...
# 2690  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080  -96.736384
# 2691                   320 Dakota Ave N, Huron, SD  44.369881  -98.213651
# 2692                23756 ARENA DR, RAPID CITY, SD  43.961714 -103.213474
# 2693               2011 W 45TH ST, SIOUX FALLS, SD  43.511243  -96.750715
# 2694           713 S Phillips Ave, Sioux Falls, SD  43.539763  -96.727161
#
#      FIPS_z
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 2690    NaN
# 2691    NaN
# 2692    NaN
# 2693    NaN
# 2694    NaN
#
# [2695 rows x 71 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan #3
# Out:
# Empty DataFrame
# Columns: [LoanNumber, full_add, Lat, Long]
# Index: []

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #15866
# Out:
#    LoanNumber                               full_add        Lat        Long
# 0  3507637205    891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281
# 1  1221237209      2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592
# 2  4673147200         40253 US Highway 14, Huron, SD  44.369109  -98.163177
# 3  6663527703  3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704
# 4  7971747009        1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("../../data/state_data/geo/geo_fips/SD_fips_scraped.csv") 
fips_check_scraped.head() #15869

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #15866

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #5503

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
#driver = webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))
#executable_path = {'executable_path': webdriver.Chrome(service=BraveService(ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()))}
executable_path = {'executable_path': ChromeDriverManager(chrome_type=ChromeType.BRAVE).install()}
option = webdriver.ChromeOptions()
option.binary_location = "/Applications/Brave Browser.app/Contents/MacOS/Brave Browser"
driver = Browser('chrome', **executable_path, options=option, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('geoCoordX').clear()
        driver.find_by_id('geoCoordY').clear()
        driver.find_by_id('geoCoordX').fill(long[i])
        driver.find_by_id('geoCoordY').fill(lat[i])
        driver.find_by_id('geoCoordsSubmit').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='geoCoordsJsonOutput')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('46')] #SD
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                #print(f"{i},{lat[i]},{long[i]} Not Found")
                not_found.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
# [WDM] - Downloading: 100%|██████████| 8.79M/8.79M [00:01<00:00, 8.16MB/s]
#   0%|          | 0/2695 [00:00<?, ?it/s]

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 2695

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:25062]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
#       LoanNumber                                      full_add        Lat  \
# 0     3507637205           891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600
# 1     1221237209             2150 COCA COLA LN, RAPID CITY, SD  44.106394
# 2     4673147200                40253 US Highway 14, Huron, SD  44.369109
# 3     6663527703         3900 W Innovation St, Sioux Falls, SD  43.578588
# 4     7971747009               1 Enterprise St, HARRISBURG, SD  43.439920
# ...          ...                                           ...        ...
# 2690  8914837010  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080
# 2691  9178718708                   320 Dakota Ave N, Huron, SD  44.369881
# 2692  9304517103                23756 ARENA DR, RAPID CITY, SD  43.961714
# 2693  9378667203               2011 W 45TH ST, SIOUX FALLS, SD  43.511243
# 2694  9879198503           713 S Phillips Ave, Sioux Falls, SD  43.539763
#
#             Long             FIPS_z
# 0     -96.478281  [461270203011033]
# 1    -103.258592  [461030114003026]
# 2     -98.163177  [460059568001132]
# 3     -96.778704  [460990104051004]
# 4     -96.703415  [460830101073026]
# ...          ...                ...
# 2690  -96.736384  [460830101162011]
# 2691  -98.213651  [460059568002064]
# 2692 -103.213474  [461030110052001]
# 2693  -96.750715  [460990015013029]
# 2694  -96.727161  [460990006002001]
#
# [2695 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
#       LoanNumber                                      full_add        Lat  \
# 0     3507637205           891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600
# 1     1221237209             2150 COCA COLA LN, RAPID CITY, SD  44.106394
# 2     4673147200                40253 US Highway 14, Huron, SD  44.369109
# 3     6663527703         3900 W Innovation St, Sioux Falls, SD  43.578588
# 4     7971747009               1 Enterprise St, HARRISBURG, SD  43.439920
# ...          ...                                           ...        ...
# 2690  8914837010  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080
# 2691  9178718708                   320 Dakota Ave N, Huron, SD  44.369881
# 2692  9304517103                23756 ARENA DR, RAPID CITY, SD  43.961714
# 2693  9378667203               2011 W 45TH ST, SIOUX FALLS, SD  43.511243
# 2694  9879198503           713 S Phillips Ave, Sioux Falls, SD  43.539763
#
#             Long           FIPS_z
# 0     -96.478281  461270203011033
# 1    -103.258592  461030114003026
# 2     -98.163177  460059568001132
# 3     -96.778704  460990104051004
# 4     -96.703415  460830101073026
# ...          ...              ...
# 2690  -96.736384  460830101162011
# 2691  -98.213651  460059568002064
# 2692 -103.213474  461030110052001
# 2693  -96.750715  460990015013029
# 2694  -96.727161  460990006002001
#
# [2695 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check #24
# Out:
#       LoanNumber                          full_add        Lat        Long  \
# 389   5274317004      12525 US Hwy 20, BUFFALO, SD  42.365652  -97.560766
# 1301  9903297002  12171 Lake Rd, BROWNS VALLEY, SD  39.242114 -121.409130
#
#      FIPS_z
# 389     NaN
# 1301    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#       LoanNumber           FIPS_z
# 0     3507637205  461270203011033
# 1     1221237209  461030114003026
# 2     4673147200  460059568001132
# 3     6663527703  460990104051004
# 4     7971747009  460830101073026
# ...          ...              ...
# 2690  8914837010  460830101162011
# 2691  9178718708  460059568002064
# 2692  9304517103  461030110052001
# 2693  9378667203  460990015013029
# 2694  9879198503  460990006002001
#
# [2695 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("../../data/state_data/geo/geocoded/geo_sd.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check.head()

#if from FIPS file
#fips_check = pd.read_csv("../../data/state_data/geo/geo_fips/SD_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #22826
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0      792074        792074          792074  3507637205      4/27/20
# 1      792075        792075          792075  1221237209      4/15/20
# 2      792076        792076          792076  4673147200      4/27/20
# 3      792077        792077          792077  6663527703       5/1/20
# 4      792078        792078          792078  7971747009       4/8/20
#
#    SBAOfficeCode ProcessingMethod                             BorrowerName  \
# 0            876              PPP                    EMPIRICAL FOODS, INC.
# 1            876              PPP  COCA-COLA BOTTLING COMPANY HIGH COUNTRY
# 2            876              PPP                   DAKOTA PROVISIONS, LLC
# 3            876              PPP                     SONIFI SOLUTIONS INC
# 4            876              PPP                  SHOWPLACE WOOD PRODUCTS
#
#         BorrowerAddress  BorrowerCity  ...                  TRIIndustrySector  \
# 0     891 TWO RIVERS DR  DAKOTA DUNES  ...                           311 Food
# 1     2150 COCA COLA LN    RAPID CITY  ...  312 Beverage and Tobacco Products
# 2   40253 US Highway 14         Huron  ...                           311 Food
# 3  3900 W Innovation St   Sioux Falls  ...                          999 Other
# 4       1 Enterprise St    HARRISBURG  ...                      337 Furniture
#
#                                    IndustrySubsector 4DigitNAICS  \
# 0            3116 Animal Slaughtering and Processing      3116.0
# 1                        3121 Beverage Manufacturing      3121.0
# 2            3116 Animal Slaughtering and Processing      3116.0
# 3           5121 Motion Picture and Video Industries      5121.0
# 4  3371 Household and Institutional Furniture and...      3371.0
#
#                  SBAOfficeLabel       Loan_Range    job_Range  \
# 0  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 1  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 2  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 3  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 4  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                 full_add        Lat        Long FIPS_z
# 0    891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281    NaN
# 1      2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592    NaN
# 2         40253 US Highway 14, Huron, SD  44.369109  -98.163177    NaN
# 3  3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704    NaN
# 4        1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415    NaN
#
# [5 rows x 73 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         792074        792074          792074  3507637205      4/27/20
# 1         792075        792075          792075  1221237209      4/15/20
# 2         792076        792076          792076  4673147200      4/27/20
# 3         792077        792077          792077  6663527703       5/1/20
# 4         792078        792078          792078  7971747009       4/8/20
# ...          ...           ...             ...         ...          ...
# 2690      794764        794764          794764  8914837010       4/9/20
# 2691      794765        794765          794765  9178718708       4/8/21
# 2692      794766        794766          794766  9304517103      4/15/20
# 2693      794767        794767          794767  9378667203      4/28/20
# 2694      794768        794768          794768  9879198503      3/12/21
#
#       SBAOfficeCode ProcessingMethod                             BorrowerName  \
# 0               876              PPP                    EMPIRICAL FOODS, INC.
# 1               876              PPP  COCA-COLA BOTTLING COMPANY HIGH COUNTRY
# 2               876              PPP                   DAKOTA PROVISIONS, LLC
# 3               876              PPP                     SONIFI SOLUTIONS INC
# 4               876              PPP                  SHOWPLACE WOOD PRODUCTS
# ...             ...              ...                                      ...
# 2690            876              PPP          EKHOLM ENTERPRISES INCORPORATED
# 2691            876              PPS         CARLSON'S NORTHSIDE SERVICE INC.
# 2692            876              PPP   HART RANCHING CAMPING RESORT CLUB, INC
# 2693            876              PPP                 TRADEMARK UNIFORMS, INC.
# 2694            876              PPS                         RMK PAINTING INC
#
#                   BorrowerAddress  BorrowerCity  ...  \
# 0               891 TWO RIVERS DR  DAKOTA DUNES  ...
# 1               2150 COCA COLA LN    RAPID CITY  ...
# 2             40253 US Highway 14         Huron  ...
# 3            3900 W Innovation St   Sioux Falls  ...
# 4                 1 Enterprise St    HARRISBURG  ...
# ...                           ...           ...  ...
# 2690  1101 West Glen Eagle Circle   Sioux Falls  ...
# 2691             320 Dakota Ave N         Huron  ...
# 2692               23756 ARENA DR    RAPID CITY  ...
# 2693               2011 W 45TH ST   SIOUX FALLS  ...
# 2694           713 S Phillips Ave   Sioux Falls  ...
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0               3116 Animal Slaughtering and Processing       3116.0
# 1                           3121 Beverage Manufacturing       3121.0
# 2               3116 Animal Slaughtering and Processing       3116.0
# 3              5121 Motion Picture and Video Industries       5121.0
# 4     3371 Household and Institutional Furniture and...       3371.0
# ...                                                 ...          ...
# 2690                             5621 Waste Collection        5621.0
# 2691                            4471 Gasoline Stations        4471.0
# 2692  7212 RV (Recreational Vehicle) Parks and Recre...       7212.0
# 2693             8123 Drycleaning and Laundry Services        8123.0
# 2694                2383 Building Finishing Contractors       2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 1     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 2     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 3     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 4     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# ...                            ...                 ...          ...
# 2690  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2691  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000       5 to 9
# 2692  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2693  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2694  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                           full_add        Lat        Long  \
# 0              891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281
# 1                2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592
# 2                   40253 US Highway 14, Huron, SD  44.369109  -98.163177
# 3            3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704
# 4                  1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415
# ...                                            ...        ...         ...
# 2690  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080  -96.736384
# 2691                   320 Dakota Ave N, Huron, SD  44.369881  -98.213651
# 2692                23756 ARENA DR, RAPID CITY, SD  43.961714 -103.213474
# 2693               2011 W 45TH ST, SIOUX FALLS, SD  43.511243  -96.750715
# 2694           713 S Phillips Ave, Sioux Falls, SD  43.539763  -96.727161
#
#       FIPS_z_x         FIPS_z_y
# 0          NaN  461270203011033
# 1          NaN  461030114003026
# 2          NaN  460059568001132
# 3          NaN  460990104051004
# 4          NaN  460830101073026
# ...        ...              ...
# 2690       NaN  460830101162011
# 2691       NaN  460059568002064
# 2692       NaN  461030110052001
# 2693       NaN  460990015013029
# 2694       NaN  460990006002001
#
# [2695 rows x 74 columns]

# %% [markdown]
# <b>Fill FIPS Columns - if FIPS file

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         792074        792074          792074  3507637205      4/27/20
# 1         792075        792075          792075  1221237209      4/15/20
# 2         792076        792076          792076  4673147200      4/27/20
# 3         792077        792077          792077  6663527703       5/1/20
# 4         792078        792078          792078  7971747009       4/8/20
# ...          ...           ...             ...         ...          ...
# 2690      794764        794764          794764  8914837010       4/9/20
# 2691      794765        794765          794765  9178718708       4/8/21
# 2692      794766        794766          794766  9304517103      4/15/20
# 2693      794767        794767          794767  9378667203      4/28/20
# 2694      794768        794768          794768  9879198503      3/12/21
#
#       SBAOfficeCode ProcessingMethod                             BorrowerName  \
# 0               876              PPP                    EMPIRICAL FOODS, INC.
# 1               876              PPP  COCA-COLA BOTTLING COMPANY HIGH COUNTRY
# 2               876              PPP                   DAKOTA PROVISIONS, LLC
# 3               876              PPP                     SONIFI SOLUTIONS INC
# 4               876              PPP                  SHOWPLACE WOOD PRODUCTS
# ...             ...              ...                                      ...
# 2690            876              PPP          EKHOLM ENTERPRISES INCORPORATED
# 2691            876              PPS         CARLSON'S NORTHSIDE SERVICE INC.
# 2692            876              PPP   HART RANCHING CAMPING RESORT CLUB, INC
# 2693            876              PPP                 TRADEMARK UNIFORMS, INC.
# 2694            876              PPS                         RMK PAINTING INC
#
#                   BorrowerAddress  BorrowerCity  ... 4DigitNAICS  \
# 0               891 TWO RIVERS DR  DAKOTA DUNES  ...      3116.0
# 1               2150 COCA COLA LN    RAPID CITY  ...      3121.0
# 2             40253 US Highway 14         Huron  ...      3116.0
# 3            3900 W Innovation St   Sioux Falls  ...      5121.0
# 4                 1 Enterprise St    HARRISBURG  ...      3371.0
# ...                           ...           ...  ...         ...
# 2690  1101 West Glen Eagle Circle   Sioux Falls  ...      5621.0
# 2691             320 Dakota Ave N         Huron  ...      4471.0
# 2692               23756 ARENA DR    RAPID CITY  ...      7212.0
# 2693               2011 W 45TH ST   SIOUX FALLS  ...      8123.0
# 2694           713 S Phillips Ave   Sioux Falls  ...      2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 1     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 2     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 3     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 4     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# ...                            ...                 ...          ...
# 2690  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2691  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000       5 to 9
# 2692  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2693  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2694  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                           full_add        Lat        Long  \
# 0              891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281
# 1                2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592
# 2                   40253 US Highway 14, Huron, SD  44.369109  -98.163177
# 3            3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704
# 4                  1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415
# ...                                            ...        ...         ...
# 2690  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080  -96.736384
# 2691                   320 Dakota Ave N, Huron, SD  44.369881  -98.213651
# 2692                23756 ARENA DR, RAPID CITY, SD  43.961714 -103.213474
# 2693               2011 W 45TH ST, SIOUX FALLS, SD  43.511243  -96.750715
# 2694           713 S Phillips Ave, Sioux Falls, SD  43.539763  -96.727161
#
#       FIPS_z_x         FIPS_z_y           FIPS_z
# 0          NaN  461270203011033  461270203011033
# 1          NaN  461030114003026  461030114003026
# 2          NaN  460059568001132  460059568001132
# 3          NaN  460990104051004  460990104051004
# 4          NaN  460830101073026  460830101073026
# ...        ...              ...              ...
# 2690       NaN  460830101162011  460830101162011
# 2691       NaN  460059568002064  460059568002064
# 2692       NaN  461030110052001  461030110052001
# 2693       NaN  460990015013029  460990015013029
# 2694       NaN  460990006002001  460990006002001
#
# [2695 rows x 75 columns]

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
#fips_merge_drop = fips_merge_drop.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0         792074        792074          792074  3507637205      4/27/20
# 1         792075        792075          792075  1221237209      4/15/20
# 2         792076        792076          792076  4673147200      4/27/20
# 3         792077        792077          792077  6663527703       5/1/20
# 4         792078        792078          792078  7971747009       4/8/20
# ...          ...           ...             ...         ...          ...
# 2690      794764        794764          794764  8914837010       4/9/20
# 2691      794765        794765          794765  9178718708       4/8/21
# 2692      794766        794766          794766  9304517103      4/15/20
# 2693      794767        794767          794767  9378667203      4/28/20
# 2694      794768        794768          794768  9879198503      3/12/21
#
#       SBAOfficeCode ProcessingMethod                             BorrowerName  \
# 0               876              PPP                    EMPIRICAL FOODS, INC.
# 1               876              PPP  COCA-COLA BOTTLING COMPANY HIGH COUNTRY
# 2               876              PPP                   DAKOTA PROVISIONS, LLC
# 3               876              PPP                     SONIFI SOLUTIONS INC
# 4               876              PPP                  SHOWPLACE WOOD PRODUCTS
# ...             ...              ...                                      ...
# 2690            876              PPP          EKHOLM ENTERPRISES INCORPORATED
# 2691            876              PPS         CARLSON'S NORTHSIDE SERVICE INC.
# 2692            876              PPP   HART RANCHING CAMPING RESORT CLUB, INC
# 2693            876              PPP                 TRADEMARK UNIFORMS, INC.
# 2694            876              PPS                         RMK PAINTING INC
#
#                   BorrowerAddress  BorrowerCity  ...  \
# 0               891 TWO RIVERS DR  DAKOTA DUNES  ...
# 1               2150 COCA COLA LN    RAPID CITY  ...
# 2             40253 US Highway 14         Huron  ...
# 3            3900 W Innovation St   Sioux Falls  ...
# 4                 1 Enterprise St    HARRISBURG  ...
# ...                           ...           ...  ...
# 2690  1101 West Glen Eagle Circle   Sioux Falls  ...
# 2691             320 Dakota Ave N         Huron  ...
# 2692               23756 ARENA DR    RAPID CITY  ...
# 2693               2011 W 45TH ST   SIOUX FALLS  ...
# 2694           713 S Phillips Ave   Sioux Falls  ...
#
#                       TRIIndustrySector  \
# 0                              311 Food
# 1     312 Beverage and Tobacco Products
# 2                              311 Food
# 3                             999 Other
# 4                         337 Furniture
# ...                                 ...
# 2690                          999 Other
# 2691                          999 Other
# 2692                          999 Other
# 2693                          999 Other
# 2694                          999 Other
#
#                                       IndustrySubsector 4DigitNAICS  \
# 0               3116 Animal Slaughtering and Processing      3116.0
# 1                           3121 Beverage Manufacturing      3121.0
# 2               3116 Animal Slaughtering and Processing      3116.0
# 3              5121 Motion Picture and Video Industries      5121.0
# 4     3371 Household and Institutional Furniture and...      3371.0
# ...                                                 ...         ...
# 2690                             5621 Waste Collection       5621.0
# 2691                            4471 Gasoline Stations       4471.0
# 2692  7212 RV (Recreational Vehicle) Parks and Recre...      7212.0
# 2693             8123 Drycleaning and Laundry Services       8123.0
# 2694                2383 Building Finishing Contractors      2383.0
#
#                     SBAOfficeLabel          Loan_Range    job_Range  \
# 0     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 1     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 2     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 3     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# 4     SOUTH DAKOTA DISTRICT OFFICE     e $5-10 million  500 or more
# ...                            ...                 ...          ...
# 2690  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 2691  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000       5 to 9
# 2692  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2693  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 2694  SOUTH DAKOTA DISTRICT OFFICE  a $150,000-350,000     10 to 19
#
#                                           full_add        Lat        Long  \
# 0              891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281
# 1                2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592
# 2                   40253 US Highway 14, Huron, SD  44.369109  -98.163177
# 3            3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704
# 4                  1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415
# ...                                            ...        ...         ...
# 2690  1101 West Glen Eagle Circle, Sioux Falls, SD  43.478080  -96.736384
# 2691                   320 Dakota Ave N, Huron, SD  44.369881  -98.213651
# 2692                23756 ARENA DR, RAPID CITY, SD  43.961714 -103.213474
# 2693               2011 W 45TH ST, SIOUX FALLS, SD  43.511243  -96.750715
# 2694           713 S Phillips Ave, Sioux Falls, SD  43.539763  -96.727161
#
#                FIPS_z
# 0     461270203011033
# 1     461030114003026
# 2     460059568001132
# 3     460990104051004
# 4     460830101073026
# ...               ...
# 2690  460830101162011
# 2691  460059568002064
# 2692  461030110052001
# 2693  460990015013029
# 2694  460990006002001
#
# [2695 rows x 73 columns]

# %%
#fips_merge_drop = fips_merge.drop(["Unnamed: 0.1", "Unnamed: 0.1.1.1"], axis=1)
fips_merge_drop.loc[fips_merge["FIPS_z"].isnull()] #verify #27 , notna #22799 / 22826
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 389       792463        792463          792463  5274317004       4/5/20
# 1301      793375        793375          793375  9903297002       4/9/20
#
#       SBAOfficeCode ProcessingMethod                   BorrowerName  \
# 389             876              PPP  TIM W OLSON CONSTRUCTION, INC
# 1301            876              PPP                    EASTMAN INC
#
#       BorrowerAddress   BorrowerCity  ... TRIIndustrySector  \
# 389   12525 US Hwy 20        BUFFALO  ...         999 Other
# 1301    12171 Lake Rd  BROWNS VALLEY  ...         999 Other
#
#                                       IndustrySubsector 4DigitNAICS  \
# 389   2381 Foundation, Structure, and Building Exter...      2381.0
# 1301                      4841 General Freight Trucking      4841.0
#
#                     SBAOfficeLabel            Loan_Range  job_Range  \
# 389   SOUTH DAKOTA DISTRICT OFFICE  b $350,000-1 million   50 to 99
# 1301  SOUTH DAKOTA DISTRICT OFFICE    a $150,000-350,000   20 to 49
#
#                               full_add        Lat        Long FIPS_z
# 389       12525 US Hwy 20, BUFFALO, SD  42.365652  -97.560766    NaN
# 1301  12171 Lake Rd, BROWNS VALLEY, SD  39.242114 -121.409130    NaN
#
# [2 rows x 73 columns]

# %% [markdown]
# Convert to File

# %%
fips_SD = fips_merge_drop

# %%
fips_SD.to_csv("../../data/state_data/geo/geo_fips/SD_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_sd_fips = pd.read_csv("../../data/state_data/geo/geo_fips/SD_fips_scraped.csv") 
geo_sd_fips.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 0           0        792074          792074            792074  3507637205
# 1           1        792075          792075            792075  1221237209
# 2           2        792076          792076            792076  4673147200
# 3           3        792077          792077            792077  6663527703
# 4           4        792078          792078            792078  7971747009
#
#   DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      4/27/20            876              PPP
# 1      4/15/20            876              PPP
# 2      4/27/20            876              PPP
# 3       5/1/20            876              PPP
# 4       4/8/20            876              PPP
#
#                               BorrowerName       BorrowerAddress  ...  \
# 0                    EMPIRICAL FOODS, INC.     891 TWO RIVERS DR  ...
# 1  COCA-COLA BOTTLING COMPANY HIGH COUNTRY     2150 COCA COLA LN  ...
# 2                   DAKOTA PROVISIONS, LLC   40253 US Highway 14  ...
# 3                     SONIFI SOLUTIONS INC  3900 W Innovation St  ...
# 4                  SHOWPLACE WOOD PRODUCTS       1 Enterprise St  ...
#
#                    TRIIndustrySector  \
# 0                           311 Food
# 1  312 Beverage and Tobacco Products
# 2                           311 Food
# 3                          999 Other
# 4                      337 Furniture
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0            3116 Animal Slaughtering and Processing       3116.0
# 1                        3121 Beverage Manufacturing       3121.0
# 2            3116 Animal Slaughtering and Processing       3116.0
# 3           5121 Motion Picture and Video Industries       5121.0
# 4  3371 Household and Institutional Furniture and...       3371.0
#
#                  SBAOfficeLabel       Loan_Range    job_Range  \
# 0  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 1  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 2  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 3  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
# 4  SOUTH DAKOTA DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                 full_add        Lat        Long        FIPS_z
# 0    891 TWO RIVERS DR, DAKOTA DUNES, SD  42.507600  -96.478281  4.612702e+14
# 1      2150 COCA COLA LN, RAPID CITY, SD  44.106394 -103.258592  4.610301e+14
# 2         40253 US Highway 14, Huron, SD  44.369109  -98.163177  4.600596e+14
# 3  3900 W Innovation St, Sioux Falls, SD  43.578588  -96.778704  4.609901e+14
# 4        1 Enterprise St, HARRISBURG, SD  43.439920  -96.703415  4.608301e+14
#
# [5 rows x 74 columns]

# %%
##### fill in missing Lat, Long, FIPS
geo_sd_fips.loc[geo_sd_fips["FIPS_z"].isnull()] #27
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  LoanNumber  \
# 389          389        792463          792463            792463  5274317004
# 1301        1301        793375          793375            793375  9903297002
#
#      DateApproved  SBAOfficeCode ProcessingMethod  \
# 389        4/5/20            876              PPP
# 1301       4/9/20            876              PPP
#
#                        BorrowerName  BorrowerAddress  ... TRIIndustrySector  \
# 389   TIM W OLSON CONSTRUCTION, INC  12525 US Hwy 20  ...         999 Other
# 1301                    EASTMAN INC    12171 Lake Rd  ...         999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 389   2381 Foundation, Structure, and Building Exter...       2381.0
# 1301                      4841 General Freight Trucking       4841.0
#
#                     SBAOfficeLabel            Loan_Range  job_Range  \
# 389   SOUTH DAKOTA DISTRICT OFFICE  b $350,000-1 million   50 to 99
# 1301  SOUTH DAKOTA DISTRICT OFFICE    a $150,000-350,000   20 to 49
#
#                               full_add        Lat        Long  FIPS_z
# 389       12525 US Hwy 20, BUFFALO, SD  42.365652  -97.560766     NaN
# 1301  12171 Lake Rd, BROWNS VALLEY, SD  39.242114 -121.409130     NaN
#
# [2 rows x 74 columns]
