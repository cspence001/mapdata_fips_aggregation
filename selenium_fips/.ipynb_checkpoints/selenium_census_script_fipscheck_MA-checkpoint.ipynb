# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_ma.csv") #- original geocoded file
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
fips_check.head() #10912
# Out:
#    Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0      398382        398382  1193108802       4/9/21            130
# 1      398383        398383  1588717109      4/10/20            101
# 2      398384        398384  1636668806      4/10/21            101
# 3      398385        398385  3105278807      4/14/21            101
# 4      398386        398386  3505097107      4/11/20            101
#
#   ProcessingMethod                            BorrowerName  \
# 0              PPP          BEHAVIORAL HEALTH NETWORK INC.
# 1              PPP          NEW ENGLAND AUTHENTIC EATS LLC
# 2              PPP  EAST BOSTON NEIGHBORHOOD HEALTH CENTER
# 3              PPP                         BRIDGEWELL INC.
# 4              PPP    SPRINGFIELD TERMINAL RAILWAY COMPANY
#
#           BorrowerAddress     BorrowerCity BorrowerState  ...  \
# 0          417 Liberty St      Springfield            MA  ...
# 1  600 Providence Highway           DEDHAM            MA  ...
# 2              10 Gove St      East Boston            MA  ...
# 3          10 Dearborn Rd          Peabody            MA  ...
# 4    1700 IRON HORSE PARK  NORTH BILLERICA            MA  ...
#
#                                             LongName TRIIndustrySector  \
# 0  Offices of Mental Health Practitioners (except...         999 Other
# 1                          Full-Service Restaurants          999 Other
# 2                 All Other Outpatient Care Centers          999 Other
# 3  Residential Mental Health and Substance Abuse ...         999 Other
# 4                               Line-Haul Railroads          999 Other
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0         6213 Offices of Other Health Practitioners       6213.0
# 1           7225 Restaurants and Other Eating Places       7225.0
# 2                       6214 Outpatient Care Centers       6214.0
# 3  6232 Residential Intellectual and Developmenta...       6232.0
# 4                           4821 Rail Transportation       4821.0
#
#                   SBAOfficeLabel       Loan_Range    job_Range  \
# 0      SPRINGFIELD BRANCH OFFICE  e $5-10 million  500 or more
# 1  MASSACHUSETTS DISTRICT OFFICE  e $5-10 million  500 or more
# 2  MASSACHUSETTS DISTRICT OFFICE  e $5-10 million  500 or more
# 3  MASSACHUSETTS DISTRICT OFFICE  e $5-10 million  500 or more
# 4  MASSACHUSETTS DISTRICT OFFICE  e $5-10 million  500 or more
#
#                                     full_add        Lat       Long
# 0            417 Liberty St, Springfield, MA  42.114272 -72.585082
# 1         600 Providence Highway, DEDHAM, MA  42.243154 -71.173284
# 2                10 Gove St, East Boston, MA  42.372271 -71.038169
# 3                10 Dearborn Rd, Peabody, MA  42.523734 -70.988951
# 4  1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955 -71.266540
#
# [5 rows x 71 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan
# Out:
#        LoanNumber                            full_add  Lat  Long
# 8854   4950267102    PO Box 508, East Bridgewater, MA  NaN   NaN
# 26136  3002827306  67 WEST ST Suite 101, MEDFIELD, MA  NaN   NaN
# 26215  7766498406       67 Catherine St, Chicopee, MA  NaN   NaN

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna.head() #10904
# Out:
#    LoanNumber                                   full_add        Lat       Long
# 0  1193108802            417 Liberty St, Springfield, MA  42.114272 -72.585082
# 1  1588717109         600 Providence Highway, DEDHAM, MA  42.243154 -71.173284
# 2  1636668806                10 Gove St, East Boston, MA  42.372271 -71.038169
# 3  3105278807                10 Dearborn Rd, Peabody, MA  42.523734 -70.988951
# 4  3505097107  1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955 -71.266540

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("data/state_data/geo/geo_fips/MA_fips_scraped.csv") 
fips_check_scraped.head()

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #40813

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #1239

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
    
executable_path = {'executable_path': ChromeDriverManager().install()}
driver = Browser('chrome', **executable_path, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('_x_id').clear()
        driver.find_by_id('_y_id').clear()
        driver.find_by_id('_x_id').fill(long[i])
        driver.find_by_id('_y_id').fill(lat[i])
        driver.find_by_id('proceed').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='pl_gov_census_geo_geocoder_domain_GeographyResult')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('25')] #MA
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                print(f"{i},{lat[i]},{long[i]} Not Found")
                notfound.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/ciaraspencer/.wdm/drivers/chromedriver/mac64/98.0.4758.102]
# HBox(children=(FloatProgress(value=0.0, max=27468.0), HTML(value='')))

# %% [markdown]
# coordinates wtih more than one return:
# 385,37.514070000000004,-77.35472 is ['514070000000004', '510872015041003']
# 1178,37.516454700000004,-77.8100575 is ['516454700000004', '511455001022014']
# 2660,37.519462299999994,-77.340384 is ['519462299999994', '510872014061012']
# second option reference FIPS code, first option references LatCoord, update fields in DataFrame

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 27468

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:1239]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
# <ipython-input-11-08e9c917fe2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fips_fill["FIPS_z"] = geo_id_list
#        LoanNumber                                   full_add        Lat  \
# 0      1193108802            417 Liberty St, Springfield, MA  42.114272
# 1      1588717109         600 Providence Highway, DEDHAM, MA  42.243154
# 2      1636668806                10 Gove St, East Boston, MA  42.372271
# 3      3105278807                10 Dearborn Rd, Peabody, MA  42.523734
# 4      3505097107  1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955
# ...           ...                                        ...        ...
# 27466  9721418410           942 Beacon St, Newton Center, MA  42.330335
# 27467  9816118406              100 Weymouth St, Rockland, MA  42.157247
# 27468  9869577804                260 MAIN ST, MARSHFIELD, MA  42.102761
# 27469  9919968406             102 South St Apt 3, Boston, MA  42.351130
# 27470  9992568400                 147 Summit St, Peabody, MA  42.519286
#
#             Long             FIPS_z
# 0     -72.585082  [250138009003008]
# 1     -71.173284  [250214024004002]
# 2     -71.038169  [250250506001005]
# 3     -70.988951  [250092103021003]
# 4     -71.266540  [250173165003016]
# ...          ...                ...
# 27466 -71.200201  [250173738004004]
# 27467 -70.908888  [250235022004000]
# 27468 -70.719124  [250235061024001]
# 27469 -71.057216  [250250701041015]
# 27470 -70.952730  [250092104022012]
#
# [27468 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
# <ipython-input-12-e19831f223ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
#        LoanNumber                                   full_add        Lat  \
# 0      1193108802            417 Liberty St, Springfield, MA  42.114272
# 1      1588717109         600 Providence Highway, DEDHAM, MA  42.243154
# 2      1636668806                10 Gove St, East Boston, MA  42.372271
# 3      3105278807                10 Dearborn Rd, Peabody, MA  42.523734
# 4      3505097107  1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955
# ...           ...                                        ...        ...
# 27466  9721418410           942 Beacon St, Newton Center, MA  42.330335
# 27467  9816118406              100 Weymouth St, Rockland, MA  42.157247
# 27468  9869577804                260 MAIN ST, MARSHFIELD, MA  42.102761
# 27469  9919968406             102 South St Apt 3, Boston, MA  42.351130
# 27470  9992568400                 147 Summit St, Peabody, MA  42.519286
#
#             Long           FIPS_z
# 0     -72.585082  250138009003008
# 1     -71.173284  250214024004002
# 2     -71.038169  250250506001005
# 3     -70.988951  250092103021003
# 4     -71.266540  250173165003016
# ...          ...              ...
# 27466 -71.200201  250173738004004
# 27467 -70.908888  250235022004000
# 27468 -70.719124  250235061024001
# 27469 -71.057216  250250701041015
# 27470 -70.952730  250092104022012
#
# [27468 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check
# Out:
#        LoanNumber                                    full_add        Lat  \
# 195    1986777209     171 PARK AVE STE 105, W SPRINGFIELD, MA  40.853720
# 449    3179517106    181 PARK AVE STE 5, WEST SPRINGFIELD, MA  40.804326
# 6319   9178467709  85 Douglas Pike Back Annex, Smithfield, MA  41.878805
# 6500   7483557208     1191 Chestnut St Suite 2-4, Newton,, MA  39.950560
# 9830   1925188408               58 Brickett Ln, Haverhill, MA  42.812902
# 10898  7215517004               58 BRICKETT LN, HAVERHILL, MA  42.812902
# 13344  9520167110                2525 Commerce Way, Vista, MA  33.149623
# 19343  1174077205       940 waterman ave, East Providence, MA  41.810657
#
#              Long FIPS_z
# 195    -73.967067    NaN
# 449    -73.939393    NaN
# 6319   -71.472838    NaN
# 6500   -75.160020    NaN
# 9830   -71.075033    NaN
# 10898  -71.075033    NaN
# 13344 -117.223241    NaN
# 19343  -71.345278    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#        LoanNumber           FIPS_z
# 0      1193108802  250138009003008
# 1      1588717109  250214024004002
# 2      1636668806  250250506001005
# 3      3105278807  250092103021003
# 4      3505097107  250173165003016
# ...           ...              ...
# 27466  9721418410  250173738004004
# 27467  9816118406  250235022004000
# 27468  9869577804  250235061024001
# 27469  9919968406  250250701041015
# 27470  9992568400  250092104022012
#
# [27468 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_ma.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check

#if from FIPS file
#fips_check = pd.read_csv("data/state_data/geo/geo_fips/MA_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #15796
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0          398382        398382  1193108802       4/9/21            130
# 1          398383        398383  1588717109      4/10/20            101
# 2          398384        398384  1636668806      4/10/21            101
# 3          398385        398385  3105278807      4/14/21            101
# 4          398386        398386  3505097107      4/11/20            101
# ...           ...           ...         ...          ...            ...
# 27466      425848        425848  9721418410      2/17/21            101
# 27467      425849        425849  9816118406      2/17/21            101
# 27468      425850        425850  9869577804       6/9/20            101
# 27469      425851        425851  9919968406      2/18/21            101
# 27470      425852        425852  9992568400      2/18/21            101
#
#       ProcessingMethod                            BorrowerName  \
# 0                  PPP          BEHAVIORAL HEALTH NETWORK INC.
# 1                  PPP          NEW ENGLAND AUTHENTIC EATS LLC
# 2                  PPP  EAST BOSTON NEIGHBORHOOD HEALTH CENTER
# 3                  PPP                         BRIDGEWELL INC.
# 4                  PPP    SPRINGFIELD TERMINAL RAILWAY COMPANY
# ...                ...                                     ...
# 27466              PPS                    ABBOT MILL WORKS LLC
# 27467              PPS                   ATLANTIC NUCLEAR CORP
# 27468              PPP  CHERUBS CHILD DEVELOPMENT CENTER, INC.
# 27469              PPS          BBIX LIMITED LIABILITY COMPANY
# 27470              PPS                             CAPONES INC
#
#               BorrowerAddress     BorrowerCity BorrowerState  ...  \
# 0              417 Liberty St      Springfield            MA  ...
# 1      600 Providence Highway           DEDHAM            MA  ...
# 2                  10 Gove St      East Boston            MA  ...
# 3              10 Dearborn Rd          Peabody            MA  ...
# 4        1700 IRON HORSE PARK  NORTH BILLERICA            MA  ...
# ...                       ...              ...           ...  ...
# 27466           942 Beacon St    Newton Center            MA  ...
# 27467         100 Weymouth St         Rockland            MA  ...
# 27468             260 MAIN ST       MARSHFIELD            MA  ...
# 27469      102 South St Apt 3           Boston            MA  ...
# 27470           147 Summit St          Peabody            MA  ...
#
#                                                 LongName TRIIndustrySector  \
# 0      Offices of Mental Health Practitioners (except...         999 Other
# 1                              Full-Service Restaurants          999 Other
# 2                     All Other Outpatient Care Centers          999 Other
# 3      Residential Mental Health and Substance Abuse ...         999 Other
# 4                                   Line-Haul Railroads          999 Other
# ...                                                  ...               ...
# 27466           Fitness and Recreational Sports Centers          999 Other
# 27467                               Testing Laboratories         999 Other
# 27468                           Child Day Care Services          999 Other
# 27469                               Engineering Services         999 Other
# 27470                          Full-Service Restaurants          999 Other
#
#                                        IndustrySubsector  4DigitNAICS  \
# 0             6213 Offices of Other Health Practitioners       6213.0
# 1               7225 Restaurants and Other Eating Places       7225.0
# 2                           6214 Outpatient Care Centers       6214.0
# 3      6232 Residential Intellectual and Developmenta...       6232.0
# 4                               4821 Rail Transportation       4821.0
# ...                                                  ...          ...
# 27466     7139 Other Amusement and Recreation Industries       7139.0
# 27467  5413 Architectural, Engineering, and Related S...       5413.0
# 27468                       6244 Child Day Care Services       6244.0
# 27469  5413 Architectural, Engineering, and Related S...       5413.0
# 27470           7225 Restaurants and Other Eating Places       7225.0
#
#                       SBAOfficeLabel          Loan_Range    job_Range  \
# 0          SPRINGFIELD BRANCH OFFICE     e $5-10 million  500 or more
# 1      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 2      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 3      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 4      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# ...                              ...                 ...          ...
# 27466  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 27467  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 27468  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 27469  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 27470  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000       5 to 9
#
#                                         full_add        Lat       Long
# 0                417 Liberty St, Springfield, MA  42.114272 -72.585082
# 1             600 Providence Highway, DEDHAM, MA  42.243154 -71.173284
# 2                    10 Gove St, East Boston, MA  42.372271 -71.038169
# 3                    10 Dearborn Rd, Peabody, MA  42.523734 -70.988951
# 4      1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955 -71.266540
# ...                                          ...        ...        ...
# 27466           942 Beacon St, Newton Center, MA  42.330335 -71.200201
# 27467              100 Weymouth St, Rockland, MA  42.157247 -70.908888
# 27468                260 MAIN ST, MARSHFIELD, MA  42.102761 -70.719124
# 27469             102 South St Apt 3, Boston, MA  42.351130 -71.057216
# 27470                 147 Summit St, Peabody, MA  42.519286 -70.952730
#
# [27471 rows x 71 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0          398382        398382  1193108802       4/9/21            130
# 1          398383        398383  1588717109      4/10/20            101
# 2          398384        398384  1636668806      4/10/21            101
# 3          398385        398385  3105278807      4/14/21            101
# 4          398386        398386  3505097107      4/11/20            101
# ...           ...           ...         ...          ...            ...
# 27466      425848        425848  9721418410      2/17/21            101
# 27467      425849        425849  9816118406      2/17/21            101
# 27468      425850        425850  9869577804       6/9/20            101
# 27469      425851        425851  9919968406      2/18/21            101
# 27470      425852        425852  9992568400      2/18/21            101
#
#       ProcessingMethod                            BorrowerName  \
# 0                  PPP          BEHAVIORAL HEALTH NETWORK INC.
# 1                  PPP          NEW ENGLAND AUTHENTIC EATS LLC
# 2                  PPP  EAST BOSTON NEIGHBORHOOD HEALTH CENTER
# 3                  PPP                         BRIDGEWELL INC.
# 4                  PPP    SPRINGFIELD TERMINAL RAILWAY COMPANY
# ...                ...                                     ...
# 27466              PPS                    ABBOT MILL WORKS LLC
# 27467              PPS                   ATLANTIC NUCLEAR CORP
# 27468              PPP  CHERUBS CHILD DEVELOPMENT CENTER, INC.
# 27469              PPS          BBIX LIMITED LIABILITY COMPANY
# 27470              PPS                             CAPONES INC
#
#               BorrowerAddress     BorrowerCity BorrowerState  ...  \
# 0              417 Liberty St      Springfield            MA  ...
# 1      600 Providence Highway           DEDHAM            MA  ...
# 2                  10 Gove St      East Boston            MA  ...
# 3              10 Dearborn Rd          Peabody            MA  ...
# 4        1700 IRON HORSE PARK  NORTH BILLERICA            MA  ...
# ...                       ...              ...           ...  ...
# 27466           942 Beacon St    Newton Center            MA  ...
# 27467         100 Weymouth St         Rockland            MA  ...
# 27468             260 MAIN ST       MARSHFIELD            MA  ...
# 27469      102 South St Apt 3           Boston            MA  ...
# 27470           147 Summit St          Peabody            MA  ...
#
#        TRIIndustrySector                                  IndustrySubsector  \
# 0              999 Other         6213 Offices of Other Health Practitioners
# 1              999 Other           7225 Restaurants and Other Eating Places
# 2              999 Other                       6214 Outpatient Care Centers
# 3              999 Other  6232 Residential Intellectual and Developmenta...
# 4              999 Other                           4821 Rail Transportation
# ...                  ...                                                ...
# 27466          999 Other     7139 Other Amusement and Recreation Industries
# 27467          999 Other  5413 Architectural, Engineering, and Related S...
# 27468          999 Other                       6244 Child Day Care Services
# 27469          999 Other  5413 Architectural, Engineering, and Related S...
# 27470          999 Other           7225 Restaurants and Other Eating Places
#
#       4DigitNAICS                 SBAOfficeLabel          Loan_Range  \
# 0          6213.0      SPRINGFIELD BRANCH OFFICE     e $5-10 million
# 1          7225.0  MASSACHUSETTS DISTRICT OFFICE     e $5-10 million
# 2          6214.0  MASSACHUSETTS DISTRICT OFFICE     e $5-10 million
# 3          6232.0  MASSACHUSETTS DISTRICT OFFICE     e $5-10 million
# 4          4821.0  MASSACHUSETTS DISTRICT OFFICE     e $5-10 million
# ...           ...                            ...                 ...
# 27466      7139.0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000
# 27467      5413.0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000
# 27468      6244.0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000
# 27469      5413.0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000
# 27470      7225.0  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000
#
#          job_Range                                   full_add        Lat  \
# 0      500 or more            417 Liberty St, Springfield, MA  42.114272
# 1      500 or more         600 Providence Highway, DEDHAM, MA  42.243154
# 2      500 or more                10 Gove St, East Boston, MA  42.372271
# 3      500 or more                10 Dearborn Rd, Peabody, MA  42.523734
# 4      500 or more  1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955
# ...            ...                                        ...        ...
# 27466     20 to 49           942 Beacon St, Newton Center, MA  42.330335
# 27467     10 to 19              100 Weymouth St, Rockland, MA  42.157247
# 27468     20 to 49                260 MAIN ST, MARSHFIELD, MA  42.102761
# 27469     10 to 19             102 South St Apt 3, Boston, MA  42.351130
# 27470       5 to 9                 147 Summit St, Peabody, MA  42.519286
#
#             Long           FIPS_z
# 0     -72.585082  250138009003008
# 1     -71.173284  250214024004002
# 2     -71.038169  250250506001005
# 3     -70.988951  250092103021003
# 4     -71.266540  250173165003016
# ...          ...              ...
# 27466 -71.200201  250173738004004
# 27467 -70.908888  250235022004000
# 27468 -70.719124  250235061024001
# 27469 -71.057216  250250701041015
# 27470 -70.952730  250092104022012
#
# [27471 rows x 72 columns]

# %% [markdown]
# If FIPS Encoded

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
fips_merge_drop

# %%
fips_merge.loc[fips_merge["FIPS_z"].isnull()] #11
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 195        398577        398577  1986777209      4/15/20            130
# 449        398831        398831  3179517106      4/11/20            130
# 6319       404701        404701  9178467709       5/1/20            101
# 6500       404882        404882  7483557208      4/28/20            101
# 8854       407236        407236  4950267102      4/13/20            101
# 9830       408212        408212  1925188408       2/2/21            101
# 10898      409280        409280  7215517004       4/7/20            101
# 13344      411726        411726  9520167110      4/15/20            101
# 19343      417725        417725  1174077205      4/15/20            101
# 26136      424518        424518  3002827306      4/29/20            101
# 26215      424597        424597  7766498406      2/12/21            130
#
#       ProcessingMethod                             BorrowerName  \
# 195                PPP          AFFINITY DENTAL MANAGEMENT INC.
# 449                PPP     SPRINGFIELD ANESTHESIA SERVICE, INC.
# 6319               PPP                        NES SOLUTIONS LLC
# 6500               PPP                               VALZAR LLC
# 8854               PPP                         ATL CONSTRUCTION
# 9830               PPS       HAVERHILL GOLF & COUNTRY CLUB INC.
# 10898              PPP          HAVERHILL GOLF AND COUNTRY CLUB
# 13344              PPP               THE COROMEGA COMPANY, INC.
# 19343              PPP  INTERNATIONAL SOURCING & MARKETING, LTD
# 26136              PPP               THE GARDEN CONTINUUM, INC.
# 26215              PPS           ANDRE MARCOUX ENTERPRISES INC.
#
#                   BorrowerAddress      BorrowerCity BorrowerState  ...  \
# 195          171 PARK AVE STE 105     W SPRINGFIELD            MA  ...
# 449            181 PARK AVE STE 5  WEST SPRINGFIELD            MA  ...
# 6319   85 Douglas Pike Back Annex        Smithfield            MA  ...
# 6500   1191 Chestnut St Suite 2-4           Newton,            MA  ...
# 8854                   PO Box 508  East Bridgewater            MA  ...
# 9830               58 Brickett Ln         Haverhill            MA  ...
# 10898              58 BRICKETT LN         HAVERHILL            MA  ...
# 13344           2525 Commerce Way             Vista            MA  ...
# 19343            940 waterman ave   East Providence            MA  ...
# 26136        67 WEST ST Suite 101          MEDFIELD            MA  ...
# 26215             67 Catherine St          Chicopee            MA  ...
#
#                            TRIIndustrySector  \
# 195                                999 Other
# 449                                999 Other
# 6319                                     NaN
# 6500                               999 Other
# 8854                               999 Other
# 9830                               999 Other
# 10898                              999 Other
# 13344                          325 Chemicals
# 19343  334 Computers and Electronic Products
# 26136                              999 Other
# 26215                              999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 195                             6212 Offices of Dentists      6212.0
# 449                           6211 Offices of Physicians      6211.0
# 6319                                                 NaN         NaN
# 6500                 6241 Individual and Family Services      6241.0
# 8854       2373 Highway, Street, and Bridge Construction      2373.0
# 9830      7139 Other Amusement and Recreation Industries      7139.0
# 10898     7139 Other Amusement and Recreation Industries      7139.0
# 13344     3254 Pharmaceutical and Medicine Manufacturing      3254.0
# 19343  3344 Semiconductor and Other Electronic Compon...      3344.0
# 26136           5617 Services to Buildings and Dwellings      5617.0
# 26215             8111 Automotive Repair and Maintenance      8111.0
#
#                       SBAOfficeLabel            Loan_Range   job_Range  \
# 195        SPRINGFIELD BRANCH OFFICE        d $2-5 million  250 to 499
# 449        SPRINGFIELD BRANCH OFFICE        d $2-5 million  100 to 249
# 6319   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million  100 to 249
# 6500   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 8854   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 9830   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 10898  MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 13344  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 19343  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 26136  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 26215      SPRINGFIELD BRANCH OFFICE    a $150,000-350,000    10 to 19
#
#                                          full_add        Lat        Long  \
# 195       171 PARK AVE STE 105, W SPRINGFIELD, MA  40.853720  -73.967067
# 449      181 PARK AVE STE 5, WEST SPRINGFIELD, MA  40.804326  -73.939393
# 6319   85 Douglas Pike Back Annex, Smithfield, MA  41.878805  -71.472838
# 6500      1191 Chestnut St Suite 2-4, Newton,, MA  39.950560  -75.160020
# 8854             PO Box 508, East Bridgewater, MA        NaN         NaN
# 9830                58 Brickett Ln, Haverhill, MA  42.812902  -71.075033
# 10898               58 BRICKETT LN, HAVERHILL, MA  42.812902  -71.075033
# 13344                2525 Commerce Way, Vista, MA  33.149623 -117.223241
# 19343       940 waterman ave, East Providence, MA  41.810657  -71.345278
# 26136          67 WEST ST Suite 101, MEDFIELD, MA        NaN         NaN
# 26215               67 Catherine St, Chicopee, MA        NaN         NaN
#
#        FIPS_z
# 195       NaN
# 449       NaN
# 6319      NaN
# 6500      NaN
# 8854      NaN
# 9830      NaN
# 10898     NaN
# 13344     NaN
# 19343     NaN
# 26136     NaN
# 26215     NaN
#
# [11 rows x 72 columns]

# %%
geo_MA_fips = fips_merge

# %% [markdown]
# Convert to File

# %%
geo_MA_fips.to_csv("data/state_data/geo/geo_fips/MA_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_MA_fips = pd.read_csv("data/state_data/geo/geo_fips/MA_fips_scraped.csv") 
geo_MA_fips
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0               0        398382          398382  1193108802       4/9/21
# 1               1        398383          398383  1588717109      4/10/20
# 2               2        398384          398384  1636668806      4/10/21
# 3               3        398385          398385  3105278807      4/14/21
# 4               4        398386          398386  3505097107      4/11/20
# ...           ...           ...             ...         ...          ...
# 27466       27466        425848          425848  9721418410      2/17/21
# 27467       27467        425849          425849  9816118406      2/17/21
# 27468       27468        425850          425850  9869577804       6/9/20
# 27469       27469        425851          425851  9919968406      2/18/21
# 27470       27470        425852          425852  9992568400      2/18/21
#
#        SBAOfficeCode ProcessingMethod                            BorrowerName  \
# 0                130              PPP          BEHAVIORAL HEALTH NETWORK INC.
# 1                101              PPP          NEW ENGLAND AUTHENTIC EATS LLC
# 2                101              PPP  EAST BOSTON NEIGHBORHOOD HEALTH CENTER
# 3                101              PPP                         BRIDGEWELL INC.
# 4                101              PPP    SPRINGFIELD TERMINAL RAILWAY COMPANY
# ...              ...              ...                                     ...
# 27466            101              PPS                    ABBOT MILL WORKS LLC
# 27467            101              PPS                   ATLANTIC NUCLEAR CORP
# 27468            101              PPP  CHERUBS CHILD DEVELOPMENT CENTER, INC.
# 27469            101              PPS          BBIX LIMITED LIABILITY COMPANY
# 27470            101              PPS                             CAPONES INC
#
#               BorrowerAddress     BorrowerCity  ... TRIIndustrySector  \
# 0              417 Liberty St      Springfield  ...         999 Other
# 1      600 Providence Highway           DEDHAM  ...         999 Other
# 2                  10 Gove St      East Boston  ...         999 Other
# 3              10 Dearborn Rd          Peabody  ...         999 Other
# 4        1700 IRON HORSE PARK  NORTH BILLERICA  ...         999 Other
# ...                       ...              ...  ...               ...
# 27466           942 Beacon St    Newton Center  ...         999 Other
# 27467         100 Weymouth St         Rockland  ...         999 Other
# 27468             260 MAIN ST       MARSHFIELD  ...         999 Other
# 27469      102 South St Apt 3           Boston  ...         999 Other
# 27470           147 Summit St          Peabody  ...         999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 0             6213 Offices of Other Health Practitioners      6213.0
# 1               7225 Restaurants and Other Eating Places      7225.0
# 2                           6214 Outpatient Care Centers      6214.0
# 3      6232 Residential Intellectual and Developmenta...      6232.0
# 4                               4821 Rail Transportation      4821.0
# ...                                                  ...         ...
# 27466     7139 Other Amusement and Recreation Industries      7139.0
# 27467  5413 Architectural, Engineering, and Related S...      5413.0
# 27468                       6244 Child Day Care Services      6244.0
# 27469  5413 Architectural, Engineering, and Related S...      5413.0
# 27470           7225 Restaurants and Other Eating Places      7225.0
#
#                       SBAOfficeLabel          Loan_Range    job_Range  \
# 0          SPRINGFIELD BRANCH OFFICE     e $5-10 million  500 or more
# 1      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 2      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 3      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# 4      MASSACHUSETTS DISTRICT OFFICE     e $5-10 million  500 or more
# ...                              ...                 ...          ...
# 27466  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 27467  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 27468  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 27469  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 27470  MASSACHUSETTS DISTRICT OFFICE  a $150,000-350,000       5 to 9
#
#                                         full_add        Lat       Long  \
# 0                417 Liberty St, Springfield, MA  42.114272 -72.585082
# 1             600 Providence Highway, DEDHAM, MA  42.243154 -71.173284
# 2                    10 Gove St, East Boston, MA  42.372271 -71.038169
# 3                    10 Dearborn Rd, Peabody, MA  42.523734 -70.988951
# 4      1700 IRON HORSE PARK, NORTH BILLERICA, MA  42.581955 -71.266540
# ...                                          ...        ...        ...
# 27466           942 Beacon St, Newton Center, MA  42.330335 -71.200201
# 27467              100 Weymouth St, Rockland, MA  42.157247 -70.908888
# 27468                260 MAIN ST, MARSHFIELD, MA  42.102761 -70.719124
# 27469             102 South St Apt 3, Boston, MA  42.351130 -71.057216
# 27470                 147 Summit St, Peabody, MA  42.519286 -70.952730
#
#              FIPS_z
# 0      2.501380e+14
# 1      2.502140e+14
# 2      2.502505e+14
# 3      2.500921e+14
# 4      2.501732e+14
# ...             ...
# 27466  2.501737e+14
# 27467  2.502350e+14
# 27468  2.502351e+14
# 27469  2.502507e+14
# 27470  2.500921e+14
#
# [27471 rows x 73 columns]

# %%
#fill in missing Lat, Long, FIPS
geo_MA_fips.loc[geo_MA_fips["FIPS_z"].isnull()] #11
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 195           195        398577          398577  1986777209      4/15/20
# 449           449        398831          398831  3179517106      4/11/20
# 6319         6319        404701          404701  9178467709       5/1/20
# 6500         6500        404882          404882  7483557208      4/28/20
# 8854         8854        407236          407236  4950267102      4/13/20
# 9830         9830        408212          408212  1925188408       2/2/21
# 10898       10898        409280          409280  7215517004       4/7/20
# 13344       13344        411726          411726  9520167110      4/15/20
# 19343       19343        417725          417725  1174077205      4/15/20
# 26136       26136        424518          424518  3002827306      4/29/20
# 26215       26215        424597          424597  7766498406      2/12/21
#
#        SBAOfficeCode ProcessingMethod  \
# 195              130              PPP
# 449              130              PPP
# 6319             101              PPP
# 6500             101              PPP
# 8854             101              PPP
# 9830             101              PPS
# 10898            101              PPP
# 13344            101              PPP
# 19343            101              PPP
# 26136            101              PPP
# 26215            130              PPS
#
#                                   BorrowerName             BorrowerAddress  \
# 195            AFFINITY DENTAL MANAGEMENT INC.        171 PARK AVE STE 105
# 449       SPRINGFIELD ANESTHESIA SERVICE, INC.          181 PARK AVE STE 5
# 6319                         NES SOLUTIONS LLC  85 Douglas Pike Back Annex
# 6500                                VALZAR LLC  1191 Chestnut St Suite 2-4
# 8854                          ATL CONSTRUCTION                  PO Box 508
# 9830        HAVERHILL GOLF & COUNTRY CLUB INC.              58 Brickett Ln
# 10898          HAVERHILL GOLF AND COUNTRY CLUB              58 BRICKETT LN
# 13344               THE COROMEGA COMPANY, INC.           2525 Commerce Way
# 19343  INTERNATIONAL SOURCING & MARKETING, LTD            940 waterman ave
# 26136               THE GARDEN CONTINUUM, INC.        67 WEST ST Suite 101
# 26215           ANDRE MARCOUX ENTERPRISES INC.             67 Catherine St
#
#            BorrowerCity  ...                      TRIIndustrySector  \
# 195       W SPRINGFIELD  ...                              999 Other
# 449    WEST SPRINGFIELD  ...                              999 Other
# 6319         Smithfield  ...                                    NaN
# 6500            Newton,  ...                              999 Other
# 8854   East Bridgewater  ...                              999 Other
# 9830          Haverhill  ...                              999 Other
# 10898         HAVERHILL  ...                              999 Other
# 13344             Vista  ...                          325 Chemicals
# 19343   East Providence  ...  334 Computers and Electronic Products
# 26136          MEDFIELD  ...                              999 Other
# 26215          Chicopee  ...                              999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 195                             6212 Offices of Dentists      6212.0
# 449                           6211 Offices of Physicians      6211.0
# 6319                                                 NaN         NaN
# 6500                 6241 Individual and Family Services      6241.0
# 8854       2373 Highway, Street, and Bridge Construction      2373.0
# 9830      7139 Other Amusement and Recreation Industries      7139.0
# 10898     7139 Other Amusement and Recreation Industries      7139.0
# 13344     3254 Pharmaceutical and Medicine Manufacturing      3254.0
# 19343  3344 Semiconductor and Other Electronic Compon...      3344.0
# 26136           5617 Services to Buildings and Dwellings      5617.0
# 26215             8111 Automotive Repair and Maintenance      8111.0
#
#                       SBAOfficeLabel            Loan_Range   job_Range  \
# 195        SPRINGFIELD BRANCH OFFICE        d $2-5 million  250 to 499
# 449        SPRINGFIELD BRANCH OFFICE        d $2-5 million  100 to 249
# 6319   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million  100 to 249
# 6500   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 8854   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 9830   MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    50 to 99
# 10898  MASSACHUSETTS DISTRICT OFFICE  b $350,000-1 million    20 to 49
# 13344  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    20 to 49
# 19343  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 26136  MASSACHUSETTS DISTRICT OFFICE    a $150,000-350,000    10 to 19
# 26215      SPRINGFIELD BRANCH OFFICE    a $150,000-350,000    10 to 19
#
#                                          full_add        Lat        Long  \
# 195       171 PARK AVE STE 105, W SPRINGFIELD, MA  40.853719  -73.967067
# 449      181 PARK AVE STE 5, WEST SPRINGFIELD, MA  40.804326  -73.939393
# 6319   85 Douglas Pike Back Annex, Smithfield, MA  41.878805  -71.472838
# 6500      1191 Chestnut St Suite 2-4, Newton,, MA  39.950560  -75.160020
# 8854             PO Box 508, East Bridgewater, MA        NaN         NaN
# 9830                58 Brickett Ln, Haverhill, MA  42.812902  -71.075033
# 10898               58 BRICKETT LN, HAVERHILL, MA  42.812902  -71.075033
# 13344                2525 Commerce Way, Vista, MA  33.149623 -117.223241
# 19343       940 waterman ave, East Providence, MA  41.810657  -71.345278
# 26136          67 WEST ST Suite 101, MEDFIELD, MA        NaN         NaN
# 26215               67 Catherine St, Chicopee, MA        NaN         NaN
#
#       FIPS_z
# 195      NaN
# 449      NaN
# 6319     NaN
# 6500     NaN
# 8854     NaN
# 9830     NaN
# 10898    NaN
# 13344    NaN
# 19343    NaN
# 26136    NaN
# 26215    NaN
#
# [11 rows x 73 columns]
