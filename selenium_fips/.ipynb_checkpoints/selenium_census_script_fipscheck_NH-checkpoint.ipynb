# %%
#dependencies
import re
from bs4 import BeautifulSoup 
from splinter import Browser
import requests
import pandas as pd
from selenium import webdriver 
from selenium.common.exceptions import TimeoutException
from webdriver_manager.chrome import ChromeDriverManager
import json
import time
from tqdm.notebook import tqdm

# %% [markdown]
# <h4>Start cells here if {state}_geo file has not been FIPS encoded

# %%
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_nh.csv") #- original geocoded file
fips_check = fips_check.drop(["Unnamed: 0.1"], axis =1) 
fips_check.head() #10912
# Out:
#    Unnamed: 0  LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0      555483  3128618805      4/14/21            189              PPP
# 1      555484  5946307005       4/6/20            189              PPP
# 2      555485  3345347110      4/11/20            189              PPP
# 3      555486  8543107003       4/8/20            189              PPP
# 4      555487  2415809002      5/16/21            189              PPP
#
#                            BorrowerName         BorrowerAddress BorrowerCity  \
# 0        EASTER SEALS NEW HAMPSHIRE INC           555 Auburn St   Manchester
# 1                NAPOLI PSC SERIES, LLC           5 OVERLOOK DR      AMHERST
# 2             EASTERN PROPANE GAS, INC.       28 industrial way    ROCHESTER
# 3    THE GRANITE GROUP WHOLESALERS, LLC             6 STORRS ST      CONCORD
# 4  LITTLETON HOSPITAL ASSOCIATION, INC.  600 Saint Johnsbury Rd    Littleton
#
#   BorrowerState  BorrowerZip  ...  \
# 0            NH       3103.0  ...
# 1            NH       3031.0  ...
# 2            NH       3867.0  ...
# 3            NH       3301.0  ...
# 4            NH       3561.0  ...
#
#                                             LongName TRIIndustrySector  \
# 0  Services for the Elderly and Persons with Disa...         999 Other
# 1                       Limited-Service Restaurants          999 Other
# 2         Gasoline Stations with Convenience Stores          999 Other
# 3  Household Appliances, Electric Housewares, and...         999 Other
# 4            General Medical and Surgical Hospitals          999 Other
#
#                                    IndustrySubsector  4DigitNAICS  \
# 0                6241 Individual and Family Services       6241.0
# 1           7225 Restaurants and Other Eating Places       7225.0
# 2                            4471 Gasoline Stations        4471.0
# 3  4236 Household Appliances and Electrical and E...       4236.0
# 4        6221 General Medical and Surgical Hospitals       6221.0
#
#                   SBAOfficeLabel       Loan_Range    job_Range  \
# 0  NEW HAMPSHIRE DISTRICT OFFICE  e $5-10 million  500 or more
# 1  NEW HAMPSHIRE DISTRICT OFFICE  e $5-10 million     20 to 49
# 2  NEW HAMPSHIRE DISTRICT OFFICE  e $5-10 million   250 to 499
# 3  NEW HAMPSHIRE DISTRICT OFFICE  e $5-10 million  500 or more
# 4  NEW HAMPSHIRE DISTRICT OFFICE  e $5-10 million   250 to 499
#
#                                 full_add        Lat       Long
# 0          555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1             5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2       28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3               6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4  600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
#
# [5 rows x 70 columns]

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long']
fips_check = fips_check[columns]

# %%
fips_check_nan = fips_check[fips_check["Lat"].isnull()] # check to make sure no nulls in coords
fips_check_nan
# Out:
# Empty DataFrame
# Columns: [LoanNumber, full_add, Lat, Long]
# Index: []

# %%
fips_check_notna = fips_check[fips_check["Lat"].notna()] # check to make sure no nulls in coords
fips_check_notna #5078
# Out:
#       LoanNumber                               full_add        Lat       Long
# 0     3128618805          555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1     5946307005             5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2     3345347110       28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3     8543107003               6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4     2415809002  600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
# ...          ...                                    ...        ...        ...
# 5073  8327357003      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365 -71.156578
# 5074  8453917202     453 CENTRAL AVENUE #107, DOVER, NH  43.197461 -70.873775
# 5075  8581768304                   114 Mast Rd, Lee, NH  43.135207 -70.988428
# 5076  9240498803              182 W Main St, Conway, NH  43.976081 -71.132761
# 5077  9968318308           20 Market St, Manchester, NH  42.990220 -71.463840
#
# [5078 rows x 4 columns]

# %% [markdown]
# <h4> Start cells here if partial FIPS already available in {state}_fips_scraped file

# %%
fips_check_scraped = pd.read_csv("data/state_data/geo/geo_fips/NH_fips_scraped.csv") 
fips_check_scraped.head()

# %%
columns = ['LoanNumber','full_add', 'Lat', 'Long', 'FIPS_z']
fips_check_scraped = fips_check_scraped[columns]

# %%
#pd.set_option('display.float_format', '{:.0f}'.format)

# %%
#Latitude, Longitude, not included
fips_check_scraped_notna = fips_check_scraped[fips_check_scraped["Lat"].notna()] # check to make sure no nulls in coords
fips_check_scraped_notna #40813

# %%
#FIPS not included, of Lat, Long available
fips_check_scraped_null = fips_check_scraped_notna[fips_check_scraped_notna["FIPS_z"].isnull()] # check to make sure no nulls in coords
fips_check_scraped_null #1239

# %% [markdown]
# <h4>FIPS Script

# %%
#if geocode file
lat = fips_check_notna["Lat"].astype(float).astype(str).to_list()
long = fips_check_notna["Long"].astype(float).astype(str).to_list()

#if FIPS_z file 
#lat = fips_check_scraped_null["Lat"].astype(float).astype(str).to_list()
#long = fips_check_scraped_null["Long"].astype(float).astype(str).to_list()

# %%
#before running script, check for any NaN within Lat, Long fields. 
def sleep():
    time.sleep(1)
    
executable_path = {'executable_path': ChromeDriverManager().install()}
driver = Browser('chrome', **executable_path, headless=False)    
url = 'https://geocoding.geo.census.gov/geocoder/geographies/coordinates?form'
driver.visit(url)

not_found = []
geo_id = []

i=0
for i in tqdm(range(len(lat))):
    #while i < len(lat):
        driver.find_by_id('_x_id').clear()
        driver.find_by_id('_y_id').clear()
        driver.find_by_id('_x_id').fill(long[i])
        driver.find_by_id('_y_id').fill(lat[i])
        driver.find_by_id('proceed').click()
        #sleep()
        #html = driver.html
        soup = BeautifulSoup(driver.html, 'html.parser')


        results = soup.find_all('div', id='pl_gov_census_geo_geocoder_domain_GeographyResult')
        for result in results:
            result_text = result.text

            result_digits = re.findall('\d+', result_text)
            startswith = [s for s in result_digits if s.startswith('33')] #NH
            fips_elements =[element for element in startswith if len(element)>=15]
            
            try:
                #print(f"{i},{lat[i]},{long[i]} is {fips_elements}")
                geo_id.append(fips_elements)
            except (KeyError, IndexError):
                print(f"{i},{lat[i]},{long[i]} Not Found")
                notfound.append(i)
                geo_id.append(None)  
            except (TimeoutException):
                driver.navigate.refresh()
    
        #sleep()
        i=i+1
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/ciaraspencer/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# HBox(children=(FloatProgress(value=0.0, max=5078.0), HTML(value='')))

# %% [markdown]
# https://iqss.github.io/dss-webscrape/filling-in-web-forms.html

# %%
geo_id_list =geo_id

# %% [markdown]
# Length Check

# %%
print(len(geo_id_list))
# Out:
# 5078

# %% [markdown]
# Matching FIPS to DataFrame

# %%
#for geocode file
fips_fill = fips_check_notna #confirm pair to notna DataFrame
#if FIPS available
#fips_fill = fips_check_scraped_null.iloc[:1239]

# %%
fips_fill["FIPS_z"] = geo_id_list
fips_fill
# Out:
#       LoanNumber                               full_add        Lat       Long  \
# 0     3128618805          555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1     5946307005             5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2     3345347110       28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3     8543107003               6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4     2415809002  600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
# ...          ...                                    ...        ...        ...
# 5073  8327357003      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365 -71.156578
# 5074  8453917202     453 CENTRAL AVENUE #107, DOVER, NH  43.197461 -70.873775
# 5075  8581768304                   114 Mast Rd, Lee, NH  43.135207 -70.988428
# 5076  9240498803              182 W Main St, Conway, NH  43.976081 -71.132761
# 5077  9968318308           20 Market St, Manchester, NH  42.990220 -71.463840
#
#                  FIPS_z
# 0     [330110016002004]
# 1     [330110152003024]
# 2     [330170846001012]
# 3     [330130322002006]
# 4     [330099601023039]
# ...                 ...
# 5073  [330079506001009]
# 5074  [330170814002015]
# 5075  [330170805003003]
# 5076  [330039554012002]
# 5077  [330112004004013]
#
# [5078 rows x 5 columns]

# %% [markdown]
# Remove brackets

# %%
fips_fill['FIPS_z'] = fips_fill['FIPS_z'].str[0]
fips_fill
# Out:
#       LoanNumber                               full_add        Lat       Long  \
# 0     3128618805          555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1     5946307005             5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2     3345347110       28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3     8543107003               6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4     2415809002  600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
# ...          ...                                    ...        ...        ...
# 5073  8327357003      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365 -71.156578
# 5074  8453917202     453 CENTRAL AVENUE #107, DOVER, NH  43.197461 -70.873775
# 5075  8581768304                   114 Mast Rd, Lee, NH  43.135207 -70.988428
# 5076  9240498803              182 W Main St, Conway, NH  43.976081 -71.132761
# 5077  9968318308           20 Market St, Manchester, NH  42.990220 -71.463840
#
#                FIPS_z
# 0     330110016002004
# 1     330110152003024
# 2     330170846001012
# 3     330130322002006
# 4     330099601023039
# ...               ...
# 5073  330079506001009
# 5074  330170814002015
# 5075  330170805003003
# 5076  330039554012002
# 5077  330112004004013
#
# [5078 rows x 5 columns]

# %%
fips_fill.loc[fips_fill["FIPS_z"].isnull()] #check
# Out:
#       LoanNumber                             full_add        Lat       Long  \
# 214   8312947109       200 Baker Ave 300, Concord, NH  42.460189 -71.384571
# 1385  3985607103  500 US HWY 1 BYPASS, PORTSMOUTH, NH  43.128510 -70.707675
# 2692  8223087000              1815 Rt 3, COLUMBIA, NH  40.857830 -74.179704
#
#      FIPS_z
# 214     NaN
# 1385    NaN
# 2692    NaN

# %% [markdown]
# Parse for Merge

# %%
cols= ["LoanNumber", "FIPS_z"]
fips_fill_parsed = fips_fill[cols]
fips_fill_parsed
# Out:
#       LoanNumber           FIPS_z
# 0     3128618805  330110016002004
# 1     5946307005  330110152003024
# 2     3345347110  330170846001012
# 3     8543107003  330130322002006
# 4     2415809002  330099601023039
# ...          ...              ...
# 5073  8327357003  330079506001009
# 5074  8453917202  330170814002015
# 5075  8581768304  330170805003003
# 5076  9240498803  330039554012002
# 5077  9968318308  330112004004013
#
# [5078 rows x 2 columns]

# %% [markdown]
# Read in base data

# %%
#if from geocode file
fips_check = pd.read_csv("data/state_data/geo/geocoded/geo_nh.csv")
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis =1) 
fips_check

#if from FIPS file
#fips_check = pd.read_csv("data/state_data/geo/geo_fips/NH_fips_scraped.csv") 
#fips_check = fips_check.drop(["Unnamed: 0.1", "Unnamed: 0.1.1", "Unnamed: 0"], axis =1) 
#fips_check.head() #15796
# Out:
#       Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0         555483        555483  3128618805      4/14/21            189
# 1         555484        555484  5946307005       4/6/20            189
# 2         555485        555485  3345347110      4/11/20            189
# 3         555486        555486  8543107003       4/8/20            189
# 4         555487        555487  2415809002      5/16/21            189
# ...          ...           ...         ...          ...            ...
# 5073      560556        560556  8327357003       4/8/20            189
# 5074      560557        560557  8453917202      4/28/20            189
# 5075      560558        560558  8581768304      1/29/21            189
# 5076      560559        560559  9240498803      4/23/21            189
# 5077      560560        560560  9968318308      1/31/21            189
#
#      ProcessingMethod                          BorrowerName  \
# 0                 PPP        EASTER SEALS NEW HAMPSHIRE INC
# 1                 PPP                NAPOLI PSC SERIES, LLC
# 2                 PPP             EASTERN PROPANE GAS, INC.
# 3                 PPP    THE GRANITE GROUP WHOLESALERS, LLC
# 4                 PPP  LITTLETON HOSPITAL ASSOCIATION, INC.
# ...               ...                                   ...
# 5073              PPP                    MOUNTAIN TIRE CORP
# 5074              PPP       EASTERN SPECIALTY CONCRETE INC.
# 5075              PPS  LIVE AND LEARN EARLY LEARNING CENTER
# 5076              PPP               CHILDREN UNLIMITED INC.
# 5077              PPS                        TRIVANTUS INC.
#
#               BorrowerAddress BorrowerCity BorrowerState  ...  \
# 0               555 Auburn St   Manchester            NH  ...
# 1               5 OVERLOOK DR      AMHERST            NH  ...
# 2           28 industrial way    ROCHESTER            NH  ...
# 3                 6 STORRS ST      CONCORD            NH  ...
# 4      600 Saint Johnsbury Rd    Littleton            NH  ...
# ...                       ...          ...           ...  ...
# 5073    15 INDUSTRIAL PARK DR       BERLIN            NH  ...
# 5074  453 CENTRAL AVENUE #107        DOVER            NH  ...
# 5075              114 Mast Rd          Lee            NH  ...
# 5076            182 W Main St       Conway            NH  ...
# 5077             20 Market St   Manchester            NH  ...
#
#                                                LongName TRIIndustrySector  \
# 0     Services for the Elderly and Persons with Disa...         999 Other
# 1                          Limited-Service Restaurants          999 Other
# 2            Gasoline Stations with Convenience Stores          999 Other
# 3     Household Appliances, Electric Housewares, and...         999 Other
# 4               General Medical and Surgical Hospitals          999 Other
# ...                                                 ...               ...
# 5073       All Other Automotive Repair and Maintenance          999 Other
# 5074  Poured Concrete Foundation and Structure Contr...         999 Other
# 5075                           Child Day Care Services          999 Other
# 5076                          Child and Youth Services          999 Other
# 5077                                  Payroll Services          999 Other
#
#                                       IndustrySubsector  4DigitNAICS  \
# 0                   6241 Individual and Family Services       6241.0
# 1              7225 Restaurants and Other Eating Places       7225.0
# 2                               4471 Gasoline Stations        4471.0
# 3     4236 Household Appliances and Electrical and E...       4236.0
# 4           6221 General Medical and Surgical Hospitals       6221.0
# ...                                                 ...          ...
# 5073             8111 Automotive Repair and Maintenance       8111.0
# 5074  2381 Foundation, Structure, and Building Exter...       2381.0
# 5075                       6244 Child Day Care Services       6244.0
# 5076                6241 Individual and Family Services       6241.0
# 5077  5412 Accounting, Tax Preparation, Bookkeeping,...       5412.0
#
#                      SBAOfficeLabel          Loan_Range    job_Range  \
# 0     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million  500 or more
# 1     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million     20 to 49
# 2     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million   250 to 499
# 3     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million  500 or more
# 4     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                             ...                 ...          ...
# 5073  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 5074  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 5075  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 5076  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 5077  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                    full_add        Lat       Long
# 0             555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1                5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2          28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3                  6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4     600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
# ...                                     ...        ...        ...
# 5073      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365 -71.156578
# 5074     453 CENTRAL AVENUE #107, DOVER, NH  43.197461 -70.873775
# 5075                   114 Mast Rd, Lee, NH  43.135207 -70.988428
# 5076              182 W Main St, Conway, NH  43.976081 -71.132761
# 5077           20 Market St, Manchester, NH  42.990220 -71.463840
#
# [5078 rows x 71 columns]

# %% [markdown]
# Merge with MainFrame

# %%
fips_merge = fips_check.merge(fips_fill_parsed, on="LoanNumber", how="left")
fips_merge
# Out:
#       Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 0         555483        555483  3128618805      4/14/21            189
# 1         555484        555484  5946307005       4/6/20            189
# 2         555485        555485  3345347110      4/11/20            189
# 3         555486        555486  8543107003       4/8/20            189
# 4         555487        555487  2415809002      5/16/21            189
# ...          ...           ...         ...          ...            ...
# 5073      560556        560556  8327357003       4/8/20            189
# 5074      560557        560557  8453917202      4/28/20            189
# 5075      560558        560558  8581768304      1/29/21            189
# 5076      560559        560559  9240498803      4/23/21            189
# 5077      560560        560560  9968318308      1/31/21            189
#
#      ProcessingMethod                          BorrowerName  \
# 0                 PPP        EASTER SEALS NEW HAMPSHIRE INC
# 1                 PPP                NAPOLI PSC SERIES, LLC
# 2                 PPP             EASTERN PROPANE GAS, INC.
# 3                 PPP    THE GRANITE GROUP WHOLESALERS, LLC
# 4                 PPP  LITTLETON HOSPITAL ASSOCIATION, INC.
# ...               ...                                   ...
# 5073              PPP                    MOUNTAIN TIRE CORP
# 5074              PPP       EASTERN SPECIALTY CONCRETE INC.
# 5075              PPS  LIVE AND LEARN EARLY LEARNING CENTER
# 5076              PPP               CHILDREN UNLIMITED INC.
# 5077              PPS                        TRIVANTUS INC.
#
#               BorrowerAddress BorrowerCity BorrowerState  ...  \
# 0               555 Auburn St   Manchester            NH  ...
# 1               5 OVERLOOK DR      AMHERST            NH  ...
# 2           28 industrial way    ROCHESTER            NH  ...
# 3                 6 STORRS ST      CONCORD            NH  ...
# 4      600 Saint Johnsbury Rd    Littleton            NH  ...
# ...                       ...          ...           ...  ...
# 5073    15 INDUSTRIAL PARK DR       BERLIN            NH  ...
# 5074  453 CENTRAL AVENUE #107        DOVER            NH  ...
# 5075              114 Mast Rd          Lee            NH  ...
# 5076            182 W Main St       Conway            NH  ...
# 5077             20 Market St   Manchester            NH  ...
#
#       TRIIndustrySector                                  IndustrySubsector  \
# 0             999 Other                6241 Individual and Family Services
# 1             999 Other           7225 Restaurants and Other Eating Places
# 2             999 Other                            4471 Gasoline Stations
# 3             999 Other  4236 Household Appliances and Electrical and E...
# 4             999 Other        6221 General Medical and Surgical Hospitals
# ...                 ...                                                ...
# 5073          999 Other             8111 Automotive Repair and Maintenance
# 5074          999 Other  2381 Foundation, Structure, and Building Exter...
# 5075          999 Other                       6244 Child Day Care Services
# 5076          999 Other                6241 Individual and Family Services
# 5077          999 Other  5412 Accounting, Tax Preparation, Bookkeeping,...
#
#      4DigitNAICS                 SBAOfficeLabel          Loan_Range  \
# 0         6241.0  NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million
# 1         7225.0  NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million
# 2         4471.0  NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million
# 3         4236.0  NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million
# 4         6221.0  NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million
# ...          ...                            ...                 ...
# 5073      8111.0  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000
# 5074      2381.0  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000
# 5075      6244.0  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000
# 5076      6241.0  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000
# 5077      5412.0  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000
#
#         job_Range                               full_add        Lat  \
# 0     500 or more          555 Auburn St, Manchester, NH  42.984669
# 1        20 to 49             5 OVERLOOK DR, AMHERST, NH  42.821269
# 2      250 to 499       28 industrial way, ROCHESTER, NH  43.309051
# 3     500 or more               6 STORRS ST, CONCORD, NH  43.200551
# 4      250 to 499  600 Saint Johnsbury Rd, Littleton, NH  44.317917
# ...           ...                                    ...        ...
# 5073     10 to 19      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365
# 5074     10 to 19     453 CENTRAL AVENUE #107, DOVER, NH  43.197461
# 5075     20 to 49                   114 Mast Rd, Lee, NH  43.135207
# 5076     20 to 49              182 W Main St, Conway, NH  43.976081
# 5077     20 to 49           20 Market St, Manchester, NH  42.990220
#
#            Long           FIPS_z
# 0    -71.449788  330110016002004
# 1    -71.607584  330110152003024
# 2    -71.004924  330170846001012
# 3    -71.531315  330130322002006
# 4    -71.825393  330099601023039
# ...         ...              ...
# 5073 -71.156578  330079506001009
# 5074 -70.873775  330170814002015
# 5075 -70.988428  330170805003003
# 5076 -71.132761  330039554012002
# 5077 -71.463840  330112004004013
#
# [5078 rows x 72 columns]

# %% [markdown]
# If FIPS Encoded

# %%
fips_merge["FIPS_z"] = fips_merge["FIPS_z_y"].fillna(fips_merge["FIPS_z_x"])
fips_merge

# %% [markdown]
# Drop Extra FIPS Columns

# %%
fips_merge_drop = fips_merge.drop(["FIPS_z_x", "FIPS_z_y"], axis=1)
fips_merge_drop

# %%
fips_merge.loc[fips_merge["FIPS_z"].isnull()] #31
# Out:
#        Unnamed: 0  Unnamed: 0.1  LoanNumber DateApproved  SBAOfficeCode  \
# 1457       187081        187081  1004577101       4/9/20            156
# 3075       188699        188699  7637387710       5/1/20            156
# 5247       190871        190871  3539977109      4/11/20            156
# 10902      196526        196526  4931747305      4/30/20            156
#
#       ProcessingMethod                   BorrowerName  \
# 1457               PPP   VISION FINANCIAL MARKETS LLC
# 3075               PPP          PIONEER EDUCATION LLC
# 5247               PPP                  EM BENSON LLC
# 10902              PPP  ELANUS CAPITAL MANAGEMENT LLC
#
#                            BorrowerAddress  BorrowerCity BorrowerState  ...  \
# 1457         120 Long Ridge Road   3 North      STAMFORD            CT  ...
# 3075                           5200 Rte 42  Turnersville            CT  ...
# 5247   1486 highland ave building 2 unit 1      CHESHIRE            CT  ...
# 10902                    180 Varick Street     SALISBURY            CT  ...
#
#                    TRIIndustrySector  \
# 1457                       999 Other
# 3075                       999 Other
# 5247   332 Fabricated Metal Products
# 10902                      999 Other
#
#                                        IndustrySubsector 4DigitNAICS  \
# 1457   5231 Securities and Commodity Contracts Interm...      5231.0
# 3075                  6116 Other Schools and Instruction      6116.0
# 5247   3329 Other Fabricated Metal Product Manufacturing      3329.0
# 10902         5239 Other Financial Investment Activities      5239.0
#
#                     SBAOfficeLabel            Loan_Range  job_Range  \
# 1457   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   50 to 99
# 3075   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   20 to 49
# 5247   CONNECTICUT DISTRICT OFFICE  b $350,000-1 million   10 to 19
# 10902  CONNECTICUT DISTRICT OFFICE    a $150,000-350,000     5 to 9
#
#                                                 full_add        Lat  \
# 1457         120 Long Ridge Road   3 North, STAMFORD, CT  41.195893
# 3075                       5200 Rte 42, Turnersville, CT  39.765211
# 5247   1486 highland ave building 2 unit 1, CHESHIRE, CT        NaN
# 10902                   180 Varick Street, SALISBURY, CT  40.727398
#
#             Long  FIPS_z
# 1457  -73.620851     NaN
# 3075  -75.048383     NaN
# 5247         NaN     NaN
# 10902 -74.005178     NaN
#
# [4 rows x 72 columns]

# %%
geo_NH_fips = fips_merge

# %% [markdown]
# Convert to File

# %%
geo_NH_fips.to_csv("data/state_data/geo/geo_fips/NH_fips_scraped.csv")

# %% [markdown]
# Review & Compare

# %%
geo_NH_fips = pd.read_csv("data/state_data/geo/geo_fips/NH_fips_scraped.csv") 
geo_NH_fips
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 0              0        555483          555483  3128618805      4/14/21
# 1              1        555484          555484  5946307005       4/6/20
# 2              2        555485          555485  3345347110      4/11/20
# 3              3        555486          555486  8543107003       4/8/20
# 4              4        555487          555487  2415809002      5/16/21
# ...          ...           ...             ...         ...          ...
# 5073        5073        560556          560556  8327357003       4/8/20
# 5074        5074        560557          560557  8453917202      4/28/20
# 5075        5075        560558          560558  8581768304      1/29/21
# 5076        5076        560559          560559  9240498803      4/23/21
# 5077        5077        560560          560560  9968318308      1/31/21
#
#       SBAOfficeCode ProcessingMethod                          BorrowerName  \
# 0               189              PPP        EASTER SEALS NEW HAMPSHIRE INC
# 1               189              PPP                NAPOLI PSC SERIES, LLC
# 2               189              PPP             EASTERN PROPANE GAS, INC.
# 3               189              PPP    THE GRANITE GROUP WHOLESALERS, LLC
# 4               189              PPP  LITTLETON HOSPITAL ASSOCIATION, INC.
# ...             ...              ...                                   ...
# 5073            189              PPP                    MOUNTAIN TIRE CORP
# 5074            189              PPP       EASTERN SPECIALTY CONCRETE INC.
# 5075            189              PPS  LIVE AND LEARN EARLY LEARNING CENTER
# 5076            189              PPP               CHILDREN UNLIMITED INC.
# 5077            189              PPS                        TRIVANTUS INC.
#
#               BorrowerAddress BorrowerCity  ... TRIIndustrySector  \
# 0               555 Auburn St   Manchester  ...         999 Other
# 1               5 OVERLOOK DR      AMHERST  ...         999 Other
# 2           28 industrial way    ROCHESTER  ...         999 Other
# 3                 6 STORRS ST      CONCORD  ...         999 Other
# 4      600 Saint Johnsbury Rd    Littleton  ...         999 Other
# ...                       ...          ...  ...               ...
# 5073    15 INDUSTRIAL PARK DR       BERLIN  ...         999 Other
# 5074  453 CENTRAL AVENUE #107        DOVER  ...         999 Other
# 5075              114 Mast Rd          Lee  ...         999 Other
# 5076            182 W Main St       Conway  ...         999 Other
# 5077             20 Market St   Manchester  ...         999 Other
#
#                                       IndustrySubsector 4DigitNAICS  \
# 0                   6241 Individual and Family Services      6241.0
# 1              7225 Restaurants and Other Eating Places      7225.0
# 2                               4471 Gasoline Stations       4471.0
# 3     4236 Household Appliances and Electrical and E...      4236.0
# 4           6221 General Medical and Surgical Hospitals      6221.0
# ...                                                 ...         ...
# 5073             8111 Automotive Repair and Maintenance      8111.0
# 5074  2381 Foundation, Structure, and Building Exter...      2381.0
# 5075                       6244 Child Day Care Services      6244.0
# 5076                6241 Individual and Family Services      6241.0
# 5077  5412 Accounting, Tax Preparation, Bookkeeping,...      5412.0
#
#                      SBAOfficeLabel          Loan_Range    job_Range  \
# 0     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million  500 or more
# 1     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million     20 to 49
# 2     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million   250 to 499
# 3     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million  500 or more
# 4     NEW HAMPSHIRE DISTRICT OFFICE     e $5-10 million   250 to 499
# ...                             ...                 ...          ...
# 5073  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 5074  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     10 to 19
# 5075  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 5076  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
# 5077  NEW HAMPSHIRE DISTRICT OFFICE  a $150,000-350,000     20 to 49
#
#                                    full_add        Lat       Long  \
# 0             555 Auburn St, Manchester, NH  42.984669 -71.449788
# 1                5 OVERLOOK DR, AMHERST, NH  42.821269 -71.607584
# 2          28 industrial way, ROCHESTER, NH  43.309051 -71.004924
# 3                  6 STORRS ST, CONCORD, NH  43.200551 -71.531315
# 4     600 Saint Johnsbury Rd, Littleton, NH  44.317917 -71.825393
# ...                                     ...        ...        ...
# 5073      15 INDUSTRIAL PARK DR, BERLIN, NH  44.510365 -71.156578
# 5074     453 CENTRAL AVENUE #107, DOVER, NH  43.197461 -70.873775
# 5075                   114 Mast Rd, Lee, NH  43.135207 -70.988428
# 5076              182 W Main St, Conway, NH  43.976081 -71.132761
# 5077           20 Market St, Manchester, NH  42.990220 -71.463840
#
#             FIPS_z
# 0     3.301100e+14
# 1     3.301102e+14
# 2     3.301708e+14
# 3     3.301303e+14
# 4     3.300996e+14
# ...            ...
# 5073  3.300795e+14
# 5074  3.301708e+14
# 5075  3.301708e+14
# 5076  3.300396e+14
# 5077  3.301120e+14
#
# [5078 rows x 73 columns]

# %%
#fill in missing Lat, Long, FIPS
geo_NH_fips.loc[geo_NH_fips["FIPS_z"].isnull()] #1241
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  LoanNumber DateApproved  \
# 214          214        555697          555697  8312947109      4/15/20
# 1385        1385        556868          556868  3985607103      4/12/20
# 2692        2692        558175          558175  8223087000       4/8/20
#
#       SBAOfficeCode ProcessingMethod                     BorrowerName  \
# 214             189              PPP  NEW HORIZON COMMUNICATIONS CORP
# 1385            189              PPP     COAST BUICK GMC CADILLAC INC
# 2692            189              PPP              HMI ACQUISITION LLC
#
#           BorrowerAddress BorrowerCity  ... TRIIndustrySector  \
# 214     200 Baker Ave 300      Concord  ...         999 Other
# 1385  500 US HWY 1 BYPASS   PORTSMOUTH  ...         999 Other
# 2692            1815 Rt 3     COLUMBIA  ...         999 Other
#
#                          IndustrySubsector 4DigitNAICS  \
# 214          5179 Other Telecommunications      5179.0
# 1385              4411 Automobile Dealers       4411.0
# 2692  1153 Support Activities for Forestry      1153.0
#
#                      SBAOfficeLabel            Loan_Range  job_Range  \
# 214   NEW HAMPSHIRE DISTRICT OFFICE        c $1-2 million   50 to 99
# 1385  NEW HAMPSHIRE DISTRICT OFFICE  b $350,000-1 million   20 to 49
# 2692  NEW HAMPSHIRE DISTRICT OFFICE    a $150,000-350,000   20 to 49
#
#                                  full_add        Lat       Long FIPS_z
# 214        200 Baker Ave 300, Concord, NH  42.460189 -71.384571    NaN
# 1385  500 US HWY 1 BYPASS, PORTSMOUTH, NH  43.128510 -70.707675    NaN
# 2692              1815 Rt 3, COLUMBIA, NH  40.857830 -74.179704    NaN
#
# [3 rows x 73 columns]
